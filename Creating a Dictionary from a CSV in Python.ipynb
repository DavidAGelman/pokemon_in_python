# %% [markdown]
# The purpose of this project is to use base python 3 functionality to gain familiarty with how lists and dictionaries function.  The end deliverable is a function that takes a csv file and converts it into a dictionary.
#
# The basic premise here is that you are building some infrastructure for a game that is a riff on Pokemon Go.  The conceit is that Pokemon gyms are now popular online destinations, and catching Pokemon in the "wild" simply requires browsing the internet for hours in the comfort of your home.  To do this, several different structures have to be created to work together.

# %% [markdown]
# ###### Step 0: Import any necessary packages

# %%
# this package is imported to improve dictionary printing to make checking work and outputs easier and cleaner
from pprint import pprint

# %% [markdown]
# ###### Step 1: Define the gym locations

# %%
# create a list of all gyms:
gyms = ['reddit.com',
        'amazon.com',
        'twitter.com',
        'linkedin.com',
        'ebay.com',
        'netflix.com',
        'amazon.com',
        'stackoverflow.com',
        'githubb.com',
        'quora.com']

# because 'amazon.com' appears twice on the list, I have have decided to use make a list out of the set of the original gyms list
gyms = list(set(gyms))

# %% [markdown]
# ###### Step 2: Every game needs players.  Create a dictionary to store information about players
#
# The player variables are:
#
#     player_id : id code unique to each player (integer)
#     player_name : entered name of the player (string)
#     time_played : number of time played the game in minutes (float)
#     player_pokemon: the player's captured pokemon (dictionary)
#     gyms_visited: ids of the gyms that a player has visited (list)

# %%
# create the necessary variables and give them values
player_id = 1
player_name = ('david')
time_played = 10.00
player_pokemon = {'pokemon_id': 0}
gyms_visited = ['reddit.com','amazon.com']

# %%
# create a dictionary by zipping together a list of keys and a list of values using the variables defined above
keys = ['player_name','time_played', 'player_pokemon', 'gyms_visited']
values = [player_name, time_played, player_pokemon, gyms_visited]
players = dict(zip(keys, values))
players = {1: players}

# take a look at the new dictionary
pprint(players)
# Out:
# {1: {'gyms_visited': ['reddit.com', 'amazon.com'],
#      'player_name': 'david',
#      'player_pokemon': {'pokemon_id': 0},
#      'time_played': 10.0}}

# %% [markdown]
# ###### Step 3: Create a new player and add them to the players dictionary

# %%
# create the dictionary for p2
player_2 = {'gyms_visited': ['alcatraz','pacific_beach'], 
            'player_name': 'allison', 
            'player_pokemon': {'pokemon_id': 0}, 
            'time_played': 10.5}
player_2 = {2: player_2}

# make sure p2 looks right
pprint(player_2)
# Out:
# {2: {'gyms_visited': ['alcatraz', 'pacific_beach'],
#      'player_name': 'allison',
#      'player_pokemon': {'pokemon_id': 0},
#      'time_played': 10.5}}

# %%
# now combine the p1 dic. with the p2 dic. to create the new_players dictionary:
new_players = dict()
new_players.update(players)
new_players.update(player_2)

# print updated players dictionary, now called new_players
pprint(new_players)
# Out:
# {1: {'gyms_visited': ['reddit.com', 'amazon.com'],
#      'player_name': 'david',
#      'player_pokemon': {'pokemon_id': 0},
#      'time_played': 10.0},
#  2: {'gyms_visited': ['alcatraz', 'pacific_beach'],
#      'player_name': 'allison',
#      'player_pokemon': {'pokemon_id': 0},
#      'time_played': 10.5}}

# %% [markdown]
# ###### Step 3.1: Use a for a loop to print out which gyms each player has visited

# %%
# the first line creates a loop over the number of players.
# the second line only runs the next for loop if a player has visited any gyms.
#     Note that we add 1 to the dictionary's index since indexing begins at zero but player keys begin at 1.
# the third line defines the next for loop for the number of gyms a player has visited
# the fourth line prints the gyms the player has visited and their name
# the fifth and sixth lines print the player's name and indicate they have visited no gyms if they have visited no gyms.

for player in range(len(new_players)):
    if len(new_players[player+1]['gyms_visited']) > 0:
        for gym in range(len(new_players[player+1]['gyms_visited'])):
            print(new_players[player+1]['player_name'] + " has visited " + new_players[player+1]['gyms_visited'][gym])
    else:
        print(new_players[player+1]['player_name'] + " has visited zero gyms.")
# Out:
# david has visited reddit.com
# david has visited amazon.com
# allison has visited alcatraz
# allison has visited pacific_beach

# %% [markdown]
# ###### Step 4: Create a pokedex containing three pokemon
#
# The pokedex is a dictionary of dictionaries.
#
# Each pokemon will be defined by these variables:
#
#     pokemon_id : unique identifier for each pokemon (integer)
#     name : the name of the pokemon (string)
#     type : the category of pokemon (string)
#     hp : base hitpoints (integer)
#     attack : base attack (integer)
#     defense : base defense (integer)
#     special_attack : base special attack (integer)
#     special_defense : base sepecial defense (integer)
#     speed : base speed (integer)
#
# We are only going to create 3 different pokemon with these `pokemon_id` and `pokemon_name` values:
#
#     1 : 'charmander'
#     2 : 'squirtle'
#     3 : 'bulbasaur'
#
# Assign charmander and bulbasaur to player 2 and squirtle to player 1.

# %%
# to create the dictionary of pokemon dictionaries, I'm going to create lists of the various attirbutes for each pokemon variable.
# once those lists are created, I will combine the lists into a new list called 'attributes'
# next, I use a comprehension to create a dictionary atrtibutes for each pokemon.
# I then zip the two together to create a dictionary of dictionaries

pokemon_id = range(1,4)

name = ['charmander', 'squirtle', 'bulbasaur']
pokemon_type = ['fire', 'water', 'poison']
hp = [100, 200, 300]
attack = [20, 13, 25]
defense  = [35, 20, 5]
special_attack = [40, 20, 35]
special_defense = [5, 20, 10]
speed = [15, 25, 30]

attribute_names = ['name',
                  'pokemon_type',
                  'hp',
                  'attack',
                  'defense',
                  'special_attack',
                  'special_defense',
                  'speed']
attributes = [name, pokemon_type, hp, attack, defense, special_attack, special_defense, speed]

pokemon_dct = [{attribute_names[col]: attributes[col][row] for col in range(len(attributes))} for row in range(len(attributes[0]))]

# print the pokemon_dct to make sure it's right...
pprint(pokemon_dct)
# Out:
# [{'attack': 20,
#   'defense': 35,
#   'hp': 100,
#   'name': 'charmander',
#   'pokemon_type': 'fire',
#   'special_attack': 40,
#   'special_defense': 5,
#   'speed': 15},
#  {'attack': 13,
#   'defense': 20,
#   'hp': 200,
#   'name': 'squirtle',
#   'pokemon_type': 'water',
#   'special_attack': 20,
#   'special_defense': 20,
#   'speed': 25},
#  {'attack': 25,
#   'defense': 5,
#   'hp': 300,
#   'name': 'bulbasaur',
#   'pokemon_type': 'poison',
#   'special_attack': 35,
#   'special_defense': 10,
#   'speed': 30}]

# %%
# now that we have the pokemon attributes all together in a list of dictionaries, can combine with pokemon ids using a zip method
pokedex = dict(zip(pokemon_id,pokemon_dct))
# print it out and check it out!
pprint(pokedex)
# Out:
# {1: {'attack': 20,
#      'defense': 35,
#      'hp': 100,
#      'name': 'charmander',
#      'pokemon_type': 'fire',
#      'special_attack': 40,
#      'special_defense': 5,
#      'speed': 15},
#  2: {'attack': 13,
#      'defense': 20,
#      'hp': 200,
#      'name': 'squirtle',
#      'pokemon_type': 'water',
#      'special_attack': 20,
#      'special_defense': 20,
#      'speed': 25},
#  3: {'attack': 25,
#      'defense': 5,
#      'hp': 300,
#      'name': 'bulbasaur',
#      'pokemon_type': 'poison',
#      'special_attack': 35,
#      'special_defense': 10,
#      'speed': 30}}

# %%
# assigne the appropriate pokemon to each player
new_players[1]['player_pokemon'] = {'pokemon_id': [2]}
new_players[2]['player_pokemon'] = {'pokemon_id': [1,3]}

# print the player information dictionary to see the updates
pprint(new_players)
# Out:
# {1: {'gyms_visited': ['reddit.com', 'amazon.com'],
#      'player_name': 'david',
#      'player_pokemon': {'pokemon_id': [2]},
#      'time_played': 10.0},
#  2: {'gyms_visited': ['alcatraz', 'pacific_beach'],
#      'player_name': 'allison',
#      'player_pokemon': {'pokemon_id': [1, 3]},
#      'time_played': 10.5}}

# %% [markdown]
# ###### Step 5: Calculate and display the power of each player's individual pokedex using a function
#
# Player power is defined as the sum of the base statistics all of their pokemon.
#
# The function should:
#
# 1. Accept a dictionary of player information, the `pokedex` dictionary, and a player_id as arguments.
# 2. For the specified player_id, look up that player's pokemon and their level(s).
# 3. Find and aggregate the attack and defense values for each of the player's pokemon from the `pokedex` dictionary.
# 4. Print "[player name]'s power is [player power].", where the player power is the sum of the base statistics for all of their pokemon.
# 5. Return the player's power value.

# %%
def power(player_dct, pokedex_dct, player_id):
    """returns the total power of all the pokemon in a player's pokedex.
    player_dct is a the dictionary that contains all the information about the game players.
    pokedex_dct is a dictionary containing all the pokemon in the game.
    player_id is the unique player id number that you want to return the power for."""
    
    total_player_power = 0
    for pokemon in range(len(player_dct[player_id]['player_pokemon']['pokemon_id'])):
        player_power = pokedex_dct[player_dct[player_id]['player_pokemon']['pokemon_id'][pokemon]]['attack']\
                    + pokedex_dct[player_dct[player_id]['player_pokemon']['pokemon_id'][pokemon]]['defense']\
                    + pokedex_dct[player_dct[player_id]['player_pokemon']['pokemon_id'][pokemon]]['hp']\
                    + pokedex_dct[player_dct[player_id]['player_pokemon']['pokemon_id'][pokemon]]['speed']\
                    + pokedex_dct[player_dct[player_id]['player_pokemon']['pokemon_id'][pokemon]]['special_attack']\
                    + pokedex_dct[player_dct[player_id]['player_pokemon']['pokemon_id'][pokemon]]['special_defense']
        #print(player_dct[player_id]['player_name'] + "'s power is " + str(player_power))
        total_player_power += player_power
    return total_player_power

# %% [markdown]
# ###### Step 5.1: Show that the function works

# %%
power(new_players,pokedex,2)
# Out:
# 620

# %% [markdown]
# ###### Step 6: Load in the csv file containing all the information about the pokemon in the game
#
# In order to use the informaton in the csv, I need to parse this string into a more useable format. The format of the string is:
#
# - Rows are separated by newline characters: \n
# - Columns are separated by commas: ,
# - All cells in the csv are double quoted. Ex: "PokedexNumber" is the first cell of the first row.
#
# Using for-loops, create a list of lists where each list within the overall list is a row of the csv/matrix, and each element in that list is a cell in that row. Additional criteria:
#
# 1. Quotes are removed from each cell item.
# 2. Numeric column values are converted to floats.
# 3. There are some cells that are empty and have no information. For these cells put a -1 value in place.
#
# Your end result is effectively a matrix. Each list in the outer list is a row, and the *j*th elements of list together form the *j*th column, which represents a data attribute. The first three lists in your pokedex list should look like this:
#
#     ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
#     [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
#     [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %%
# read in pokedex info
raw_pd = ''
pokedex_file = 'pokedex_basic.csv'
with open(pokedex_file, 'r') as f:
    raw_pd = f.read()
    
# the pokedex string is assigned to the raw_pd variable

# %%
#first split the lines up
# we're calling the read in, split csv poke_file
poke_file = raw_pd.split('\n')

# %%
# now get rid of all the double quotes
for item in range(len(poke_file)):
    poke_file[item] = poke_file[item].replace('\"',"")

# %%
# now split by the comma so each item is it's own entry
for item in range(len(poke_file)):
    poke_file[item] = poke_file[item].split(",")

# %%
# replace blank cells w/ -1
for item in range(len(poke_file)):
    if poke_file[item] == "":
        poke_file[item] = -1
    else:
        poke_file[item] = poke_file[item]

# %%
# now convert all the numbers from strings to floats
# create the converting function
def float_conv(i):
    """Converts an object into a float if possible.
    i is the object to be converted to float.
    """
    try:
        return float(i)
    except ValueError:
        return i

# now use the function in a list comprehension to apply it to each row (pokemon) in the poke_file
poke_file = [[float_conv(i) for i in item] for item in poke_file]

# %%
# look at the  first three rows to make sure that it matches with the expected output
poke_file[:3]
# Out:
# [['PokedexNumber',
#   'Name',
#   'Type',
#   'Total',
#   'HP',
#   'Attack',
#   'Defense',
#   'SpecialAttack',
#   'SpecialDefense',
#   'Speed'],
#  [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0],
#  [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]]

# %% [markdown]
# ###### Step 7: Write a function to generate a full pokedex dictionary
#
# The function should:
#
# 1. Take the parsed pokedex information created above as an argument.
# 2. Return a dictionary in the same format as the manual pokedex created before, containing the information from the parsed full pokedex file.

# %%
def pokedex_generator(row):
    """returns a dictionary of attributes for a pokemon.
    row is an item (aka a pokemon) from the poke_file csv file.
    """
    pokemon_info = {'attack': row[5],
     'defense': row[6],
     'hp': row[4],
     'name': row[1],
     'pokemon_type': row[2],
     'special_attack': row[7],
     'special_defense': row[8],
     'speed': row[9],
     'total': row[3]}
    return pokemon_info

# %%
# use a for loop to create the pokedex dictionary to account for pokemon that have repeat id numbers

# create a list of pokemon ids
pokemon_ids = [row[0] for row in poke_file]

#peel off and discard the first element since it is the string
pokemon_ids = pokemon_ids[1:]

#initialize a blank dictionary
new_full_pokedex = {}

# run the loop using the pokedex_generator function
for i,j in enumerate(pokemon_ids):
    while j in new_full_pokedex.keys():
        j +=.1
    new_full_pokedex[j] = pokedex_generator(poke_file[i])
new_full_pokedex
# Out:
# {1.0: {'attack': 'Attack',
#   'defense': 'Defense',
#   'hp': 'HP',
#   'name': 'Name',
#   'pokemon_type': 'Type',
#   'special_attack': 'SpecialAttack',
#   'special_defense': 'SpecialDefense',
#   'speed': 'Speed',
#   'total': 'Total'},
#  2.0: {'attack': 49.0,
#   'defense': 49.0,
#   'hp': 45.0,
#   'name': 'Bulbasaur',
#   'pokemon_type': 'GrassPoison',
#   'special_attack': 65.0,
#   'special_defense': 65.0,
#   'speed': 45.0,
#   'total': 318.0},
#  3.0: {'attack': 62.0,
#   'defense': 63.0,
#   'hp': 60.0,
#   'name': 'Ivysaur',
#   'pokemon_type': 'GrassPoison',
#   'special_attack': 80.0,
#   'special_defense': 80.0,
#   'speed': 60.0,
#   'total': 405.0},
#  3.1: {'attack': 82.0,
#   'defense': 83.0,
#   'hp': 80.0,
#   'name': 'Venusaur',
#   'pokemon_type': 'GrassPoison',
#   'special_attack': 100.0,
#   'special_defense': 100.0,
#   'speed': 80.0,
#   'total': 525.0},
#  4.0: {'attack': 100.0,
#   'defense': 123.0,
#   'hp': 80.0,
#   'name': 'VenusaurMega Venusaur',
#   'pokemon_type': 'GrassPoison',
#   'special_attack': 122.0,
#   'special_defense': 120.0,
#   'speed': 80.0,
#   'total': 625.0},
#  5.0: {'attack': 52.0,
#   'defense': 43.0,
#   'hp': 39.0,
#   'name': 'Charmander',
#   'pokemon_type': 'Fire',
#   'special_attack': 60.0,
#   'special_defense': 50.0,
#   'speed': 65.0,
#   'total': 309.0},
#  6.0: {'attack': 64.0,
#   'defense': 58.0,
#   'hp': 58.0,
#   'name': 'Charmeleon',
#   'pokemon_type': 'Fire',
#   'special_attack': 80.0,
#   'special_defense': 65.0,
#   'speed': 80.0,
#   'total': 405.0},
#  6.1: {'attack': 84.0,
#   'defense': 78.0,
#   'hp': 78.0,
#   'name': 'Charizard',
#   'pokemon_type': 'FireFlying',
#   'special_attack': 109.0,
#   'special_defense': 85.0,
#   'speed': 100.0,
#   'total': 534.0},
#  6.199999999999999: {'attack': 130.0,
#   'defense': 111.0,
#   'hp': 78.0,
#   'name': 'CharizardMega Charizard X',
#   'pokemon_type': 'FireDragon',
#   'special_attack': 130.0,
#   'special_defense': 85.0,
#   'speed': 100.0,
#   'total': 634.0},
#  7.0: {'attack': 104.0,
#   'defense': 78.0,
#   'hp': 78.0,
#   'name': 'CharizardMega Charizard Y',
#   'pokemon_type': 'FireFlying',
#   'special_attack': 159.0,
#   'special_defense': 115.0,
#   'speed': 100.0,
#   'total': 634.0},
#  8.0: {'attack': 48.0,
#   'defense': 65.0,
#   'hp': 44.0,
#   'name': 'Squirtle',
#   'pokemon_type': 'Water',
#   'special_attack': 50.0,
#   'special_defense': 64.0,
#   'speed': 43.0,
#   'total': 314.0},
#  9.0: {'attack': 63.0,
#   'defense': 80.0,
#   'hp': 59.0,
#   'name': 'Wartortle',
#   'pokemon_type': 'Water',
#   'special_attack': 65.0,
#   'special_defense': 80.0,
#   'speed': 58.0,
#   'total': 405.0},
#  9.1: {'attack': 83.0,
#   'defense': 100.0,
#   'hp': 79.0,
#   'name': 'Blastoise',
#   'pokemon_type': 'Water',
#   'special_attack': 85.0,
#   'special_defense': 105.0,
#   'speed': 78.0,
#   'total': 530.0},
#  10.0: {'attack': 103.0,
#   'defense': 120.0,
#   'hp': 79.0,
#   'name': 'BlastoiseMega Blastoise',
#   'pokemon_type': 'Water',
#   'special_attack': 135.0,
#   'special_defense': 115.0,
#   'speed': 78.0,
#   'total': 630.0},
#  11.0: {'attack': 30.0,
#   'defense': 35.0,
#   'hp': 45.0,
#   'name': 'Caterpie',
#   'pokemon_type': 'Bug',
#   'special_attack': 20.0,
#   'special_defense': 20.0,
#   'speed': 45.0,
#   'total': 195.0},
#  12.0: {'attack': 20.0,
#   'defense': 55.0,
#   'hp': 50.0,
#   'name': 'Metapod',
#   'pokemon_type': 'Bug',
#   'special_attack': 25.0,
#   'special_defense': 25.0,
#   'speed': 30.0,
#   'total': 205.0},
#  13.0: {'attack': 45.0,
#   'defense': 50.0,
#   'hp': 60.0,
#   'name': 'Butterfree',
#   'pokemon_type': 'BugFlying',
#   'special_attack': 90.0,
#   'special_defense': 80.0,
#   'speed': 70.0,
#   'total': 395.0},
#  14.0: {'attack': 35.0,
#   'defense': 30.0,
#   'hp': 40.0,
#   'name': 'Weedle',
#   'pokemon_type': 'BugPoison',
#   'special_attack': 20.0,
#   'special_defense': 20.0,
#   'speed': 50.0,
#   'total': 195.0},
#  15.0: {'attack': 25.0,
#   'defense': 50.0,
#   'hp': 45.0,
#   'name': 'Kakuna',
#   'pokemon_type': 'BugPoison',
#   'special_attack': 25.0,
#   'special_defense': 25.0,
#   'speed': 35.0,
#   'total': 205.0},
#  15.1: {'attack': 90.0,
#   'defense': 40.0,
#   'hp': 65.0,
#   'name': 'Beedrill',
#   'pokemon_type': 'BugPoison',
#   'special_attack': 45.0,
#   'special_defense': 80.0,
#   'speed': 75.0,
#   'total': 395.0},
#  16.0: {'attack': 150.0,
#   'defense': 40.0,
#   'hp': 65.0,
#   'name': 'BeedrillMega Beedrill',
#   'pokemon_type': 'BugPoison',
#   'special_attack': 15.0,
#   'special_defense': 80.0,
#   'speed': 145.0,
#   'total': 495.0},
#  17.0: {'attack': 45.0,
#   'defense': 40.0,
#   'hp': 40.0,
#   'name': 'Pidgey',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 35.0,
#   'special_defense': 35.0,
#   'speed': 56.0,
#   'total': 251.0},
#  18.0: {'attack': 60.0,
#   'defense': 55.0,
#   'hp': 63.0,
#   'name': 'Pidgeotto',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 50.0,
#   'special_defense': 50.0,
#   'speed': 71.0,
#   'total': 349.0},
#  18.1: {'attack': 80.0,
#   'defense': 75.0,
#   'hp': 83.0,
#   'name': 'Pidgeot',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 70.0,
#   'special_defense': 70.0,
#   'speed': 101.0,
#   'total': 479.0},
#  19.0: {'attack': 80.0,
#   'defense': 80.0,
#   'hp': 83.0,
#   'name': 'PidgeotMega Pidgeot',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 135.0,
#   'special_defense': 80.0,
#   'speed': 121.0,
#   'total': 579.0},
#  20.0: {'attack': 56.0,
#   'defense': 35.0,
#   'hp': 30.0,
#   'name': 'Rattata',
#   'pokemon_type': 'Normal',
#   'special_attack': 25.0,
#   'special_defense': 35.0,
#   'speed': 72.0,
#   'total': 253.0},
#  21.0: {'attack': 81.0,
#   'defense': 60.0,
#   'hp': 55.0,
#   'name': 'Raticate',
#   'pokemon_type': 'Normal',
#   'special_attack': 50.0,
#   'special_defense': 70.0,
#   'speed': 97.0,
#   'total': 413.0},
#  22.0: {'attack': 60.0,
#   'defense': 30.0,
#   'hp': 40.0,
#   'name': 'Spearow',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 31.0,
#   'special_defense': 31.0,
#   'speed': 70.0,
#   'total': 262.0},
#  23.0: {'attack': 90.0,
#   'defense': 65.0,
#   'hp': 65.0,
#   'name': 'Fearow',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 61.0,
#   'special_defense': 61.0,
#   'speed': 100.0,
#   'total': 442.0},
#  24.0: {'attack': 60.0,
#   'defense': 44.0,
#   'hp': 35.0,
#   'name': 'Ekans',
#   'pokemon_type': 'Poison',
#   'special_attack': 40.0,
#   'special_defense': 54.0,
#   'speed': 55.0,
#   'total': 288.0},
#  25.0: {'attack': 85.0,
#   'defense': 69.0,
#   'hp': 60.0,
#   'name': 'Arbok',
#   'pokemon_type': 'Poison',
#   'special_attack': 65.0,
#   'special_defense': 79.0,
#   'speed': 80.0,
#   'total': 438.0},
#  26.0: {'attack': 55.0,
#   'defense': 40.0,
#   'hp': 35.0,
#   'name': 'Pikachu',
#   'pokemon_type': 'Electric',
#   'special_attack': 50.0,
#   'special_defense': 50.0,
#   'speed': 90.0,
#   'total': 320.0},
#  27.0: {'attack': 90.0,
#   'defense': 55.0,
#   'hp': 60.0,
#   'name': 'Raichu',
#   'pokemon_type': 'Electric',
#   'special_attack': 90.0,
#   'special_defense': 80.0,
#   'speed': 110.0,
#   'total': 485.0},
#  28.0: {'attack': 75.0,
#   'defense': 85.0,
#   'hp': 50.0,
#   'name': 'Sandshrew',
#   'pokemon_type': 'Ground',
#   'special_attack': 20.0,
#   'special_defense': 30.0,
#   'speed': 40.0,
#   'total': 300.0},
#  29.0: {'attack': 100.0,
#   'defense': 110.0,
#   'hp': 75.0,
#   'name': 'Sandslash',
#   'pokemon_type': 'Ground',
#   'special_attack': 45.0,
#   'special_defense': 55.0,
#   'speed': 65.0,
#   'total': 450.0},
#  30.0: {'attack': 47.0,
#   'defense': 52.0,
#   'hp': 55.0,
#   'name': 'NidoranF',
#   'pokemon_type': 'Poison',
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 41.0,
#   'total': 275.0},
#  31.0: {'attack': 62.0,
#   'defense': 67.0,
#   'hp': 70.0,
#   'name': 'Nidorina',
#   'pokemon_type': 'Poison',
#   'special_attack': 55.0,
#   'special_defense': 55.0,
#   'speed': 56.0,
#   'total': 365.0},
#  32.0: {'attack': 92.0,
#   'defense': 87.0,
#   'hp': 90.0,
#   'name': 'Nidoqueen',
#   'pokemon_type': 'PoisonGround',
#   'special_attack': 75.0,
#   'special_defense': 85.0,
#   'speed': 76.0,
#   'total': 505.0},
#  33.0: {'attack': 57.0,
#   'defense': 40.0,
#   'hp': 46.0,
#   'name': 'NidoranM',
#   'pokemon_type': 'Poison',
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 50.0,
#   'total': 273.0},
#  34.0: {'attack': 72.0,
#   'defense': 57.0,
#   'hp': 61.0,
#   'name': 'Nidorino',
#   'pokemon_type': 'Poison',
#   'special_attack': 55.0,
#   'special_defense': 55.0,
#   'speed': 65.0,
#   'total': 365.0},
#  35.0: {'attack': 102.0,
#   'defense': 77.0,
#   'hp': 81.0,
#   'name': 'Nidoking',
#   'pokemon_type': 'PoisonGround',
#   'special_attack': 85.0,
#   'special_defense': 75.0,
#   'speed': 85.0,
#   'total': 505.0},
#  36.0: {'attack': 45.0,
#   'defense': 48.0,
#   'hp': 70.0,
#   'name': 'Clefairy',
#   'pokemon_type': 'Fairy',
#   'special_attack': 60.0,
#   'special_defense': 65.0,
#   'speed': 35.0,
#   'total': 323.0},
#  37.0: {'attack': 70.0,
#   'defense': 73.0,
#   'hp': 95.0,
#   'name': 'Clefable',
#   'pokemon_type': 'Fairy',
#   'special_attack': 95.0,
#   'special_defense': 90.0,
#   'speed': 60.0,
#   'total': 483.0},
#  38.0: {'attack': 41.0,
#   'defense': 40.0,
#   'hp': 38.0,
#   'name': 'Vulpix',
#   'pokemon_type': 'Fire',
#   'special_attack': 50.0,
#   'special_defense': 65.0,
#   'speed': 65.0,
#   'total': 299.0},
#  39.0: {'attack': 76.0,
#   'defense': 75.0,
#   'hp': 73.0,
#   'name': 'Ninetales',
#   'pokemon_type': 'Fire',
#   'special_attack': 81.0,
#   'special_defense': 100.0,
#   'speed': 100.0,
#   'total': 505.0},
#  40.0: {'attack': 45.0,
#   'defense': 20.0,
#   'hp': 115.0,
#   'name': 'Jigglypuff',
#   'pokemon_type': 'NormalFairy',
#   'special_attack': 45.0,
#   'special_defense': 25.0,
#   'speed': 20.0,
#   'total': 270.0},
#  41.0: {'attack': 70.0,
#   'defense': 45.0,
#   'hp': 140.0,
#   'name': 'Wigglytuff',
#   'pokemon_type': 'NormalFairy',
#   'special_attack': 85.0,
#   'special_defense': 50.0,
#   'speed': 45.0,
#   'total': 435.0},
#  42.0: {'attack': 45.0,
#   'defense': 35.0,
#   'hp': 40.0,
#   'name': 'Zubat',
#   'pokemon_type': 'PoisonFlying',
#   'special_attack': 30.0,
#   'special_defense': 40.0,
#   'speed': 55.0,
#   'total': 245.0},
#  43.0: {'attack': 80.0,
#   'defense': 70.0,
#   'hp': 75.0,
#   'name': 'Golbat',
#   'pokemon_type': 'PoisonFlying',
#   'special_attack': 65.0,
#   'special_defense': 75.0,
#   'speed': 90.0,
#   'total': 455.0},
#  44.0: {'attack': 50.0,
#   'defense': 55.0,
#   'hp': 45.0,
#   'name': 'Oddish',
#   'pokemon_type': 'GrassPoison',
#   'special_attack': 75.0,
#   'special_defense': 65.0,
#   'speed': 30.0,
#   'total': 320.0},
#  45.0: {'attack': 65.0,
#   'defense': 70.0,
#   'hp': 60.0,
#   'name': 'Gloom',
#   'pokemon_type': 'GrassPoison',
#   'special_attack': 85.0,
#   'special_defense': 75.0,
#   'speed': 40.0,
#   'total': 395.0},
#  46.0: {'attack': 80.0,
#   'defense': 85.0,
#   'hp': 75.0,
#   'name': 'Vileplume',
#   'pokemon_type': 'GrassPoison',
#   'special_attack': 110.0,
#   'special_defense': 90.0,
#   'speed': 50.0,
#   'total': 490.0},
#  47.0: {'attack': 70.0,
#   'defense': 55.0,
#   'hp': 35.0,
#   'name': 'Paras',
#   'pokemon_type': 'BugGrass',
#   'special_attack': 45.0,
#   'special_defense': 55.0,
#   'speed': 25.0,
#   'total': 285.0},
#  48.0: {'attack': 95.0,
#   'defense': 80.0,
#   'hp': 60.0,
#   'name': 'Parasect',
#   'pokemon_type': 'BugGrass',
#   'special_attack': 60.0,
#   'special_defense': 80.0,
#   'speed': 30.0,
#   'total': 405.0},
#  49.0: {'attack': 55.0,
#   'defense': 50.0,
#   'hp': 60.0,
#   'name': 'Venonat',
#   'pokemon_type': 'BugPoison',
#   'special_attack': 40.0,
#   'special_defense': 55.0,
#   'speed': 45.0,
#   'total': 305.0},
#  50.0: {'attack': 65.0,
#   'defense': 60.0,
#   'hp': 70.0,
#   'name': 'Venomoth',
#   'pokemon_type': 'BugPoison',
#   'special_attack': 90.0,
#   'special_defense': 75.0,
#   'speed': 90.0,
#   'total': 450.0},
#  51.0: {'attack': 55.0,
#   'defense': 25.0,
#   'hp': 10.0,
#   'name': 'Diglett',
#   'pokemon_type': 'Ground',
#   'special_attack': 35.0,
#   'special_defense': 45.0,
#   'speed': 95.0,
#   'total': 265.0},
#  52.0: {'attack': 80.0,
#   'defense': 50.0,
#   'hp': 35.0,
#   'name': 'Dugtrio',
#   'pokemon_type': 'Ground',
#   'special_attack': 50.0,
#   'special_defense': 70.0,
#   'speed': 120.0,
#   'total': 405.0},
#  53.0: {'attack': 45.0,
#   'defense': 35.0,
#   'hp': 40.0,
#   'name': 'Meowth',
#   'pokemon_type': 'Normal',
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 90.0,
#   'total': 290.0},
#  54.0: {'attack': 70.0,
#   'defense': 60.0,
#   'hp': 65.0,
#   'name': 'Persian',
#   'pokemon_type': 'Normal',
#   'special_attack': 65.0,
#   'special_defense': 65.0,
#   'speed': 115.0,
#   'total': 440.0},
#  55.0: {'attack': 52.0,
#   'defense': 48.0,
#   'hp': 50.0,
#   'name': 'Psyduck',
#   'pokemon_type': 'Water',
#   'special_attack': 65.0,
#   'special_defense': 50.0,
#   'speed': 55.0,
#   'total': 320.0},
#  56.0: {'attack': 82.0,
#   'defense': 78.0,
#   'hp': 80.0,
#   'name': 'Golduck',
#   'pokemon_type': 'Water',
#   'special_attack': 95.0,
#   'special_defense': 80.0,
#   'speed': 85.0,
#   'total': 500.0},
#  57.0: {'attack': 80.0,
#   'defense': 35.0,
#   'hp': 40.0,
#   'name': 'Mankey',
#   'pokemon_type': 'Fighting',
#   'special_attack': 35.0,
#   'special_defense': 45.0,
#   'speed': 70.0,
#   'total': 305.0},
#  58.0: {'attack': 105.0,
#   'defense': 60.0,
#   'hp': 65.0,
#   'name': 'Primeape',
#   'pokemon_type': 'Fighting',
#   'special_attack': 60.0,
#   'special_defense': 70.0,
#   'speed': 95.0,
#   'total': 455.0},
#  59.0: {'attack': 70.0,
#   'defense': 45.0,
#   'hp': 55.0,
#   'name': 'Growlithe',
#   'pokemon_type': 'Fire',
#   'special_attack': 70.0,
#   'special_defense': 50.0,
#   'speed': 60.0,
#   'total': 350.0},
#  60.0: {'attack': 110.0,
#   'defense': 80.0,
#   'hp': 90.0,
#   'name': 'Arcanine',
#   'pokemon_type': 'Fire',
#   'special_attack': 100.0,
#   'special_defense': 80.0,
#   'speed': 95.0,
#   'total': 555.0},
#  61.0: {'attack': 50.0,
#   'defense': 40.0,
#   'hp': 40.0,
#   'name': 'Poliwag',
#   'pokemon_type': 'Water',
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 90.0,
#   'total': 300.0},
#  62.0: {'attack': 65.0,
#   'defense': 65.0,
#   'hp': 65.0,
#   'name': 'Poliwhirl',
#   'pokemon_type': 'Water',
#   'special_attack': 50.0,
#   'special_defense': 50.0,
#   'speed': 90.0,
#   'total': 385.0},
#  63.0: {'attack': 95.0,
#   'defense': 95.0,
#   'hp': 90.0,
#   'name': 'Poliwrath',
#   'pokemon_type': 'WaterFighting',
#   'special_attack': 70.0,
#   'special_defense': 90.0,
#   'speed': 70.0,
#   'total': 510.0},
#  64.0: {'attack': 20.0,
#   'defense': 15.0,
#   'hp': 25.0,
#   'name': 'Abra',
#   'pokemon_type': 'Psychic',
#   'special_attack': 105.0,
#   'special_defense': 55.0,
#   'speed': 90.0,
#   'total': 310.0},
#  65.0: {'attack': 35.0,
#   'defense': 30.0,
#   'hp': 40.0,
#   'name': 'Kadabra',
#   'pokemon_type': 'Psychic',
#   'special_attack': 120.0,
#   'special_defense': 70.0,
#   'speed': 105.0,
#   'total': 400.0},
#  65.1: {'attack': 50.0,
#   'defense': 45.0,
#   'hp': 55.0,
#   'name': 'Alakazam',
#   'pokemon_type': 'Psychic',
#   'special_attack': 135.0,
#   'special_defense': 95.0,
#   'speed': 120.0,
#   'total': 500.0},
#  66.0: {'attack': 50.0,
#   'defense': 65.0,
#   'hp': 55.0,
#   'name': 'AlakazamMega Alakazam',
#   'pokemon_type': 'Psychic',
#   'special_attack': 175.0,
#   'special_defense': 95.0,
#   'speed': 150.0,
#   'total': 590.0},
#  67.0: {'attack': 80.0,
#   'defense': 50.0,
#   'hp': 70.0,
#   'name': 'Machop',
#   'pokemon_type': 'Fighting',
#   'special_attack': 35.0,
#   'special_defense': 35.0,
#   'speed': 35.0,
#   'total': 305.0},
#  68.0: {'attack': 100.0,
#   'defense': 70.0,
#   'hp': 80.0,
#   'name': 'Machoke',
#   'pokemon_type': 'Fighting',
#   'special_attack': 50.0,
#   'special_defense': 60.0,
#   'speed': 45.0,
#   'total': 405.0},
#  69.0: {'attack': 130.0,
#   'defense': 80.0,
#   'hp': 90.0,
#   'name': 'Machamp',
#   'pokemon_type': 'Fighting',
#   'special_attack': 65.0,
#   'special_defense': 85.0,
#   'speed': 55.0,
#   'total': 505.0},
#  70.0: {'attack': 75.0,
#   'defense': 35.0,
#   'hp': 50.0,
#   'name': 'Bellsprout',
#   'pokemon_type': 'GrassPoison',
#   'special_attack': 70.0,
#   'special_defense': 30.0,
#   'speed': 40.0,
#   'total': 300.0},
#  71.0: {'attack': 90.0,
#   'defense': 50.0,
#   'hp': 65.0,
#   'name': 'Weepinbell',
#   'pokemon_type': 'GrassPoison',
#   'special_attack': 85.0,
#   'special_defense': 45.0,
#   'speed': 55.0,
#   'total': 390.0},
#  72.0: {'attack': 105.0,
#   'defense': 65.0,
#   'hp': 80.0,
#   'name': 'Victreebel',
#   'pokemon_type': 'GrassPoison',
#   'special_attack': 100.0,
#   'special_defense': 70.0,
#   'speed': 70.0,
#   'total': 490.0},
#  73.0: {'attack': 40.0,
#   'defense': 35.0,
#   'hp': 40.0,
#   'name': 'Tentacool',
#   'pokemon_type': 'WaterPoison',
#   'special_attack': 50.0,
#   'special_defense': 100.0,
#   'speed': 70.0,
#   'total': 335.0},
#  74.0: {'attack': 70.0,
#   'defense': 65.0,
#   'hp': 80.0,
#   'name': 'Tentacruel',
#   'pokemon_type': 'WaterPoison',
#   'special_attack': 80.0,
#   'special_defense': 120.0,
#   'speed': 100.0,
#   'total': 515.0},
#  75.0: {'attack': 80.0,
#   'defense': 100.0,
#   'hp': 40.0,
#   'name': 'Geodude',
#   'pokemon_type': 'RockGround',
#   'special_attack': 30.0,
#   'special_defense': 30.0,
#   'speed': 20.0,
#   'total': 300.0},
#  76.0: {'attack': 95.0,
#   'defense': 115.0,
#   'hp': 55.0,
#   'name': 'Graveler',
#   'pokemon_type': 'RockGround',
#   'special_attack': 45.0,
#   'special_defense': 45.0,
#   'speed': 35.0,
#   'total': 390.0},
#  77.0: {'attack': 120.0,
#   'defense': 130.0,
#   'hp': 80.0,
#   'name': 'Golem',
#   'pokemon_type': 'RockGround',
#   'special_attack': 55.0,
#   'special_defense': 65.0,
#   'speed': 45.0,
#   'total': 495.0},
#  78.0: {'attack': 85.0,
#   'defense': 55.0,
#   'hp': 50.0,
#   'name': 'Ponyta',
#   'pokemon_type': 'Fire',
#   'special_attack': 65.0,
#   'special_defense': 65.0,
#   'speed': 90.0,
#   'total': 410.0},
#  79.0: {'attack': 100.0,
#   'defense': 70.0,
#   'hp': 65.0,
#   'name': 'Rapidash',
#   'pokemon_type': 'Fire',
#   'special_attack': 80.0,
#   'special_defense': 80.0,
#   'speed': 105.0,
#   'total': 500.0},
#  80.0: {'attack': 65.0,
#   'defense': 65.0,
#   'hp': 90.0,
#   'name': 'Slowpoke',
#   'pokemon_type': 'WaterPsychic',
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 15.0,
#   'total': 315.0},
#  80.1: {'attack': 75.0,
#   'defense': 110.0,
#   'hp': 95.0,
#   'name': 'Slowbro',
#   'pokemon_type': 'WaterPsychic',
#   'special_attack': 100.0,
#   'special_defense': 80.0,
#   'speed': 30.0,
#   'total': 490.0},
#  81.0: {'attack': 75.0,
#   'defense': 180.0,
#   'hp': 95.0,
#   'name': 'SlowbroMega Slowbro',
#   'pokemon_type': 'WaterPsychic',
#   'special_attack': 130.0,
#   'special_defense': 80.0,
#   'speed': 30.0,
#   'total': 590.0},
#  82.0: {'attack': 35.0,
#   'defense': 70.0,
#   'hp': 25.0,
#   'name': 'Magnemite',
#   'pokemon_type': 'ElectricSteel',
#   'special_attack': 95.0,
#   'special_defense': 55.0,
#   'speed': 45.0,
#   'total': 325.0},
#  83.0: {'attack': 60.0,
#   'defense': 95.0,
#   'hp': 50.0,
#   'name': 'Magneton',
#   'pokemon_type': 'ElectricSteel',
#   'special_attack': 120.0,
#   'special_defense': 70.0,
#   'speed': 70.0,
#   'total': 465.0},
#  84.0: {'attack': 65.0,
#   'defense': 55.0,
#   'hp': 52.0,
#   'name': "Farfetch'd",
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 58.0,
#   'special_defense': 62.0,
#   'speed': 60.0,
#   'total': 352.0},
#  85.0: {'attack': 85.0,
#   'defense': 45.0,
#   'hp': 35.0,
#   'name': 'Doduo',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 35.0,
#   'special_defense': 35.0,
#   'speed': 75.0,
#   'total': 310.0},
#  86.0: {'attack': 110.0,
#   'defense': 70.0,
#   'hp': 60.0,
#   'name': 'Dodrio',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 60.0,
#   'special_defense': 60.0,
#   'speed': 100.0,
#   'total': 460.0},
#  87.0: {'attack': 45.0,
#   'defense': 55.0,
#   'hp': 65.0,
#   'name': 'Seel',
#   'pokemon_type': 'Water',
#   'special_attack': 45.0,
#   'special_defense': 70.0,
#   'speed': 45.0,
#   'total': 325.0},
#  88.0: {'attack': 70.0,
#   'defense': 80.0,
#   'hp': 90.0,
#   'name': 'Dewgong',
#   'pokemon_type': 'WaterIce',
#   'special_attack': 70.0,
#   'special_defense': 95.0,
#   'speed': 70.0,
#   'total': 475.0},
#  89.0: {'attack': 80.0,
#   'defense': 50.0,
#   'hp': 80.0,
#   'name': 'Grimer',
#   'pokemon_type': 'Poison',
#   'special_attack': 40.0,
#   'special_defense': 50.0,
#   'speed': 25.0,
#   'total': 325.0},
#  90.0: {'attack': 105.0,
#   'defense': 75.0,
#   'hp': 105.0,
#   'name': 'Muk',
#   'pokemon_type': 'Poison',
#   'special_attack': 65.0,
#   'special_defense': 100.0,
#   'speed': 50.0,
#   'total': 500.0},
#  91.0: {'attack': 65.0,
#   'defense': 100.0,
#   'hp': 30.0,
#   'name': 'Shellder',
#   'pokemon_type': 'Water',
#   'special_attack': 45.0,
#   'special_defense': 25.0,
#   'speed': 40.0,
#   'total': 305.0},
#  92.0: {'attack': 95.0,
#   'defense': 180.0,
#   'hp': 50.0,
#   'name': 'Cloyster',
#   'pokemon_type': 'WaterIce',
#   'special_attack': 85.0,
#   'special_defense': 45.0,
#   'speed': 70.0,
#   'total': 525.0},
#  93.0: {'attack': 35.0,
#   'defense': 30.0,
#   'hp': 30.0,
#   'name': 'Gastly',
#   'pokemon_type': 'GhostPoison',
#   'special_attack': 100.0,
#   'special_defense': 35.0,
#   'speed': 80.0,
#   'total': 310.0},
#  94.0: {'attack': 50.0,
#   'defense': 45.0,
#   'hp': 45.0,
#   'name': 'Haunter',
#   'pokemon_type': 'GhostPoison',
#   'special_attack': 115.0,
#   'special_defense': 55.0,
#   'speed': 95.0,
#   'total': 405.0},
#  94.1: {'attack': 65.0,
#   'defense': 60.0,
#   'hp': 60.0,
#   'name': 'Gengar',
#   'pokemon_type': 'GhostPoison',
#   'special_attack': 130.0,
#   'special_defense': 75.0,
#   'speed': 110.0,
#   'total': 500.0},
#  95.0: {'attack': 65.0,
#   'defense': 80.0,
#   'hp': 60.0,
#   'name': 'GengarMega Gengar',
#   'pokemon_type': 'GhostPoison',
#   'special_attack': 170.0,
#   'special_defense': 95.0,
#   'speed': 130.0,
#   'total': 600.0},
#  96.0: {'attack': 45.0,
#   'defense': 160.0,
#   'hp': 35.0,
#   'name': 'Onix',
#   'pokemon_type': 'RockGround',
#   'special_attack': 30.0,
#   'special_defense': 45.0,
#   'speed': 70.0,
#   'total': 385.0},
#  97.0: {'attack': 48.0,
#   'defense': 45.0,
#   'hp': 60.0,
#   'name': 'Drowzee',
#   'pokemon_type': 'Psychic',
#   'special_attack': 43.0,
#   'special_defense': 90.0,
#   'speed': 42.0,
#   'total': 328.0},
#  98.0: {'attack': 73.0,
#   'defense': 70.0,
#   'hp': 85.0,
#   'name': 'Hypno',
#   'pokemon_type': 'Psychic',
#   'special_attack': 73.0,
#   'special_defense': 115.0,
#   'speed': 67.0,
#   'total': 483.0},
#  99.0: {'attack': 105.0,
#   'defense': 90.0,
#   'hp': 30.0,
#   'name': 'Krabby',
#   'pokemon_type': 'Water',
#   'special_attack': 25.0,
#   'special_defense': 25.0,
#   'speed': 50.0,
#   'total': 325.0},
#  100.0: {'attack': 130.0,
#   'defense': 115.0,
#   'hp': 55.0,
#   'name': 'Kingler',
#   'pokemon_type': 'Water',
#   'special_attack': 50.0,
#   'special_defense': 50.0,
#   'speed': 75.0,
#   'total': 475.0},
#  101.0: {'attack': 30.0,
#   'defense': 50.0,
#   'hp': 40.0,
#   'name': 'Voltorb',
#   'pokemon_type': 'Electric',
#   'special_attack': 55.0,
#   'special_defense': 55.0,
#   'speed': 100.0,
#   'total': 330.0},
#  102.0: {'attack': 50.0,
#   'defense': 70.0,
#   'hp': 60.0,
#   'name': 'Electrode',
#   'pokemon_type': 'Electric',
#   'special_attack': 80.0,
#   'special_defense': 80.0,
#   'speed': 140.0,
#   'total': 480.0},
#  103.0: {'attack': 40.0,
#   'defense': 80.0,
#   'hp': 60.0,
#   'name': 'Exeggcute',
#   'pokemon_type': 'GrassPsychic',
#   'special_attack': 60.0,
#   'special_defense': 45.0,
#   'speed': 40.0,
#   'total': 325.0},
#  104.0: {'attack': 95.0,
#   'defense': 85.0,
#   'hp': 95.0,
#   'name': 'Exeggutor',
#   'pokemon_type': 'GrassPsychic',
#   'special_attack': 125.0,
#   'special_defense': 65.0,
#   'speed': 55.0,
#   'total': 520.0},
#  105.0: {'attack': 50.0,
#   'defense': 95.0,
#   'hp': 50.0,
#   'name': 'Cubone',
#   'pokemon_type': 'Ground',
#   'special_attack': 40.0,
#   'special_defense': 50.0,
#   'speed': 35.0,
#   'total': 320.0},
#  106.0: {'attack': 80.0,
#   'defense': 110.0,
#   'hp': 60.0,
#   'name': 'Marowak',
#   'pokemon_type': 'Ground',
#   'special_attack': 50.0,
#   'special_defense': 80.0,
#   'speed': 45.0,
#   'total': 425.0},
#  107.0: {'attack': 120.0,
#   'defense': 53.0,
#   'hp': 50.0,
#   'name': 'Hitmonlee',
#   'pokemon_type': 'Fighting',
#   'special_attack': 35.0,
#   'special_defense': 110.0,
#   'speed': 87.0,
#   'total': 455.0},
#  108.0: {'attack': 105.0,
#   'defense': 79.0,
#   'hp': 50.0,
#   'name': 'Hitmonchan',
#   'pokemon_type': 'Fighting',
#   'special_attack': 35.0,
#   'special_defense': 110.0,
#   'speed': 76.0,
#   'total': 455.0},
#  109.0: {'attack': 55.0,
#   'defense': 75.0,
#   'hp': 90.0,
#   'name': 'Lickitung',
#   'pokemon_type': 'Normal',
#   'special_attack': 60.0,
#   'special_defense': 75.0,
#   'speed': 30.0,
#   'total': 385.0},
#  110.0: {'attack': 65.0,
#   'defense': 95.0,
#   'hp': 40.0,
#   'name': 'Koffing',
#   'pokemon_type': 'Poison',
#   'special_attack': 60.0,
#   'special_defense': 45.0,
#   'speed': 35.0,
#   'total': 340.0},
#  111.0: {'attack': 90.0,
#   'defense': 120.0,
#   'hp': 65.0,
#   'name': 'Weezing',
#   'pokemon_type': 'Poison',
#   'special_attack': 85.0,
#   'special_defense': 70.0,
#   'speed': 60.0,
#   'total': 490.0},
#  112.0: {'attack': 85.0,
#   'defense': 95.0,
#   'hp': 80.0,
#   'name': 'Rhyhorn',
#   'pokemon_type': 'GroundRock',
#   'special_attack': 30.0,
#   'special_defense': 30.0,
#   'speed': 25.0,
#   'total': 345.0},
#  113.0: {'attack': 130.0,
#   'defense': 120.0,
#   'hp': 105.0,
#   'name': 'Rhydon',
#   'pokemon_type': 'GroundRock',
#   'special_attack': 45.0,
#   'special_defense': 45.0,
#   'speed': 40.0,
#   'total': 485.0},
#  114.0: {'attack': 5.0,
#   'defense': 5.0,
#   'hp': 250.0,
#   'name': 'Chansey',
#   'pokemon_type': 'Normal',
#   'special_attack': 35.0,
#   'special_defense': 105.0,
#   'speed': 50.0,
#   'total': 450.0},
#  115.0: {'attack': 55.0,
#   'defense': 115.0,
#   'hp': 65.0,
#   'name': 'Tangela',
#   'pokemon_type': 'Grass',
#   'special_attack': 100.0,
#   'special_defense': 40.0,
#   'speed': 60.0,
#   'total': 435.0},
#  115.1: {'attack': 95.0,
#   'defense': 80.0,
#   'hp': 105.0,
#   'name': 'Kangaskhan',
#   'pokemon_type': 'Normal',
#   'special_attack': 40.0,
#   'special_defense': 80.0,
#   'speed': 90.0,
#   'total': 490.0},
#  116.0: {'attack': 125.0,
#   'defense': 100.0,
#   'hp': 105.0,
#   'name': 'KangaskhanMega Kangaskhan',
#   'pokemon_type': 'Normal',
#   'special_attack': 60.0,
#   'special_defense': 100.0,
#   'speed': 100.0,
#   'total': 590.0},
#  117.0: {'attack': 40.0,
#   'defense': 70.0,
#   'hp': 30.0,
#   'name': 'Horsea',
#   'pokemon_type': 'Water',
#   'special_attack': 70.0,
#   'special_defense': 25.0,
#   'speed': 60.0,
#   'total': 295.0},
#  118.0: {'attack': 65.0,
#   'defense': 95.0,
#   'hp': 55.0,
#   'name': 'Seadra',
#   'pokemon_type': 'Water',
#   'special_attack': 95.0,
#   'special_defense': 45.0,
#   'speed': 85.0,
#   'total': 440.0},
#  119.0: {'attack': 67.0,
#   'defense': 60.0,
#   'hp': 45.0,
#   'name': 'Goldeen',
#   'pokemon_type': 'Water',
#   'special_attack': 35.0,
#   'special_defense': 50.0,
#   'speed': 63.0,
#   'total': 320.0},
#  120.0: {'attack': 92.0,
#   'defense': 65.0,
#   'hp': 80.0,
#   'name': 'Seaking',
#   'pokemon_type': 'Water',
#   'special_attack': 65.0,
#   'special_defense': 80.0,
#   'speed': 68.0,
#   'total': 450.0},
#  121.0: {'attack': 45.0,
#   'defense': 55.0,
#   'hp': 30.0,
#   'name': 'Staryu',
#   'pokemon_type': 'Water',
#   'special_attack': 70.0,
#   'special_defense': 55.0,
#   'speed': 85.0,
#   'total': 340.0},
#  122.0: {'attack': 75.0,
#   'defense': 85.0,
#   'hp': 60.0,
#   'name': 'Starmie',
#   'pokemon_type': 'WaterPsychic',
#   'special_attack': 100.0,
#   'special_defense': 85.0,
#   'speed': 115.0,
#   'total': 520.0},
#  123.0: {'attack': 45.0,
#   'defense': 65.0,
#   'hp': 40.0,
#   'name': 'Mr. Mime',
#   'pokemon_type': 'PsychicFairy',
#   'special_attack': 100.0,
#   'special_defense': 120.0,
#   'speed': 90.0,
#   'total': 460.0},
#  124.0: {'attack': 110.0,
#   'defense': 80.0,
#   'hp': 70.0,
#   'name': 'Scyther',
#   'pokemon_type': 'BugFlying',
#   'special_attack': 55.0,
#   'special_defense': 80.0,
#   'speed': 105.0,
#   'total': 500.0},
#  125.0: {'attack': 50.0,
#   'defense': 35.0,
#   'hp': 65.0,
#   'name': 'Jynx',
#   'pokemon_type': 'IcePsychic',
#   'special_attack': 115.0,
#   'special_defense': 95.0,
#   'speed': 95.0,
#   'total': 455.0},
#  126.0: {'attack': 83.0,
#   'defense': 57.0,
#   'hp': 65.0,
#   'name': 'Electabuzz',
#   'pokemon_type': 'Electric',
#   'special_attack': 95.0,
#   'special_defense': 85.0,
#   'speed': 105.0,
#   'total': 490.0},
#  127.0: {'attack': 95.0,
#   'defense': 57.0,
#   'hp': 65.0,
#   'name': 'Magmar',
#   'pokemon_type': 'Fire',
#   'special_attack': 100.0,
#   'special_defense': 85.0,
#   'speed': 93.0,
#   'total': 495.0},
#  127.1: {'attack': 125.0,
#   'defense': 100.0,
#   'hp': 65.0,
#   'name': 'Pinsir',
#   'pokemon_type': 'Bug',
#   'special_attack': 55.0,
#   'special_defense': 70.0,
#   'speed': 85.0,
#   'total': 500.0},
#  128.0: {'attack': 155.0,
#   'defense': 120.0,
#   'hp': 65.0,
#   'name': 'PinsirMega Pinsir',
#   'pokemon_type': 'BugFlying',
#   'special_attack': 65.0,
#   'special_defense': 90.0,
#   'speed': 105.0,
#   'total': 600.0},
#  129.0: {'attack': 100.0,
#   'defense': 95.0,
#   'hp': 75.0,
#   'name': 'Tauros',
#   'pokemon_type': 'Normal',
#   'special_attack': 40.0,
#   'special_defense': 70.0,
#   'speed': 110.0,
#   'total': 490.0},
#  130.0: {'attack': 10.0,
#   'defense': 55.0,
#   'hp': 20.0,
#   'name': 'Magikarp',
#   'pokemon_type': 'Water',
#   'special_attack': 15.0,
#   'special_defense': 20.0,
#   'speed': 80.0,
#   'total': 200.0},
#  130.1: {'attack': 125.0,
#   'defense': 79.0,
#   'hp': 95.0,
#   'name': 'Gyarados',
#   'pokemon_type': 'WaterFlying',
#   'special_attack': 60.0,
#   'special_defense': 100.0,
#   'speed': 81.0,
#   'total': 540.0},
#  131.0: {'attack': 155.0,
#   'defense': 109.0,
#   'hp': 95.0,
#   'name': 'GyaradosMega Gyarados',
#   'pokemon_type': 'WaterDark',
#   'special_attack': 70.0,
#   'special_defense': 130.0,
#   'speed': 81.0,
#   'total': 640.0},
#  132.0: {'attack': 85.0,
#   'defense': 80.0,
#   'hp': 130.0,
#   'name': 'Lapras',
#   'pokemon_type': 'WaterIce',
#   'special_attack': 85.0,
#   'special_defense': 95.0,
#   'speed': 60.0,
#   'total': 535.0},
#  133.0: {'attack': 48.0,
#   'defense': 48.0,
#   'hp': 48.0,
#   'name': 'Ditto',
#   'pokemon_type': 'Normal',
#   'special_attack': 48.0,
#   'special_defense': 48.0,
#   'speed': 48.0,
#   'total': 288.0},
#  134.0: {'attack': 55.0,
#   'defense': 50.0,
#   'hp': 55.0,
#   'name': 'Eevee',
#   'pokemon_type': 'Normal',
#   'special_attack': 45.0,
#   'special_defense': 65.0,
#   'speed': 55.0,
#   'total': 325.0},
#  135.0: {'attack': 65.0,
#   'defense': 60.0,
#   'hp': 130.0,
#   'name': 'Vaporeon',
#   'pokemon_type': 'Water',
#   'special_attack': 110.0,
#   'special_defense': 95.0,
#   'speed': 65.0,
#   'total': 525.0},
#  136.0: {'attack': 65.0,
#   'defense': 60.0,
#   'hp': 65.0,
#   'name': 'Jolteon',
#   'pokemon_type': 'Electric',
#   'special_attack': 110.0,
#   'special_defense': 95.0,
#   'speed': 130.0,
#   'total': 525.0},
#  137.0: {'attack': 130.0,
#   'defense': 60.0,
#   'hp': 65.0,
#   'name': 'Flareon',
#   'pokemon_type': 'Fire',
#   'special_attack': 95.0,
#   'special_defense': 110.0,
#   'speed': 65.0,
#   'total': 525.0},
#  138.0: {'attack': 60.0,
#   'defense': 70.0,
#   'hp': 65.0,
#   'name': 'Porygon',
#   'pokemon_type': 'Normal',
#   'special_attack': 85.0,
#   'special_defense': 75.0,
#   'speed': 40.0,
#   'total': 395.0},
#  139.0: {'attack': 40.0,
#   'defense': 100.0,
#   'hp': 35.0,
#   'name': 'Omanyte',
#   'pokemon_type': 'RockWater',
#   'special_attack': 90.0,
#   'special_defense': 55.0,
#   'speed': 35.0,
#   'total': 355.0},
#  140.0: {'attack': 60.0,
#   'defense': 125.0,
#   'hp': 70.0,
#   'name': 'Omastar',
#   'pokemon_type': 'RockWater',
#   'special_attack': 115.0,
#   'special_defense': 70.0,
#   'speed': 55.0,
#   'total': 495.0},
#  141.0: {'attack': 80.0,
#   'defense': 90.0,
#   'hp': 30.0,
#   'name': 'Kabuto',
#   'pokemon_type': 'RockWater',
#   'special_attack': 55.0,
#   'special_defense': 45.0,
#   'speed': 55.0,
#   'total': 355.0},
#  142.0: {'attack': 115.0,
#   'defense': 105.0,
#   'hp': 60.0,
#   'name': 'Kabutops',
#   'pokemon_type': 'RockWater',
#   'special_attack': 65.0,
#   'special_defense': 70.0,
#   'speed': 80.0,
#   'total': 495.0},
#  142.1: {'attack': 105.0,
#   'defense': 65.0,
#   'hp': 80.0,
#   'name': 'Aerodactyl',
#   'pokemon_type': 'RockFlying',
#   'special_attack': 60.0,
#   'special_defense': 75.0,
#   'speed': 130.0,
#   'total': 515.0},
#  143.0: {'attack': 135.0,
#   'defense': 85.0,
#   'hp': 80.0,
#   'name': 'AerodactylMega Aerodactyl',
#   'pokemon_type': 'RockFlying',
#   'special_attack': 70.0,
#   'special_defense': 95.0,
#   'speed': 150.0,
#   'total': 615.0},
#  144.0: {'attack': 110.0,
#   'defense': 65.0,
#   'hp': 160.0,
#   'name': 'Snorlax',
#   'pokemon_type': 'Normal',
#   'special_attack': 65.0,
#   'special_defense': 110.0,
#   'speed': 30.0,
#   'total': 540.0},
#  145.0: {'attack': 85.0,
#   'defense': 100.0,
#   'hp': 90.0,
#   'name': 'Articuno',
#   'pokemon_type': 'IceFlying',
#   'special_attack': 95.0,
#   'special_defense': 125.0,
#   'speed': 85.0,
#   'total': 580.0},
#  146.0: {'attack': 90.0,
#   'defense': 85.0,
#   'hp': 90.0,
#   'name': 'Zapdos',
#   'pokemon_type': 'ElectricFlying',
#   'special_attack': 125.0,
#   'special_defense': 90.0,
#   'speed': 100.0,
#   'total': 580.0},
#  147.0: {'attack': 100.0,
#   'defense': 90.0,
#   'hp': 90.0,
#   'name': 'Moltres',
#   'pokemon_type': 'FireFlying',
#   'special_attack': 125.0,
#   'special_defense': 85.0,
#   'speed': 90.0,
#   'total': 580.0},
#  148.0: {'attack': 64.0,
#   'defense': 45.0,
#   'hp': 41.0,
#   'name': 'Dratini',
#   'pokemon_type': 'Dragon',
#   'special_attack': 50.0,
#   'special_defense': 50.0,
#   'speed': 50.0,
#   'total': 300.0},
#  149.0: {'attack': 84.0,
#   'defense': 65.0,
#   'hp': 61.0,
#   'name': 'Dragonair',
#   'pokemon_type': 'Dragon',
#   'special_attack': 70.0,
#   'special_defense': 70.0,
#   'speed': 70.0,
#   'total': 420.0},
#  150.0: {'attack': 134.0,
#   'defense': 95.0,
#   'hp': 91.0,
#   'name': 'Dragonite',
#   'pokemon_type': 'DragonFlying',
#   'special_attack': 100.0,
#   'special_defense': 100.0,
#   'speed': 80.0,
#   'total': 600.0},
#  150.1: {'attack': 110.0,
#   'defense': 90.0,
#   'hp': 106.0,
#   'name': 'Mewtwo',
#   'pokemon_type': 'Psychic',
#   'special_attack': 154.0,
#   'special_defense': 90.0,
#   'speed': 130.0,
#   'total': 680.0},
#  150.2: {'attack': 190.0,
#   'defense': 100.0,
#   'hp': 126.0,
#   'name': 'MewtwoMega Mewtwo X',
#   'pokemon_type': 'PsychicFighting',
#   'special_attack': 154.0,
#   'special_defense': 100.0,
#   'speed': 130.0,
#   'total': 800.0},
#  151.0: {'attack': 150.0,
#   'defense': 70.0,
#   'hp': 106.0,
#   'name': 'MewtwoMega Mewtwo Y',
#   'pokemon_type': 'Psychic',
#   'special_attack': 194.0,
#   'special_defense': 120.0,
#   'speed': 140.0,
#   'total': 780.0},
#  152.0: {'attack': 100.0,
#   'defense': 100.0,
#   'hp': 100.0,
#   'name': 'Mew',
#   'pokemon_type': 'Psychic',
#   'special_attack': 100.0,
#   'special_defense': 100.0,
#   'speed': 100.0,
#   'total': 600.0},
#  153.0: {'attack': 49.0,
#   'defense': 65.0,
#   'hp': 45.0,
#   'name': 'Chikorita',
#   'pokemon_type': 'Grass',
#   'special_attack': 49.0,
#   'special_defense': 65.0,
#   'speed': 45.0,
#   'total': 318.0},
#  154.0: {'attack': 62.0,
#   'defense': 80.0,
#   'hp': 60.0,
#   'name': 'Bayleef',
#   'pokemon_type': 'Grass',
#   'special_attack': 63.0,
#   'special_defense': 80.0,
#   'speed': 60.0,
#   'total': 405.0},
#  155.0: {'attack': 82.0,
#   'defense': 100.0,
#   'hp': 80.0,
#   'name': 'Meganium',
#   'pokemon_type': 'Grass',
#   'special_attack': 83.0,
#   'special_defense': 100.0,
#   'speed': 80.0,
#   'total': 525.0},
#  156.0: {'attack': 52.0,
#   'defense': 43.0,
#   'hp': 39.0,
#   'name': 'Cyndaquil',
#   'pokemon_type': 'Fire',
#   'special_attack': 60.0,
#   'special_defense': 50.0,
#   'speed': 65.0,
#   'total': 309.0},
#  157.0: {'attack': 64.0,
#   'defense': 58.0,
#   'hp': 58.0,
#   'name': 'Quilava',
#   'pokemon_type': 'Fire',
#   'special_attack': 80.0,
#   'special_defense': 65.0,
#   'speed': 80.0,
#   'total': 405.0},
#  158.0: {'attack': 84.0,
#   'defense': 78.0,
#   'hp': 78.0,
#   'name': 'Typhlosion',
#   'pokemon_type': 'Fire',
#   'special_attack': 109.0,
#   'special_defense': 85.0,
#   'speed': 100.0,
#   'total': 534.0},
#  159.0: {'attack': 65.0,
#   'defense': 64.0,
#   'hp': 50.0,
#   'name': 'Totodile',
#   'pokemon_type': 'Water',
#   'special_attack': 44.0,
#   'special_defense': 48.0,
#   'speed': 43.0,
#   'total': 314.0},
#  160.0: {'attack': 80.0,
#   'defense': 80.0,
#   'hp': 65.0,
#   'name': 'Croconaw',
#   'pokemon_type': 'Water',
#   'special_attack': 59.0,
#   'special_defense': 63.0,
#   'speed': 58.0,
#   'total': 405.0},
#  161.0: {'attack': 105.0,
#   'defense': 100.0,
#   'hp': 85.0,
#   'name': 'Feraligatr',
#   'pokemon_type': 'Water',
#   'special_attack': 79.0,
#   'special_defense': 83.0,
#   'speed': 78.0,
#   'total': 530.0},
#  162.0: {'attack': 46.0,
#   'defense': 34.0,
#   'hp': 35.0,
#   'name': 'Sentret',
#   'pokemon_type': 'Normal',
#   'special_attack': 35.0,
#   'special_defense': 45.0,
#   'speed': 20.0,
#   'total': 215.0},
#  163.0: {'attack': 76.0,
#   'defense': 64.0,
#   'hp': 85.0,
#   'name': 'Furret',
#   'pokemon_type': 'Normal',
#   'special_attack': 45.0,
#   'special_defense': 55.0,
#   'speed': 90.0,
#   'total': 415.0},
#  164.0: {'attack': 30.0,
#   'defense': 30.0,
#   'hp': 60.0,
#   'name': 'Hoothoot',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 36.0,
#   'special_defense': 56.0,
#   'speed': 50.0,
#   'total': 262.0},
#  165.0: {'attack': 50.0,
#   'defense': 50.0,
#   'hp': 100.0,
#   'name': 'Noctowl',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 76.0,
#   'special_defense': 96.0,
#   'speed': 70.0,
#   'total': 442.0},
#  166.0: {'attack': 20.0,
#   'defense': 30.0,
#   'hp': 40.0,
#   'name': 'Ledyba',
#   'pokemon_type': 'BugFlying',
#   'special_attack': 40.0,
#   'special_defense': 80.0,
#   'speed': 55.0,
#   'total': 265.0},
#  167.0: {'attack': 35.0,
#   'defense': 50.0,
#   'hp': 55.0,
#   'name': 'Ledian',
#   'pokemon_type': 'BugFlying',
#   'special_attack': 55.0,
#   'special_defense': 110.0,
#   'speed': 85.0,
#   'total': 390.0},
#  168.0: {'attack': 60.0,
#   'defense': 40.0,
#   'hp': 40.0,
#   'name': 'Spinarak',
#   'pokemon_type': 'BugPoison',
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 30.0,
#   'total': 250.0},
#  169.0: {'attack': 90.0,
#   'defense': 70.0,
#   'hp': 70.0,
#   'name': 'Ariados',
#   'pokemon_type': 'BugPoison',
#   'special_attack': 60.0,
#   'special_defense': 60.0,
#   'speed': 40.0,
#   'total': 390.0},
#  170.0: {'attack': 90.0,
#   'defense': 80.0,
#   'hp': 85.0,
#   'name': 'Crobat',
#   'pokemon_type': 'PoisonFlying',
#   'special_attack': 70.0,
#   'special_defense': 80.0,
#   'speed': 130.0,
#   'total': 535.0},
#  171.0: {'attack': 38.0,
#   'defense': 38.0,
#   'hp': 75.0,
#   'name': 'Chinchou',
#   'pokemon_type': 'WaterElectric',
#   'special_attack': 56.0,
#   'special_defense': 56.0,
#   'speed': 67.0,
#   'total': 330.0},
#  172.0: {'attack': 58.0,
#   'defense': 58.0,
#   'hp': 125.0,
#   'name': 'Lanturn',
#   'pokemon_type': 'WaterElectric',
#   'special_attack': 76.0,
#   'special_defense': 76.0,
#   'speed': 67.0,
#   'total': 460.0},
#  173.0: {'attack': 40.0,
#   'defense': 15.0,
#   'hp': 20.0,
#   'name': 'Pichu',
#   'pokemon_type': 'Electric',
#   'special_attack': 35.0,
#   'special_defense': 35.0,
#   'speed': 60.0,
#   'total': 205.0},
#  174.0: {'attack': 25.0,
#   'defense': 28.0,
#   'hp': 50.0,
#   'name': 'Cleffa',
#   'pokemon_type': 'Fairy',
#   'special_attack': 45.0,
#   'special_defense': 55.0,
#   'speed': 15.0,
#   'total': 218.0},
#  175.0: {'attack': 30.0,
#   'defense': 15.0,
#   'hp': 90.0,
#   'name': 'Igglybuff',
#   'pokemon_type': 'NormalFairy',
#   'special_attack': 40.0,
#   'special_defense': 20.0,
#   'speed': 15.0,
#   'total': 210.0},
#  176.0: {'attack': 20.0,
#   'defense': 65.0,
#   'hp': 35.0,
#   'name': 'Togepi',
#   'pokemon_type': 'Fairy',
#   'special_attack': 40.0,
#   'special_defense': 65.0,
#   'speed': 20.0,
#   'total': 245.0},
#  177.0: {'attack': 40.0,
#   'defense': 85.0,
#   'hp': 55.0,
#   'name': 'Togetic',
#   'pokemon_type': 'FairyFlying',
#   'special_attack': 80.0,
#   'special_defense': 105.0,
#   'speed': 40.0,
#   'total': 405.0},
#  178.0: {'attack': 50.0,
#   'defense': 45.0,
#   'hp': 40.0,
#   'name': 'Natu',
#   'pokemon_type': 'PsychicFlying',
#   'special_attack': 70.0,
#   'special_defense': 45.0,
#   'speed': 70.0,
#   'total': 320.0},
#  179.0: {'attack': 75.0,
#   'defense': 70.0,
#   'hp': 65.0,
#   'name': 'Xatu',
#   'pokemon_type': 'PsychicFlying',
#   'special_attack': 95.0,
#   'special_defense': 70.0,
#   'speed': 95.0,
#   'total': 470.0},
#  180.0: {'attack': 40.0,
#   'defense': 40.0,
#   'hp': 55.0,
#   'name': 'Mareep',
#   'pokemon_type': 'Electric',
#   'special_attack': 65.0,
#   'special_defense': 45.0,
#   'speed': 35.0,
#   'total': 280.0},
#  181.0: {'attack': 55.0,
#   'defense': 55.0,
#   'hp': 70.0,
#   'name': 'Flaaffy',
#   'pokemon_type': 'Electric',
#   'special_attack': 80.0,
#   'special_defense': 60.0,
#   'speed': 45.0,
#   'total': 365.0},
#  181.1: {'attack': 75.0,
#   'defense': 85.0,
#   'hp': 90.0,
#   'name': 'Ampharos',
#   'pokemon_type': 'Electric',
#   'special_attack': 115.0,
#   'special_defense': 90.0,
#   'speed': 55.0,
#   'total': 510.0},
#  182.0: {'attack': 95.0,
#   'defense': 105.0,
#   'hp': 90.0,
#   'name': 'AmpharosMega Ampharos',
#   'pokemon_type': 'ElectricDragon',
#   'special_attack': 165.0,
#   'special_defense': 110.0,
#   'speed': 45.0,
#   'total': 610.0},
#  183.0: {'attack': 80.0,
#   'defense': 95.0,
#   'hp': 75.0,
#   'name': 'Bellossom',
#   'pokemon_type': 'Grass',
#   'special_attack': 90.0,
#   'special_defense': 100.0,
#   'speed': 50.0,
#   'total': 490.0},
#  184.0: {'attack': 20.0,
#   'defense': 50.0,
#   'hp': 70.0,
#   'name': 'Marill',
#   'pokemon_type': 'WaterFairy',
#   'special_attack': 20.0,
#   'special_defense': 50.0,
#   'speed': 40.0,
#   'total': 250.0},
#  185.0: {'attack': 50.0,
#   'defense': 80.0,
#   'hp': 100.0,
#   'name': 'Azumarill',
#   'pokemon_type': 'WaterFairy',
#   'special_attack': 60.0,
#   'special_defense': 80.0,
#   'speed': 50.0,
#   'total': 420.0},
#  186.0: {'attack': 100.0,
#   'defense': 115.0,
#   'hp': 70.0,
#   'name': 'Sudowoodo',
#   'pokemon_type': 'Rock',
#   'special_attack': 30.0,
#   'special_defense': 65.0,
#   'speed': 30.0,
#   'total': 410.0},
#  187.0: {'attack': 75.0,
#   'defense': 75.0,
#   'hp': 90.0,
#   'name': 'Politoed',
#   'pokemon_type': 'Water',
#   'special_attack': 90.0,
#   'special_defense': 100.0,
#   'speed': 70.0,
#   'total': 500.0},
#  188.0: {'attack': 35.0,
#   'defense': 40.0,
#   'hp': 35.0,
#   'name': 'Hoppip',
#   'pokemon_type': 'GrassFlying',
#   'special_attack': 35.0,
#   'special_defense': 55.0,
#   'speed': 50.0,
#   'total': 250.0},
#  189.0: {'attack': 45.0,
#   'defense': 50.0,
#   'hp': 55.0,
#   'name': 'Skiploom',
#   'pokemon_type': 'GrassFlying',
#   'special_attack': 45.0,
#   'special_defense': 65.0,
#   'speed': 80.0,
#   'total': 340.0},
#  190.0: {'attack': 55.0,
#   'defense': 70.0,
#   'hp': 75.0,
#   'name': 'Jumpluff',
#   'pokemon_type': 'GrassFlying',
#   'special_attack': 55.0,
#   'special_defense': 95.0,
#   'speed': 110.0,
#   'total': 460.0},
#  191.0: {'attack': 70.0,
#   'defense': 55.0,
#   'hp': 55.0,
#   'name': 'Aipom',
#   'pokemon_type': 'Normal',
#   'special_attack': 40.0,
#   'special_defense': 55.0,
#   'speed': 85.0,
#   'total': 360.0},
#  192.0: {'attack': 30.0,
#   'defense': 30.0,
#   'hp': 30.0,
#   'name': 'Sunkern',
#   'pokemon_type': 'Grass',
#   'special_attack': 30.0,
#   'special_defense': 30.0,
#   'speed': 30.0,
#   'total': 180.0},
#  193.0: {'attack': 75.0,
#   'defense': 55.0,
#   'hp': 75.0,
#   'name': 'Sunflora',
#   'pokemon_type': 'Grass',
#   'special_attack': 105.0,
#   'special_defense': 85.0,
#   'speed': 30.0,
#   'total': 425.0},
#  194.0: {'attack': 65.0,
#   'defense': 45.0,
#   'hp': 65.0,
#   'name': 'Yanma',
#   'pokemon_type': 'BugFlying',
#   'special_attack': 75.0,
#   'special_defense': 45.0,
#   'speed': 95.0,
#   'total': 390.0},
#  195.0: {'attack': 45.0,
#   'defense': 45.0,
#   'hp': 55.0,
#   'name': 'Wooper',
#   'pokemon_type': 'WaterGround',
#   'special_attack': 25.0,
#   'special_defense': 25.0,
#   'speed': 15.0,
#   'total': 210.0},
#  196.0: {'attack': 85.0,
#   'defense': 85.0,
#   'hp': 95.0,
#   'name': 'Quagsire',
#   'pokemon_type': 'WaterGround',
#   'special_attack': 65.0,
#   'special_defense': 65.0,
#   'speed': 35.0,
#   'total': 430.0},
#  197.0: {'attack': 65.0,
#   'defense': 60.0,
#   'hp': 65.0,
#   'name': 'Espeon',
#   'pokemon_type': 'Psychic',
#   'special_attack': 130.0,
#   'special_defense': 95.0,
#   'speed': 110.0,
#   'total': 525.0},
#  198.0: {'attack': 65.0,
#   'defense': 110.0,
#   'hp': 95.0,
#   'name': 'Umbreon',
#   'pokemon_type': 'Dark',
#   'special_attack': 60.0,
#   'special_defense': 130.0,
#   'speed': 65.0,
#   'total': 525.0},
#  199.0: {'attack': 85.0,
#   'defense': 42.0,
#   'hp': 60.0,
#   'name': 'Murkrow',
#   'pokemon_type': 'DarkFlying',
#   'special_attack': 85.0,
#   'special_defense': 42.0,
#   'speed': 91.0,
#   'total': 405.0},
#  200.0: {'attack': 75.0,
#   'defense': 80.0,
#   'hp': 95.0,
#   'name': 'Slowking',
#   'pokemon_type': 'WaterPsychic',
#   'special_attack': 100.0,
#   'special_defense': 110.0,
#   'speed': 30.0,
#   'total': 490.0},
#  201.0: {'attack': 60.0,
#   'defense': 60.0,
#   'hp': 60.0,
#   'name': 'Misdreavus',
#   'pokemon_type': 'Ghost',
#   'special_attack': 85.0,
#   'special_defense': 85.0,
#   'speed': 85.0,
#   'total': 435.0},
#  202.0: {'attack': 72.0,
#   'defense': 48.0,
#   'hp': 48.0,
#   'name': 'Unown',
#   'pokemon_type': 'Psychic',
#   'special_attack': 72.0,
#   'special_defense': 48.0,
#   'speed': 48.0,
#   'total': 336.0},
#  203.0: {'attack': 33.0,
#   'defense': 58.0,
#   'hp': 190.0,
#   'name': 'Wobbuffet',
#   'pokemon_type': 'Psychic',
#   'special_attack': 33.0,
#   'special_defense': 58.0,
#   'speed': 33.0,
#   'total': 405.0},
#  204.0: {'attack': 80.0,
#   'defense': 65.0,
#   'hp': 70.0,
#   'name': 'Girafarig',
#   'pokemon_type': 'NormalPsychic',
#   'special_attack': 90.0,
#   'special_defense': 65.0,
#   'speed': 85.0,
#   'total': 455.0},
#  205.0: {'attack': 65.0,
#   'defense': 90.0,
#   'hp': 50.0,
#   'name': 'Pineco',
#   'pokemon_type': 'Bug',
#   'special_attack': 35.0,
#   'special_defense': 35.0,
#   'speed': 15.0,
#   'total': 290.0},
#  206.0: {'attack': 90.0,
#   'defense': 140.0,
#   'hp': 75.0,
#   'name': 'Forretress',
#   'pokemon_type': 'BugSteel',
#   'special_attack': 60.0,
#   'special_defense': 60.0,
#   'speed': 40.0,
#   'total': 465.0},
#  207.0: {'attack': 70.0,
#   'defense': 70.0,
#   'hp': 100.0,
#   'name': 'Dunsparce',
#   'pokemon_type': 'Normal',
#   'special_attack': 65.0,
#   'special_defense': 65.0,
#   'speed': 45.0,
#   'total': 415.0},
#  208.0: {'attack': 75.0,
#   'defense': 105.0,
#   'hp': 65.0,
#   'name': 'Gligar',
#   'pokemon_type': 'GroundFlying',
#   'special_attack': 35.0,
#   'special_defense': 65.0,
#   'speed': 85.0,
#   'total': 430.0},
#  208.1: {'attack': 85.0,
#   'defense': 200.0,
#   'hp': 75.0,
#   'name': 'Steelix',
#   'pokemon_type': 'SteelGround',
#   'special_attack': 55.0,
#   'special_defense': 65.0,
#   'speed': 30.0,
#   'total': 510.0},
#  209.0: {'attack': 125.0,
#   'defense': 230.0,
#   'hp': 75.0,
#   'name': 'SteelixMega Steelix',
#   'pokemon_type': 'SteelGround',
#   'special_attack': 55.0,
#   'special_defense': 95.0,
#   'speed': 30.0,
#   'total': 610.0},
#  210.0: {'attack': 80.0,
#   'defense': 50.0,
#   'hp': 60.0,
#   'name': 'Snubbull',
#   'pokemon_type': 'Fairy',
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 30.0,
#   'total': 300.0},
#  211.0: {'attack': 120.0,
#   'defense': 75.0,
#   'hp': 90.0,
#   'name': 'Granbull',
#   'pokemon_type': 'Fairy',
#   'special_attack': 60.0,
#   'special_defense': 60.0,
#   'speed': 45.0,
#   'total': 450.0},
#  212.0: {'attack': 95.0,
#   'defense': 75.0,
#   'hp': 65.0,
#   'name': 'Qwilfish',
#   'pokemon_type': 'WaterPoison',
#   'special_attack': 55.0,
#   'special_defense': 55.0,
#   'speed': 85.0,
#   'total': 430.0},
#  212.1: {'attack': 130.0,
#   'defense': 100.0,
#   'hp': 70.0,
#   'name': 'Scizor',
#   'pokemon_type': 'BugSteel',
#   'special_attack': 55.0,
#   'special_defense': 80.0,
#   'speed': 65.0,
#   'total': 500.0},
#  213.0: {'attack': 150.0,
#   'defense': 140.0,
#   'hp': 70.0,
#   'name': 'ScizorMega Scizor',
#   'pokemon_type': 'BugSteel',
#   'special_attack': 65.0,
#   'special_defense': 100.0,
#   'speed': 75.0,
#   'total': 600.0},
#  214.0: {'attack': 10.0,
#   'defense': 230.0,
#   'hp': 20.0,
#   'name': 'Shuckle',
#   'pokemon_type': 'BugRock',
#   'special_attack': 10.0,
#   'special_defense': 230.0,
#   'speed': 5.0,
#   'total': 505.0},
#  214.1: {'attack': 125.0,
#   'defense': 75.0,
#   'hp': 80.0,
#   'name': 'Heracross',
#   'pokemon_type': 'BugFighting',
#   'special_attack': 40.0,
#   'special_defense': 95.0,
#   'speed': 85.0,
#   'total': 500.0},
#  215.0: {'attack': 185.0,
#   'defense': 115.0,
#   'hp': 80.0,
#   'name': 'HeracrossMega Heracross',
#   'pokemon_type': 'BugFighting',
#   'special_attack': 40.0,
#   'special_defense': 105.0,
#   'speed': 75.0,
#   'total': 600.0},
#  216.0: {'attack': 95.0,
#   'defense': 55.0,
#   'hp': 55.0,
#   'name': 'Sneasel',
#   'pokemon_type': 'DarkIce',
#   'special_attack': 35.0,
#   'special_defense': 75.0,
#   'speed': 115.0,
#   'total': 430.0},
#  217.0: {'attack': 80.0,
#   'defense': 50.0,
#   'hp': 60.0,
#   'name': 'Teddiursa',
#   'pokemon_type': 'Normal',
#   'special_attack': 50.0,
#   'special_defense': 50.0,
#   'speed': 40.0,
#   'total': 330.0},
#  218.0: {'attack': 130.0,
#   'defense': 75.0,
#   'hp': 90.0,
#   'name': 'Ursaring',
#   'pokemon_type': 'Normal',
#   'special_attack': 75.0,
#   'special_defense': 75.0,
#   'speed': 55.0,
#   'total': 500.0},
#  219.0: {'attack': 40.0,
#   'defense': 40.0,
#   'hp': 40.0,
#   'name': 'Slugma',
#   'pokemon_type': 'Fire',
#   'special_attack': 70.0,
#   'special_defense': 40.0,
#   'speed': 20.0,
#   'total': 250.0},
#  220.0: {'attack': 50.0,
#   'defense': 120.0,
#   'hp': 50.0,
#   'name': 'Magcargo',
#   'pokemon_type': 'FireRock',
#   'special_attack': 80.0,
#   'special_defense': 80.0,
#   'speed': 30.0,
#   'total': 410.0},
#  221.0: {'attack': 50.0,
#   'defense': 40.0,
#   'hp': 50.0,
#   'name': 'Swinub',
#   'pokemon_type': 'IceGround',
#   'special_attack': 30.0,
#   'special_defense': 30.0,
# ...
#  653.0: {'attack': 107.0,
#   'defense': 122.0,
#   'hp': 88.0,
#   'name': 'Chesnaught',
#   'pokemon_type': 'GrassFighting',
#   'special_attack': 74.0,
#   'special_defense': 75.0,
#   'speed': 64.0,
#   'total': 530.0},
#  654.0: {'attack': 45.0,
#   'defense': 40.0,
#   'hp': 40.0,
#   'name': 'Fennekin',
#   'pokemon_type': 'Fire',
#   'special_attack': 62.0,
#   'special_defense': 60.0,
#   'speed': 60.0,
#   'total': 307.0},
#  655.0: {'attack': 59.0,
#   'defense': 58.0,
#   'hp': 59.0,
#   'name': 'Braixen',
#   'pokemon_type': 'Fire',
#   'special_attack': 90.0,
#   'special_defense': 70.0,
#   'speed': 73.0,
#   'total': 409.0},
#  656.0: {'attack': 69.0,
#   'defense': 72.0,
#   'hp': 75.0,
#   'name': 'Delphox',
#   'pokemon_type': 'FirePsychic',
#   'special_attack': 114.0,
#   'special_defense': 100.0,
#   'speed': 104.0,
#   'total': 534.0},
#  657.0: {'attack': 56.0,
#   'defense': 40.0,
#   'hp': 41.0,
#   'name': 'Froakie',
#   'pokemon_type': 'Water',
#   'special_attack': 62.0,
#   'special_defense': 44.0,
#   'speed': 71.0,
#   'total': 314.0},
#  658.0: {'attack': 63.0,
#   'defense': 52.0,
#   'hp': 54.0,
#   'name': 'Frogadier',
#   'pokemon_type': 'Water',
#   'special_attack': 83.0,
#   'special_defense': 56.0,
#   'speed': 97.0,
#   'total': 405.0},
#  659.0: {'attack': 95.0,
#   'defense': 67.0,
#   'hp': 72.0,
#   'name': 'Greninja',
#   'pokemon_type': 'WaterDark',
#   'special_attack': 103.0,
#   'special_defense': 71.0,
#   'speed': 122.0,
#   'total': 530.0},
#  660.0: {'attack': 36.0,
#   'defense': 38.0,
#   'hp': 38.0,
#   'name': 'Bunnelby',
#   'pokemon_type': 'Normal',
#   'special_attack': 32.0,
#   'special_defense': 36.0,
#   'speed': 57.0,
#   'total': 237.0},
#  661.0: {'attack': 56.0,
#   'defense': 77.0,
#   'hp': 85.0,
#   'name': 'Diggersby',
#   'pokemon_type': 'NormalGround',
#   'special_attack': 50.0,
#   'special_defense': 77.0,
#   'speed': 78.0,
#   'total': 423.0},
#  662.0: {'attack': 50.0,
#   'defense': 43.0,
#   'hp': 45.0,
#   'name': 'Fletchling',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 40.0,
#   'special_defense': 38.0,
#   'speed': 62.0,
#   'total': 278.0},
#  663.0: {'attack': 73.0,
#   'defense': 55.0,
#   'hp': 62.0,
#   'name': 'Fletchinder',
#   'pokemon_type': 'FireFlying',
#   'special_attack': 56.0,
#   'special_defense': 52.0,
#   'speed': 84.0,
#   'total': 382.0},
#  664.0: {'attack': 81.0,
#   'defense': 71.0,
#   'hp': 78.0,
#   'name': 'Talonflame',
#   'pokemon_type': 'FireFlying',
#   'special_attack': 74.0,
#   'special_defense': 69.0,
#   'speed': 126.0,
#   'total': 499.0},
#  665.0: {'attack': 35.0,
#   'defense': 40.0,
#   'hp': 38.0,
#   'name': 'Scatterbug',
#   'pokemon_type': 'Bug',
#   'special_attack': 27.0,
#   'special_defense': 25.0,
#   'speed': 35.0,
#   'total': 200.0},
#  666.0: {'attack': 22.0,
#   'defense': 60.0,
#   'hp': 45.0,
#   'name': 'Spewpa',
#   'pokemon_type': 'Bug',
#   'special_attack': 27.0,
#   'special_defense': 30.0,
#   'speed': 29.0,
#   'total': 213.0},
#  667.0: {'attack': 52.0,
#   'defense': 50.0,
#   'hp': 80.0,
#   'name': 'Vivillon',
#   'pokemon_type': 'BugFlying',
#   'special_attack': 90.0,
#   'special_defense': 50.0,
#   'speed': 89.0,
#   'total': 411.0},
#  668.0: {'attack': 50.0,
#   'defense': 58.0,
#   'hp': 62.0,
#   'name': 'Litleo',
#   'pokemon_type': 'FireNormal',
#   'special_attack': 73.0,
#   'special_defense': 54.0,
#   'speed': 72.0,
#   'total': 369.0},
#  669.0: {'attack': 68.0,
#   'defense': 72.0,
#   'hp': 86.0,
#   'name': 'Pyroar',
#   'pokemon_type': 'FireNormal',
#   'special_attack': 109.0,
#   'special_defense': 66.0,
#   'speed': 106.0,
#   'total': 507.0},
#  670.0: {'attack': 38.0,
#   'defense': 39.0,
#   'hp': 44.0,
#   'name': 'Flabebe',
#   'pokemon_type': 'Fairy',
#   'special_attack': 61.0,
#   'special_defense': 79.0,
#   'speed': 42.0,
#   'total': 303.0},
#  671.0: {'attack': 45.0,
#   'defense': 47.0,
#   'hp': 54.0,
#   'name': 'Floette',
#   'pokemon_type': 'Fairy',
#   'special_attack': 75.0,
#   'special_defense': 98.0,
#   'speed': 52.0,
#   'total': 371.0},
#  672.0: {'attack': 65.0,
#   'defense': 68.0,
#   'hp': 78.0,
#   'name': 'Florges',
#   'pokemon_type': 'Fairy',
#   'special_attack': 112.0,
#   'special_defense': 154.0,
#   'speed': 75.0,
#   'total': 552.0},
#  673.0: {'attack': 65.0,
#   'defense': 48.0,
#   'hp': 66.0,
#   'name': 'Skiddo',
#   'pokemon_type': 'Grass',
#   'special_attack': 62.0,
#   'special_defense': 57.0,
#   'speed': 52.0,
#   'total': 350.0},
#  674.0: {'attack': 100.0,
#   'defense': 62.0,
#   'hp': 123.0,
#   'name': 'Gogoat',
#   'pokemon_type': 'Grass',
#   'special_attack': 97.0,
#   'special_defense': 81.0,
#   'speed': 68.0,
#   'total': 531.0},
#  675.0: {'attack': 82.0,
#   'defense': 62.0,
#   'hp': 67.0,
#   'name': 'Pancham',
#   'pokemon_type': 'Fighting',
#   'special_attack': 46.0,
#   'special_defense': 48.0,
#   'speed': 43.0,
#   'total': 348.0},
#  676.0: {'attack': 124.0,
#   'defense': 78.0,
#   'hp': 95.0,
#   'name': 'Pangoro',
#   'pokemon_type': 'FightingDark',
#   'special_attack': 69.0,
#   'special_defense': 71.0,
#   'speed': 58.0,
#   'total': 495.0},
#  677.0: {'attack': 80.0,
#   'defense': 60.0,
#   'hp': 75.0,
#   'name': 'Furfrou',
#   'pokemon_type': 'Normal',
#   'special_attack': 65.0,
#   'special_defense': 90.0,
#   'speed': 102.0,
#   'total': 472.0},
#  678.0: {'attack': 48.0,
#   'defense': 54.0,
#   'hp': 62.0,
#   'name': 'Espurr',
#   'pokemon_type': 'Psychic',
#   'special_attack': 63.0,
#   'special_defense': 60.0,
#   'speed': 68.0,
#   'total': 355.0},
#  678.1: {'attack': 48.0,
#   'defense': 76.0,
#   'hp': 74.0,
#   'name': 'MeowsticMale',
#   'pokemon_type': 'Psychic',
#   'special_attack': 83.0,
#   'special_defense': 81.0,
#   'speed': 104.0,
#   'total': 466.0},
#  679.0: {'attack': 48.0,
#   'defense': 76.0,
#   'hp': 74.0,
#   'name': 'MeowsticFemale',
#   'pokemon_type': 'Psychic',
#   'special_attack': 83.0,
#   'special_defense': 81.0,
#   'speed': 104.0,
#   'total': 466.0},
#  680.0: {'attack': 80.0,
#   'defense': 100.0,
#   'hp': 45.0,
#   'name': 'Honedge',
#   'pokemon_type': 'SteelGhost',
#   'special_attack': 35.0,
#   'special_defense': 37.0,
#   'speed': 28.0,
#   'total': 325.0},
#  681.0: {'attack': 110.0,
#   'defense': 150.0,
#   'hp': 59.0,
#   'name': 'Doublade',
#   'pokemon_type': 'SteelGhost',
#   'special_attack': 45.0,
#   'special_defense': 49.0,
#   'speed': 35.0,
#   'total': 448.0},
#  681.1: {'attack': 150.0,
#   'defense': 50.0,
#   'hp': 60.0,
#   'name': 'AegislashBlade Forme',
#   'pokemon_type': 'SteelGhost',
#   'special_attack': 150.0,
#   'special_defense': 50.0,
#   'speed': 60.0,
#   'total': 520.0},
#  682.0: {'attack': 50.0,
#   'defense': 150.0,
#   'hp': 60.0,
#   'name': 'AegislashShield Forme',
#   'pokemon_type': 'SteelGhost',
#   'special_attack': 50.0,
#   'special_defense': 150.0,
#   'speed': 60.0,
#   'total': 520.0},
#  683.0: {'attack': 52.0,
#   'defense': 60.0,
#   'hp': 78.0,
#   'name': 'Spritzee',
#   'pokemon_type': 'Fairy',
#   'special_attack': 63.0,
#   'special_defense': 65.0,
#   'speed': 23.0,
#   'total': 341.0},
#  684.0: {'attack': 72.0,
#   'defense': 72.0,
#   'hp': 101.0,
#   'name': 'Aromatisse',
#   'pokemon_type': 'Fairy',
#   'special_attack': 99.0,
#   'special_defense': 89.0,
#   'speed': 29.0,
#   'total': 462.0},
#  685.0: {'attack': 48.0,
#   'defense': 66.0,
#   'hp': 62.0,
#   'name': 'Swirlix',
#   'pokemon_type': 'Fairy',
#   'special_attack': 59.0,
#   'special_defense': 57.0,
#   'speed': 49.0,
#   'total': 341.0},
#  686.0: {'attack': 80.0,
#   'defense': 86.0,
#   'hp': 82.0,
#   'name': 'Slurpuff',
#   'pokemon_type': 'Fairy',
#   'special_attack': 85.0,
#   'special_defense': 75.0,
#   'speed': 72.0,
#   'total': 480.0},
#  687.0: {'attack': 54.0,
#   'defense': 53.0,
#   'hp': 53.0,
#   'name': 'Inkay',
#   'pokemon_type': 'DarkPsychic',
#   'special_attack': 37.0,
#   'special_defense': 46.0,
#   'speed': 45.0,
#   'total': 288.0},
#  688.0: {'attack': 92.0,
#   'defense': 88.0,
#   'hp': 86.0,
#   'name': 'Malamar',
#   'pokemon_type': 'DarkPsychic',
#   'special_attack': 68.0,
#   'special_defense': 75.0,
#   'speed': 73.0,
#   'total': 482.0},
#  689.0: {'attack': 52.0,
#   'defense': 67.0,
#   'hp': 42.0,
#   'name': 'Binacle',
#   'pokemon_type': 'RockWater',
#   'special_attack': 39.0,
#   'special_defense': 56.0,
#   'speed': 50.0,
#   'total': 306.0},
#  690.0: {'attack': 105.0,
#   'defense': 115.0,
#   'hp': 72.0,
#   'name': 'Barbaracle',
#   'pokemon_type': 'RockWater',
#   'special_attack': 54.0,
#   'special_defense': 86.0,
#   'speed': 68.0,
#   'total': 500.0},
#  691.0: {'attack': 60.0,
#   'defense': 60.0,
#   'hp': 50.0,
#   'name': 'Skrelp',
#   'pokemon_type': 'PoisonWater',
#   'special_attack': 60.0,
#   'special_defense': 60.0,
#   'speed': 30.0,
#   'total': 320.0},
#  692.0: {'attack': 75.0,
#   'defense': 90.0,
#   'hp': 65.0,
#   'name': 'Dragalge',
#   'pokemon_type': 'PoisonDragon',
#   'special_attack': 97.0,
#   'special_defense': 123.0,
#   'speed': 44.0,
#   'total': 494.0},
#  693.0: {'attack': 53.0,
#   'defense': 62.0,
#   'hp': 50.0,
#   'name': 'Clauncher',
#   'pokemon_type': 'Water',
#   'special_attack': 58.0,
#   'special_defense': 63.0,
#   'speed': 44.0,
#   'total': 330.0},
#  694.0: {'attack': 73.0,
#   'defense': 88.0,
#   'hp': 71.0,
#   'name': 'Clawitzer',
#   'pokemon_type': 'Water',
#   'special_attack': 120.0,
#   'special_defense': 89.0,
#   'speed': 59.0,
#   'total': 500.0},
#  695.0: {'attack': 38.0,
#   'defense': 33.0,
#   'hp': 44.0,
#   'name': 'Helioptile',
#   'pokemon_type': 'ElectricNormal',
#   'special_attack': 61.0,
#   'special_defense': 43.0,
#   'speed': 70.0,
#   'total': 289.0},
#  696.0: {'attack': 55.0,
#   'defense': 52.0,
#   'hp': 62.0,
#   'name': 'Heliolisk',
#   'pokemon_type': 'ElectricNormal',
#   'special_attack': 109.0,
#   'special_defense': 94.0,
#   'speed': 109.0,
#   'total': 481.0},
#  697.0: {'attack': 89.0,
#   'defense': 77.0,
#   'hp': 58.0,
#   'name': 'Tyrunt',
#   'pokemon_type': 'RockDragon',
#   'special_attack': 45.0,
#   'special_defense': 45.0,
#   'speed': 48.0,
#   'total': 362.0},
#  698.0: {'attack': 121.0,
#   'defense': 119.0,
#   'hp': 82.0,
#   'name': 'Tyrantrum',
#   'pokemon_type': 'RockDragon',
#   'special_attack': 69.0,
#   'special_defense': 59.0,
#   'speed': 71.0,
#   'total': 521.0},
#  699.0: {'attack': 59.0,
#   'defense': 50.0,
#   'hp': 77.0,
#   'name': 'Amaura',
#   'pokemon_type': 'RockIce',
#   'special_attack': 67.0,
#   'special_defense': 63.0,
#   'speed': 46.0,
#   'total': 362.0},
#  700.0: {'attack': 77.0,
#   'defense': 72.0,
#   'hp': 123.0,
#   'name': 'Aurorus',
#   'pokemon_type': 'RockIce',
#   'special_attack': 99.0,
#   'special_defense': 92.0,
#   'speed': 58.0,
#   'total': 521.0},
#  701.0: {'attack': 65.0,
#   'defense': 65.0,
#   'hp': 95.0,
#   'name': 'Sylveon',
#   'pokemon_type': 'Fairy',
#   'special_attack': 110.0,
#   'special_defense': 130.0,
#   'speed': 60.0,
#   'total': 525.0},
#  702.0: {'attack': 92.0,
#   'defense': 75.0,
#   'hp': 78.0,
#   'name': 'Hawlucha',
#   'pokemon_type': 'FightingFlying',
#   'special_attack': 74.0,
#   'special_defense': 63.0,
#   'speed': 118.0,
#   'total': 500.0},
#  703.0: {'attack': 58.0,
#   'defense': 57.0,
#   'hp': 67.0,
#   'name': 'Dedenne',
#   'pokemon_type': 'ElectricFairy',
#   'special_attack': 81.0,
#   'special_defense': 67.0,
#   'speed': 101.0,
#   'total': 431.0},
#  704.0: {'attack': 50.0,
#   'defense': 150.0,
#   'hp': 50.0,
#   'name': 'Carbink',
#   'pokemon_type': 'RockFairy',
#   'special_attack': 50.0,
#   'special_defense': 150.0,
#   'speed': 50.0,
#   'total': 500.0},
#  705.0: {'attack': 50.0,
#   'defense': 35.0,
#   'hp': 45.0,
#   'name': 'Goomy',
#   'pokemon_type': 'Dragon',
#   'special_attack': 55.0,
#   'special_defense': 75.0,
#   'speed': 40.0,
#   'total': 300.0},
#  706.0: {'attack': 75.0,
#   'defense': 53.0,
#   'hp': 68.0,
#   'name': 'Sliggoo',
#   'pokemon_type': 'Dragon',
#   'special_attack': 83.0,
#   'special_defense': 113.0,
#   'speed': 60.0,
#   'total': 452.0},
#  707.0: {'attack': 100.0,
#   'defense': 70.0,
#   'hp': 90.0,
#   'name': 'Goodra',
#   'pokemon_type': 'Dragon',
#   'special_attack': 110.0,
#   'special_defense': 150.0,
#   'speed': 80.0,
#   'total': 600.0},
#  708.0: {'attack': 80.0,
#   'defense': 91.0,
#   'hp': 57.0,
#   'name': 'Klefki',
#   'pokemon_type': 'SteelFairy',
#   'special_attack': 80.0,
#   'special_defense': 87.0,
#   'speed': 75.0,
#   'total': 470.0},
#  709.0: {'attack': 70.0,
#   'defense': 48.0,
#   'hp': 43.0,
#   'name': 'Phantump',
#   'pokemon_type': 'GhostGrass',
#   'special_attack': 50.0,
#   'special_defense': 60.0,
#   'speed': 38.0,
#   'total': 309.0},
#  710.0: {'attack': 110.0,
#   'defense': 76.0,
#   'hp': 85.0,
#   'name': 'Trevenant',
#   'pokemon_type': 'GhostGrass',
#   'special_attack': 65.0,
#   'special_defense': 82.0,
#   'speed': 56.0,
#   'total': 474.0},
#  710.1: {'attack': 66.0,
#   'defense': 70.0,
#   'hp': 49.0,
#   'name': 'PumpkabooAverage Size',
#   'pokemon_type': 'GhostGrass',
#   'special_attack': 44.0,
#   'special_defense': 55.0,
#   'speed': 51.0,
#   'total': 335.0},
#  710.2: {'attack': 66.0,
#   'defense': 70.0,
#   'hp': 44.0,
#   'name': 'PumpkabooSmall Size',
#   'pokemon_type': 'GhostGrass',
#   'special_attack': 44.0,
#   'special_defense': 55.0,
#   'speed': 56.0,
#   'total': 335.0},
#  710.3000000000001: {'attack': 66.0,
#   'defense': 70.0,
#   'hp': 54.0,
#   'name': 'PumpkabooLarge Size',
#   'pokemon_type': 'GhostGrass',
#   'special_attack': 44.0,
#   'special_defense': 55.0,
#   'speed': 46.0,
#   'total': 335.0},
#  711.0: {'attack': 66.0,
#   'defense': 70.0,
#   'hp': 59.0,
#   'name': 'PumpkabooSuper Size',
#   'pokemon_type': 'GhostGrass',
#   'special_attack': 44.0,
#   'special_defense': 55.0,
#   'speed': 41.0,
#   'total': 335.0},
#  711.1: {'attack': 90.0,
#   'defense': 122.0,
#   'hp': 65.0,
#   'name': 'GourgeistAverage Size',
#   'pokemon_type': 'GhostGrass',
#   'special_attack': 58.0,
#   'special_defense': 75.0,
#   'speed': 84.0,
#   'total': 494.0},
#  711.2: {'attack': 85.0,
#   'defense': 122.0,
#   'hp': 55.0,
#   'name': 'GourgeistSmall Size',
#   'pokemon_type': 'GhostGrass',
#   'special_attack': 58.0,
#   'special_defense': 75.0,
#   'speed': 99.0,
#   'total': 494.0},
#  711.3000000000001: {'attack': 95.0,
#   'defense': 122.0,
#   'hp': 75.0,
#   'name': 'GourgeistLarge Size',
#   'pokemon_type': 'GhostGrass',
#   'special_attack': 58.0,
#   'special_defense': 75.0,
#   'speed': 69.0,
#   'total': 494.0},
#  712.0: {'attack': 100.0,
#   'defense': 122.0,
#   'hp': 85.0,
#   'name': 'GourgeistSuper Size',
#   'pokemon_type': 'GhostGrass',
#   'special_attack': 58.0,
#   'special_defense': 75.0,
#   'speed': 54.0,
#   'total': 494.0},
#  713.0: {'attack': 69.0,
#   'defense': 85.0,
#   'hp': 55.0,
#   'name': 'Bergmite',
#   'pokemon_type': 'Ice',
#   'special_attack': 32.0,
#   'special_defense': 35.0,
#   'speed': 28.0,
#   'total': 304.0},
#  714.0: {'attack': 117.0,
#   'defense': 184.0,
#   'hp': 95.0,
#   'name': 'Avalugg',
#   'pokemon_type': 'Ice',
#   'special_attack': 44.0,
#   'special_defense': 46.0,
#   'speed': 28.0,
#   'total': 514.0},
#  715.0: {'attack': 30.0,
#   'defense': 35.0,
#   'hp': 40.0,
#   'name': 'Noibat',
#   'pokemon_type': 'FlyingDragon',
#   'special_attack': 45.0,
#   'special_defense': 40.0,
#   'speed': 55.0,
#   'total': 245.0},
#  716.0: {'attack': 70.0,
#   'defense': 80.0,
#   'hp': 85.0,
#   'name': 'Noivern',
#   'pokemon_type': 'FlyingDragon',
#   'special_attack': 97.0,
#   'special_defense': 80.0,
#   'speed': 123.0,
#   'total': 535.0},
#  717.0: {'attack': 131.0,
#   'defense': 95.0,
#   'hp': 126.0,
#   'name': 'Xerneas',
#   'pokemon_type': 'Fairy',
#   'special_attack': 131.0,
#   'special_defense': 98.0,
#   'speed': 99.0,
#   'total': 680.0},
#  718.0: {'attack': 131.0,
#   'defense': 95.0,
#   'hp': 126.0,
#   'name': 'Yveltal',
#   'pokemon_type': 'DarkFlying',
#   'special_attack': 131.0,
#   'special_defense': 98.0,
#   'speed': 99.0,
#   'total': 680.0},
#  719.0: {'attack': 100.0,
#   'defense': 121.0,
#   'hp': 108.0,
#   'name': 'Zygarde Forme',
#   'pokemon_type': 'DragonGround',
#   'special_attack': 81.0,
#   'special_defense': 95.0,
#   'speed': 95.0,
#   'total': 600.0},
#  719.1: {'attack': 100.0,
#   'defense': 150.0,
#   'hp': 50.0,
#   'name': 'Diancie',
#   'pokemon_type': 'RockFairy',
#   'special_attack': 100.0,
#   'special_defense': 150.0,
#   'speed': 50.0,
#   'total': 600.0},
#  720.0: {'attack': 160.0,
#   'defense': 110.0,
#   'hp': 50.0,
#   'name': 'DiancieMega Diancie',
#   'pokemon_type': 'RockFairy',
#   'special_attack': 160.0,
#   'special_defense': 110.0,
#   'speed': 110.0,
#   'total': 700.0},
#  720.1: {'attack': 110.0,
#   'defense': 60.0,
#   'hp': 80.0,
#   'name': 'HoopaHoopa Confined',
#   'pokemon_type': 'PsychicGhost',
#   'special_attack': 150.0,
#   'special_defense': 130.0,
#   'speed': 70.0,
#   'total': 600.0},
#  721.0: {'attack': 160.0,
#   'defense': 60.0,
#   'hp': 80.0,
#   'name': 'HoopaHoopa Unbound',
#   'pokemon_type': 'PsychicDark',
#   'special_attack': 170.0,
#   'special_defense': 130.0,
#   'speed': 80.0,
#   'total': 680.0}}

# %%
# look at the complete pokedex
new_full_pokedex
# Out:
# {1.0: {'attack': 'Attack',
#   'defense': 'Defense',
#   'hp': 'HP',
#   'name': 'Name',
#   'pokemon_type': 'Type',
#   'special_attack': 'SpecialAttack',
#   'special_defense': 'SpecialDefense',
#   'speed': 'Speed',
#   'total': 'Total'},
#  2.0: {'attack': 49.0,
#   'defense': 49.0,
#   'hp': 45.0,
#   'name': 'Bulbasaur',
#   'pokemon_type': 'GrassPoison',
#   'special_attack': 65.0,
#   'special_defense': 65.0,
#   'speed': 45.0,
#   'total': 318.0},
#  3.0: {'attack': 62.0,
#   'defense': 63.0,
#   'hp': 60.0,
#   'name': 'Ivysaur',
#   'pokemon_type': 'GrassPoison',
#   'special_attack': 80.0,
#   'special_defense': 80.0,
#   'speed': 60.0,
#   'total': 405.0},
#  3.1: {'attack': 82.0,
#   'defense': 83.0,
#   'hp': 80.0,
#   'name': 'Venusaur',
#   'pokemon_type': 'GrassPoison',
#   'special_attack': 100.0,
#   'special_defense': 100.0,
#   'speed': 80.0,
#   'total': 525.0},
#  4.0: {'attack': 100.0,
#   'defense': 123.0,
#   'hp': 80.0,
#   'name': 'VenusaurMega Venusaur',
#   'pokemon_type': 'GrassPoison',
#   'special_attack': 122.0,
#   'special_defense': 120.0,
#   'speed': 80.0,
#   'total': 625.0},
#  5.0: {'attack': 52.0,
#   'defense': 43.0,
#   'hp': 39.0,
#   'name': 'Charmander',
#   'pokemon_type': 'Fire',
#   'special_attack': 60.0,
#   'special_defense': 50.0,
#   'speed': 65.0,
#   'total': 309.0},
#  6.0: {'attack': 64.0,
#   'defense': 58.0,
#   'hp': 58.0,
#   'name': 'Charmeleon',
#   'pokemon_type': 'Fire',
#   'special_attack': 80.0,
#   'special_defense': 65.0,
#   'speed': 80.0,
#   'total': 405.0},
#  6.1: {'attack': 84.0,
#   'defense': 78.0,
#   'hp': 78.0,
#   'name': 'Charizard',
#   'pokemon_type': 'FireFlying',
#   'special_attack': 109.0,
#   'special_defense': 85.0,
#   'speed': 100.0,
#   'total': 534.0},
#  6.199999999999999: {'attack': 130.0,
#   'defense': 111.0,
#   'hp': 78.0,
#   'name': 'CharizardMega Charizard X',
#   'pokemon_type': 'FireDragon',
#   'special_attack': 130.0,
#   'special_defense': 85.0,
#   'speed': 100.0,
#   'total': 634.0},
#  7.0: {'attack': 104.0,
#   'defense': 78.0,
#   'hp': 78.0,
#   'name': 'CharizardMega Charizard Y',
#   'pokemon_type': 'FireFlying',
#   'special_attack': 159.0,
#   'special_defense': 115.0,
#   'speed': 100.0,
#   'total': 634.0},
#  8.0: {'attack': 48.0,
#   'defense': 65.0,
#   'hp': 44.0,
#   'name': 'Squirtle',
#   'pokemon_type': 'Water',
#   'special_attack': 50.0,
#   'special_defense': 64.0,
#   'speed': 43.0,
#   'total': 314.0},
#  9.0: {'attack': 63.0,
#   'defense': 80.0,
#   'hp': 59.0,
#   'name': 'Wartortle',
#   'pokemon_type': 'Water',
#   'special_attack': 65.0,
#   'special_defense': 80.0,
#   'speed': 58.0,
#   'total': 405.0},
#  9.1: {'attack': 83.0,
#   'defense': 100.0,
#   'hp': 79.0,
#   'name': 'Blastoise',
#   'pokemon_type': 'Water',
#   'special_attack': 85.0,
#   'special_defense': 105.0,
#   'speed': 78.0,
#   'total': 530.0},
#  10.0: {'attack': 103.0,
#   'defense': 120.0,
#   'hp': 79.0,
#   'name': 'BlastoiseMega Blastoise',
#   'pokemon_type': 'Water',
#   'special_attack': 135.0,
#   'special_defense': 115.0,
#   'speed': 78.0,
#   'total': 630.0},
#  11.0: {'attack': 30.0,
#   'defense': 35.0,
#   'hp': 45.0,
#   'name': 'Caterpie',
#   'pokemon_type': 'Bug',
#   'special_attack': 20.0,
#   'special_defense': 20.0,
#   'speed': 45.0,
#   'total': 195.0},
#  12.0: {'attack': 20.0,
#   'defense': 55.0,
#   'hp': 50.0,
#   'name': 'Metapod',
#   'pokemon_type': 'Bug',
#   'special_attack': 25.0,
#   'special_defense': 25.0,
#   'speed': 30.0,
#   'total': 205.0},
#  13.0: {'attack': 45.0,
#   'defense': 50.0,
#   'hp': 60.0,
#   'name': 'Butterfree',
#   'pokemon_type': 'BugFlying',
#   'special_attack': 90.0,
#   'special_defense': 80.0,
#   'speed': 70.0,
#   'total': 395.0},
#  14.0: {'attack': 35.0,
#   'defense': 30.0,
#   'hp': 40.0,
#   'name': 'Weedle',
#   'pokemon_type': 'BugPoison',
#   'special_attack': 20.0,
#   'special_defense': 20.0,
#   'speed': 50.0,
#   'total': 195.0},
#  15.0: {'attack': 25.0,
#   'defense': 50.0,
#   'hp': 45.0,
#   'name': 'Kakuna',
#   'pokemon_type': 'BugPoison',
#   'special_attack': 25.0,
#   'special_defense': 25.0,
#   'speed': 35.0,
#   'total': 205.0},
#  15.1: {'attack': 90.0,
#   'defense': 40.0,
#   'hp': 65.0,
#   'name': 'Beedrill',
#   'pokemon_type': 'BugPoison',
#   'special_attack': 45.0,
#   'special_defense': 80.0,
#   'speed': 75.0,
#   'total': 395.0},
#  16.0: {'attack': 150.0,
#   'defense': 40.0,
#   'hp': 65.0,
#   'name': 'BeedrillMega Beedrill',
#   'pokemon_type': 'BugPoison',
#   'special_attack': 15.0,
#   'special_defense': 80.0,
#   'speed': 145.0,
#   'total': 495.0},
#  17.0: {'attack': 45.0,
#   'defense': 40.0,
#   'hp': 40.0,
#   'name': 'Pidgey',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 35.0,
#   'special_defense': 35.0,
#   'speed': 56.0,
#   'total': 251.0},
#  18.0: {'attack': 60.0,
#   'defense': 55.0,
#   'hp': 63.0,
#   'name': 'Pidgeotto',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 50.0,
#   'special_defense': 50.0,
#   'speed': 71.0,
#   'total': 349.0},
#  18.1: {'attack': 80.0,
#   'defense': 75.0,
#   'hp': 83.0,
#   'name': 'Pidgeot',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 70.0,
#   'special_defense': 70.0,
#   'speed': 101.0,
#   'total': 479.0},
#  19.0: {'attack': 80.0,
#   'defense': 80.0,
#   'hp': 83.0,
#   'name': 'PidgeotMega Pidgeot',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 135.0,
#   'special_defense': 80.0,
#   'speed': 121.0,
#   'total': 579.0},
#  20.0: {'attack': 56.0,
#   'defense': 35.0,
#   'hp': 30.0,
#   'name': 'Rattata',
#   'pokemon_type': 'Normal',
#   'special_attack': 25.0,
#   'special_defense': 35.0,
#   'speed': 72.0,
#   'total': 253.0},
#  21.0: {'attack': 81.0,
#   'defense': 60.0,
#   'hp': 55.0,
#   'name': 'Raticate',
#   'pokemon_type': 'Normal',
#   'special_attack': 50.0,
#   'special_defense': 70.0,
#   'speed': 97.0,
#   'total': 413.0},
#  22.0: {'attack': 60.0,
#   'defense': 30.0,
#   'hp': 40.0,
#   'name': 'Spearow',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 31.0,
#   'special_defense': 31.0,
#   'speed': 70.0,
#   'total': 262.0},
#  23.0: {'attack': 90.0,
#   'defense': 65.0,
#   'hp': 65.0,
#   'name': 'Fearow',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 61.0,
#   'special_defense': 61.0,
#   'speed': 100.0,
#   'total': 442.0},
#  24.0: {'attack': 60.0,
#   'defense': 44.0,
#   'hp': 35.0,
#   'name': 'Ekans',
#   'pokemon_type': 'Poison',
#   'special_attack': 40.0,
#   'special_defense': 54.0,
#   'speed': 55.0,
#   'total': 288.0},
#  25.0: {'attack': 85.0,
#   'defense': 69.0,
#   'hp': 60.0,
#   'name': 'Arbok',
#   'pokemon_type': 'Poison',
#   'special_attack': 65.0,
#   'special_defense': 79.0,
#   'speed': 80.0,
#   'total': 438.0},
#  26.0: {'attack': 55.0,
#   'defense': 40.0,
#   'hp': 35.0,
#   'name': 'Pikachu',
#   'pokemon_type': 'Electric',
#   'special_attack': 50.0,
#   'special_defense': 50.0,
#   'speed': 90.0,
#   'total': 320.0},
#  27.0: {'attack': 90.0,
#   'defense': 55.0,
#   'hp': 60.0,
#   'name': 'Raichu',
#   'pokemon_type': 'Electric',
#   'special_attack': 90.0,
#   'special_defense': 80.0,
#   'speed': 110.0,
#   'total': 485.0},
#  28.0: {'attack': 75.0,
#   'defense': 85.0,
#   'hp': 50.0,
#   'name': 'Sandshrew',
#   'pokemon_type': 'Ground',
#   'special_attack': 20.0,
#   'special_defense': 30.0,
#   'speed': 40.0,
#   'total': 300.0},
#  29.0: {'attack': 100.0,
#   'defense': 110.0,
#   'hp': 75.0,
#   'name': 'Sandslash',
#   'pokemon_type': 'Ground',
#   'special_attack': 45.0,
#   'special_defense': 55.0,
#   'speed': 65.0,
#   'total': 450.0},
#  30.0: {'attack': 47.0,
#   'defense': 52.0,
#   'hp': 55.0,
#   'name': 'NidoranF',
#   'pokemon_type': 'Poison',
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 41.0,
#   'total': 275.0},
#  31.0: {'attack': 62.0,
#   'defense': 67.0,
#   'hp': 70.0,
#   'name': 'Nidorina',
#   'pokemon_type': 'Poison',
#   'special_attack': 55.0,
#   'special_defense': 55.0,
#   'speed': 56.0,
#   'total': 365.0},
#  32.0: {'attack': 92.0,
#   'defense': 87.0,
#   'hp': 90.0,
#   'name': 'Nidoqueen',
#   'pokemon_type': 'PoisonGround',
#   'special_attack': 75.0,
#   'special_defense': 85.0,
#   'speed': 76.0,
#   'total': 505.0},
#  33.0: {'attack': 57.0,
#   'defense': 40.0,
#   'hp': 46.0,
#   'name': 'NidoranM',
#   'pokemon_type': 'Poison',
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 50.0,
#   'total': 273.0},
#  34.0: {'attack': 72.0,
#   'defense': 57.0,
#   'hp': 61.0,
#   'name': 'Nidorino',
#   'pokemon_type': 'Poison',
#   'special_attack': 55.0,
#   'special_defense': 55.0,
#   'speed': 65.0,
#   'total': 365.0},
#  35.0: {'attack': 102.0,
#   'defense': 77.0,
#   'hp': 81.0,
#   'name': 'Nidoking',
#   'pokemon_type': 'PoisonGround',
#   'special_attack': 85.0,
#   'special_defense': 75.0,
#   'speed': 85.0,
#   'total': 505.0},
#  36.0: {'attack': 45.0,
#   'defense': 48.0,
#   'hp': 70.0,
#   'name': 'Clefairy',
#   'pokemon_type': 'Fairy',
#   'special_attack': 60.0,
#   'special_defense': 65.0,
#   'speed': 35.0,
#   'total': 323.0},
#  37.0: {'attack': 70.0,
#   'defense': 73.0,
#   'hp': 95.0,
#   'name': 'Clefable',
#   'pokemon_type': 'Fairy',
#   'special_attack': 95.0,
#   'special_defense': 90.0,
#   'speed': 60.0,
#   'total': 483.0},
#  38.0: {'attack': 41.0,
#   'defense': 40.0,
#   'hp': 38.0,
#   'name': 'Vulpix',
#   'pokemon_type': 'Fire',
#   'special_attack': 50.0,
#   'special_defense': 65.0,
#   'speed': 65.0,
#   'total': 299.0},
#  39.0: {'attack': 76.0,
#   'defense': 75.0,
#   'hp': 73.0,
#   'name': 'Ninetales',
#   'pokemon_type': 'Fire',
#   'special_attack': 81.0,
#   'special_defense': 100.0,
#   'speed': 100.0,
#   'total': 505.0},
#  40.0: {'attack': 45.0,
#   'defense': 20.0,
#   'hp': 115.0,
#   'name': 'Jigglypuff',
#   'pokemon_type': 'NormalFairy',
#   'special_attack': 45.0,
#   'special_defense': 25.0,
#   'speed': 20.0,
#   'total': 270.0},
#  41.0: {'attack': 70.0,
#   'defense': 45.0,
#   'hp': 140.0,
#   'name': 'Wigglytuff',
#   'pokemon_type': 'NormalFairy',
#   'special_attack': 85.0,
#   'special_defense': 50.0,
#   'speed': 45.0,
#   'total': 435.0},
#  42.0: {'attack': 45.0,
#   'defense': 35.0,
#   'hp': 40.0,
#   'name': 'Zubat',
#   'pokemon_type': 'PoisonFlying',
#   'special_attack': 30.0,
#   'special_defense': 40.0,
#   'speed': 55.0,
#   'total': 245.0},
#  43.0: {'attack': 80.0,
#   'defense': 70.0,
#   'hp': 75.0,
#   'name': 'Golbat',
#   'pokemon_type': 'PoisonFlying',
#   'special_attack': 65.0,
#   'special_defense': 75.0,
#   'speed': 90.0,
#   'total': 455.0},
#  44.0: {'attack': 50.0,
#   'defense': 55.0,
#   'hp': 45.0,
#   'name': 'Oddish',
#   'pokemon_type': 'GrassPoison',
#   'special_attack': 75.0,
#   'special_defense': 65.0,
#   'speed': 30.0,
#   'total': 320.0},
#  45.0: {'attack': 65.0,
#   'defense': 70.0,
#   'hp': 60.0,
#   'name': 'Gloom',
#   'pokemon_type': 'GrassPoison',
#   'special_attack': 85.0,
#   'special_defense': 75.0,
#   'speed': 40.0,
#   'total': 395.0},
#  46.0: {'attack': 80.0,
#   'defense': 85.0,
#   'hp': 75.0,
#   'name': 'Vileplume',
#   'pokemon_type': 'GrassPoison',
#   'special_attack': 110.0,
#   'special_defense': 90.0,
#   'speed': 50.0,
#   'total': 490.0},
#  47.0: {'attack': 70.0,
#   'defense': 55.0,
#   'hp': 35.0,
#   'name': 'Paras',
#   'pokemon_type': 'BugGrass',
#   'special_attack': 45.0,
#   'special_defense': 55.0,
#   'speed': 25.0,
#   'total': 285.0},
#  48.0: {'attack': 95.0,
#   'defense': 80.0,
#   'hp': 60.0,
#   'name': 'Parasect',
#   'pokemon_type': 'BugGrass',
#   'special_attack': 60.0,
#   'special_defense': 80.0,
#   'speed': 30.0,
#   'total': 405.0},
#  49.0: {'attack': 55.0,
#   'defense': 50.0,
#   'hp': 60.0,
#   'name': 'Venonat',
#   'pokemon_type': 'BugPoison',
#   'special_attack': 40.0,
#   'special_defense': 55.0,
#   'speed': 45.0,
#   'total': 305.0},
#  50.0: {'attack': 65.0,
#   'defense': 60.0,
#   'hp': 70.0,
#   'name': 'Venomoth',
#   'pokemon_type': 'BugPoison',
#   'special_attack': 90.0,
#   'special_defense': 75.0,
#   'speed': 90.0,
#   'total': 450.0},
#  51.0: {'attack': 55.0,
#   'defense': 25.0,
#   'hp': 10.0,
#   'name': 'Diglett',
#   'pokemon_type': 'Ground',
#   'special_attack': 35.0,
#   'special_defense': 45.0,
#   'speed': 95.0,
#   'total': 265.0},
#  52.0: {'attack': 80.0,
#   'defense': 50.0,
#   'hp': 35.0,
#   'name': 'Dugtrio',
#   'pokemon_type': 'Ground',
#   'special_attack': 50.0,
#   'special_defense': 70.0,
#   'speed': 120.0,
#   'total': 405.0},
#  53.0: {'attack': 45.0,
#   'defense': 35.0,
#   'hp': 40.0,
#   'name': 'Meowth',
#   'pokemon_type': 'Normal',
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 90.0,
#   'total': 290.0},
#  54.0: {'attack': 70.0,
#   'defense': 60.0,
#   'hp': 65.0,
#   'name': 'Persian',
#   'pokemon_type': 'Normal',
#   'special_attack': 65.0,
#   'special_defense': 65.0,
#   'speed': 115.0,
#   'total': 440.0},
#  55.0: {'attack': 52.0,
#   'defense': 48.0,
#   'hp': 50.0,
#   'name': 'Psyduck',
#   'pokemon_type': 'Water',
#   'special_attack': 65.0,
#   'special_defense': 50.0,
#   'speed': 55.0,
#   'total': 320.0},
#  56.0: {'attack': 82.0,
#   'defense': 78.0,
#   'hp': 80.0,
#   'name': 'Golduck',
#   'pokemon_type': 'Water',
#   'special_attack': 95.0,
#   'special_defense': 80.0,
#   'speed': 85.0,
#   'total': 500.0},
#  57.0: {'attack': 80.0,
#   'defense': 35.0,
#   'hp': 40.0,
#   'name': 'Mankey',
#   'pokemon_type': 'Fighting',
#   'special_attack': 35.0,
#   'special_defense': 45.0,
#   'speed': 70.0,
#   'total': 305.0},
#  58.0: {'attack': 105.0,
#   'defense': 60.0,
#   'hp': 65.0,
#   'name': 'Primeape',
#   'pokemon_type': 'Fighting',
#   'special_attack': 60.0,
#   'special_defense': 70.0,
#   'speed': 95.0,
#   'total': 455.0},
#  59.0: {'attack': 70.0,
#   'defense': 45.0,
#   'hp': 55.0,
#   'name': 'Growlithe',
#   'pokemon_type': 'Fire',
#   'special_attack': 70.0,
#   'special_defense': 50.0,
#   'speed': 60.0,
#   'total': 350.0},
#  60.0: {'attack': 110.0,
#   'defense': 80.0,
#   'hp': 90.0,
#   'name': 'Arcanine',
#   'pokemon_type': 'Fire',
#   'special_attack': 100.0,
#   'special_defense': 80.0,
#   'speed': 95.0,
#   'total': 555.0},
#  61.0: {'attack': 50.0,
#   'defense': 40.0,
#   'hp': 40.0,
#   'name': 'Poliwag',
#   'pokemon_type': 'Water',
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 90.0,
#   'total': 300.0},
#  62.0: {'attack': 65.0,
#   'defense': 65.0,
#   'hp': 65.0,
#   'name': 'Poliwhirl',
#   'pokemon_type': 'Water',
#   'special_attack': 50.0,
#   'special_defense': 50.0,
#   'speed': 90.0,
#   'total': 385.0},
#  63.0: {'attack': 95.0,
#   'defense': 95.0,
#   'hp': 90.0,
#   'name': 'Poliwrath',
#   'pokemon_type': 'WaterFighting',
#   'special_attack': 70.0,
#   'special_defense': 90.0,
#   'speed': 70.0,
#   'total': 510.0},
#  64.0: {'attack': 20.0,
#   'defense': 15.0,
#   'hp': 25.0,
#   'name': 'Abra',
#   'pokemon_type': 'Psychic',
#   'special_attack': 105.0,
#   'special_defense': 55.0,
#   'speed': 90.0,
#   'total': 310.0},
#  65.0: {'attack': 35.0,
#   'defense': 30.0,
#   'hp': 40.0,
#   'name': 'Kadabra',
#   'pokemon_type': 'Psychic',
#   'special_attack': 120.0,
#   'special_defense': 70.0,
#   'speed': 105.0,
#   'total': 400.0},
#  65.1: {'attack': 50.0,
#   'defense': 45.0,
#   'hp': 55.0,
#   'name': 'Alakazam',
#   'pokemon_type': 'Psychic',
#   'special_attack': 135.0,
#   'special_defense': 95.0,
#   'speed': 120.0,
#   'total': 500.0},
#  66.0: {'attack': 50.0,
#   'defense': 65.0,
#   'hp': 55.0,
#   'name': 'AlakazamMega Alakazam',
#   'pokemon_type': 'Psychic',
#   'special_attack': 175.0,
#   'special_defense': 95.0,
#   'speed': 150.0,
#   'total': 590.0},
#  67.0: {'attack': 80.0,
#   'defense': 50.0,
#   'hp': 70.0,
#   'name': 'Machop',
#   'pokemon_type': 'Fighting',
#   'special_attack': 35.0,
#   'special_defense': 35.0,
#   'speed': 35.0,
#   'total': 305.0},
#  68.0: {'attack': 100.0,
#   'defense': 70.0,
#   'hp': 80.0,
#   'name': 'Machoke',
#   'pokemon_type': 'Fighting',
#   'special_attack': 50.0,
#   'special_defense': 60.0,
#   'speed': 45.0,
#   'total': 405.0},
#  69.0: {'attack': 130.0,
#   'defense': 80.0,
#   'hp': 90.0,
#   'name': 'Machamp',
#   'pokemon_type': 'Fighting',
#   'special_attack': 65.0,
#   'special_defense': 85.0,
#   'speed': 55.0,
#   'total': 505.0},
#  70.0: {'attack': 75.0,
#   'defense': 35.0,
#   'hp': 50.0,
#   'name': 'Bellsprout',
#   'pokemon_type': 'GrassPoison',
#   'special_attack': 70.0,
#   'special_defense': 30.0,
#   'speed': 40.0,
#   'total': 300.0},
#  71.0: {'attack': 90.0,
#   'defense': 50.0,
#   'hp': 65.0,
#   'name': 'Weepinbell',
#   'pokemon_type': 'GrassPoison',
#   'special_attack': 85.0,
#   'special_defense': 45.0,
#   'speed': 55.0,
#   'total': 390.0},
#  72.0: {'attack': 105.0,
#   'defense': 65.0,
#   'hp': 80.0,
#   'name': 'Victreebel',
#   'pokemon_type': 'GrassPoison',
#   'special_attack': 100.0,
#   'special_defense': 70.0,
#   'speed': 70.0,
#   'total': 490.0},
#  73.0: {'attack': 40.0,
#   'defense': 35.0,
#   'hp': 40.0,
#   'name': 'Tentacool',
#   'pokemon_type': 'WaterPoison',
#   'special_attack': 50.0,
#   'special_defense': 100.0,
#   'speed': 70.0,
#   'total': 335.0},
#  74.0: {'attack': 70.0,
#   'defense': 65.0,
#   'hp': 80.0,
#   'name': 'Tentacruel',
#   'pokemon_type': 'WaterPoison',
#   'special_attack': 80.0,
#   'special_defense': 120.0,
#   'speed': 100.0,
#   'total': 515.0},
#  75.0: {'attack': 80.0,
#   'defense': 100.0,
#   'hp': 40.0,
#   'name': 'Geodude',
#   'pokemon_type': 'RockGround',
#   'special_attack': 30.0,
#   'special_defense': 30.0,
#   'speed': 20.0,
#   'total': 300.0},
#  76.0: {'attack': 95.0,
#   'defense': 115.0,
#   'hp': 55.0,
#   'name': 'Graveler',
#   'pokemon_type': 'RockGround',
#   'special_attack': 45.0,
#   'special_defense': 45.0,
#   'speed': 35.0,
#   'total': 390.0},
#  77.0: {'attack': 120.0,
#   'defense': 130.0,
#   'hp': 80.0,
#   'name': 'Golem',
#   'pokemon_type': 'RockGround',
#   'special_attack': 55.0,
#   'special_defense': 65.0,
#   'speed': 45.0,
#   'total': 495.0},
#  78.0: {'attack': 85.0,
#   'defense': 55.0,
#   'hp': 50.0,
#   'name': 'Ponyta',
#   'pokemon_type': 'Fire',
#   'special_attack': 65.0,
#   'special_defense': 65.0,
#   'speed': 90.0,
#   'total': 410.0},
#  79.0: {'attack': 100.0,
#   'defense': 70.0,
#   'hp': 65.0,
#   'name': 'Rapidash',
#   'pokemon_type': 'Fire',
#   'special_attack': 80.0,
#   'special_defense': 80.0,
#   'speed': 105.0,
#   'total': 500.0},
#  80.0: {'attack': 65.0,
#   'defense': 65.0,
#   'hp': 90.0,
#   'name': 'Slowpoke',
#   'pokemon_type': 'WaterPsychic',
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 15.0,
#   'total': 315.0},
#  80.1: {'attack': 75.0,
#   'defense': 110.0,
#   'hp': 95.0,
#   'name': 'Slowbro',
#   'pokemon_type': 'WaterPsychic',
#   'special_attack': 100.0,
#   'special_defense': 80.0,
#   'speed': 30.0,
#   'total': 490.0},
#  81.0: {'attack': 75.0,
#   'defense': 180.0,
#   'hp': 95.0,
#   'name': 'SlowbroMega Slowbro',
#   'pokemon_type': 'WaterPsychic',
#   'special_attack': 130.0,
#   'special_defense': 80.0,
#   'speed': 30.0,
#   'total': 590.0},
#  82.0: {'attack': 35.0,
#   'defense': 70.0,
#   'hp': 25.0,
#   'name': 'Magnemite',
#   'pokemon_type': 'ElectricSteel',
#   'special_attack': 95.0,
#   'special_defense': 55.0,
#   'speed': 45.0,
#   'total': 325.0},
#  83.0: {'attack': 60.0,
#   'defense': 95.0,
#   'hp': 50.0,
#   'name': 'Magneton',
#   'pokemon_type': 'ElectricSteel',
#   'special_attack': 120.0,
#   'special_defense': 70.0,
#   'speed': 70.0,
#   'total': 465.0},
#  84.0: {'attack': 65.0,
#   'defense': 55.0,
#   'hp': 52.0,
#   'name': "Farfetch'd",
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 58.0,
#   'special_defense': 62.0,
#   'speed': 60.0,
#   'total': 352.0},
#  85.0: {'attack': 85.0,
#   'defense': 45.0,
#   'hp': 35.0,
#   'name': 'Doduo',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 35.0,
#   'special_defense': 35.0,
#   'speed': 75.0,
#   'total': 310.0},
#  86.0: {'attack': 110.0,
#   'defense': 70.0,
#   'hp': 60.0,
#   'name': 'Dodrio',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 60.0,
#   'special_defense': 60.0,
#   'speed': 100.0,
#   'total': 460.0},
#  87.0: {'attack': 45.0,
#   'defense': 55.0,
#   'hp': 65.0,
#   'name': 'Seel',
#   'pokemon_type': 'Water',
#   'special_attack': 45.0,
#   'special_defense': 70.0,
#   'speed': 45.0,
#   'total': 325.0},
#  88.0: {'attack': 70.0,
#   'defense': 80.0,
#   'hp': 90.0,
#   'name': 'Dewgong',
#   'pokemon_type': 'WaterIce',
#   'special_attack': 70.0,
#   'special_defense': 95.0,
#   'speed': 70.0,
#   'total': 475.0},
#  89.0: {'attack': 80.0,
#   'defense': 50.0,
#   'hp': 80.0,
#   'name': 'Grimer',
#   'pokemon_type': 'Poison',
#   'special_attack': 40.0,
#   'special_defense': 50.0,
#   'speed': 25.0,
#   'total': 325.0},
#  90.0: {'attack': 105.0,
#   'defense': 75.0,
#   'hp': 105.0,
#   'name': 'Muk',
#   'pokemon_type': 'Poison',
#   'special_attack': 65.0,
#   'special_defense': 100.0,
#   'speed': 50.0,
#   'total': 500.0},
#  91.0: {'attack': 65.0,
#   'defense': 100.0,
#   'hp': 30.0,
#   'name': 'Shellder',
#   'pokemon_type': 'Water',
#   'special_attack': 45.0,
#   'special_defense': 25.0,
#   'speed': 40.0,
#   'total': 305.0},
#  92.0: {'attack': 95.0,
#   'defense': 180.0,
#   'hp': 50.0,
#   'name': 'Cloyster',
#   'pokemon_type': 'WaterIce',
#   'special_attack': 85.0,
#   'special_defense': 45.0,
#   'speed': 70.0,
#   'total': 525.0},
#  93.0: {'attack': 35.0,
#   'defense': 30.0,
#   'hp': 30.0,
#   'name': 'Gastly',
#   'pokemon_type': 'GhostPoison',
#   'special_attack': 100.0,
#   'special_defense': 35.0,
#   'speed': 80.0,
#   'total': 310.0},
#  94.0: {'attack': 50.0,
#   'defense': 45.0,
#   'hp': 45.0,
#   'name': 'Haunter',
#   'pokemon_type': 'GhostPoison',
#   'special_attack': 115.0,
#   'special_defense': 55.0,
#   'speed': 95.0,
#   'total': 405.0},
#  94.1: {'attack': 65.0,
#   'defense': 60.0,
#   'hp': 60.0,
#   'name': 'Gengar',
#   'pokemon_type': 'GhostPoison',
#   'special_attack': 130.0,
#   'special_defense': 75.0,
#   'speed': 110.0,
#   'total': 500.0},
#  95.0: {'attack': 65.0,
#   'defense': 80.0,
#   'hp': 60.0,
#   'name': 'GengarMega Gengar',
#   'pokemon_type': 'GhostPoison',
#   'special_attack': 170.0,
#   'special_defense': 95.0,
#   'speed': 130.0,
#   'total': 600.0},
#  96.0: {'attack': 45.0,
#   'defense': 160.0,
#   'hp': 35.0,
#   'name': 'Onix',
#   'pokemon_type': 'RockGround',
#   'special_attack': 30.0,
#   'special_defense': 45.0,
#   'speed': 70.0,
#   'total': 385.0},
#  97.0: {'attack': 48.0,
#   'defense': 45.0,
#   'hp': 60.0,
#   'name': 'Drowzee',
#   'pokemon_type': 'Psychic',
#   'special_attack': 43.0,
#   'special_defense': 90.0,
#   'speed': 42.0,
#   'total': 328.0},
#  98.0: {'attack': 73.0,
#   'defense': 70.0,
#   'hp': 85.0,
#   'name': 'Hypno',
#   'pokemon_type': 'Psychic',
#   'special_attack': 73.0,
#   'special_defense': 115.0,
#   'speed': 67.0,
#   'total': 483.0},
#  99.0: {'attack': 105.0,
#   'defense': 90.0,
#   'hp': 30.0,
#   'name': 'Krabby',
#   'pokemon_type': 'Water',
#   'special_attack': 25.0,
#   'special_defense': 25.0,
#   'speed': 50.0,
#   'total': 325.0},
#  100.0: {'attack': 130.0,
#   'defense': 115.0,
#   'hp': 55.0,
#   'name': 'Kingler',
#   'pokemon_type': 'Water',
#   'special_attack': 50.0,
#   'special_defense': 50.0,
#   'speed': 75.0,
#   'total': 475.0},
#  101.0: {'attack': 30.0,
#   'defense': 50.0,
#   'hp': 40.0,
#   'name': 'Voltorb',
#   'pokemon_type': 'Electric',
#   'special_attack': 55.0,
#   'special_defense': 55.0,
#   'speed': 100.0,
#   'total': 330.0},
#  102.0: {'attack': 50.0,
#   'defense': 70.0,
#   'hp': 60.0,
#   'name': 'Electrode',
#   'pokemon_type': 'Electric',
#   'special_attack': 80.0,
#   'special_defense': 80.0,
#   'speed': 140.0,
#   'total': 480.0},
#  103.0: {'attack': 40.0,
#   'defense': 80.0,
#   'hp': 60.0,
#   'name': 'Exeggcute',
#   'pokemon_type': 'GrassPsychic',
#   'special_attack': 60.0,
#   'special_defense': 45.0,
#   'speed': 40.0,
#   'total': 325.0},
#  104.0: {'attack': 95.0,
#   'defense': 85.0,
#   'hp': 95.0,
#   'name': 'Exeggutor',
#   'pokemon_type': 'GrassPsychic',
#   'special_attack': 125.0,
#   'special_defense': 65.0,
#   'speed': 55.0,
#   'total': 520.0},
#  105.0: {'attack': 50.0,
#   'defense': 95.0,
#   'hp': 50.0,
#   'name': 'Cubone',
#   'pokemon_type': 'Ground',
#   'special_attack': 40.0,
#   'special_defense': 50.0,
#   'speed': 35.0,
#   'total': 320.0},
#  106.0: {'attack': 80.0,
#   'defense': 110.0,
#   'hp': 60.0,
#   'name': 'Marowak',
#   'pokemon_type': 'Ground',
#   'special_attack': 50.0,
#   'special_defense': 80.0,
#   'speed': 45.0,
#   'total': 425.0},
#  107.0: {'attack': 120.0,
#   'defense': 53.0,
#   'hp': 50.0,
#   'name': 'Hitmonlee',
#   'pokemon_type': 'Fighting',
#   'special_attack': 35.0,
#   'special_defense': 110.0,
#   'speed': 87.0,
#   'total': 455.0},
#  108.0: {'attack': 105.0,
#   'defense': 79.0,
#   'hp': 50.0,
#   'name': 'Hitmonchan',
#   'pokemon_type': 'Fighting',
#   'special_attack': 35.0,
#   'special_defense': 110.0,
#   'speed': 76.0,
#   'total': 455.0},
#  109.0: {'attack': 55.0,
#   'defense': 75.0,
#   'hp': 90.0,
#   'name': 'Lickitung',
#   'pokemon_type': 'Normal',
#   'special_attack': 60.0,
#   'special_defense': 75.0,
#   'speed': 30.0,
#   'total': 385.0},
#  110.0: {'attack': 65.0,
#   'defense': 95.0,
#   'hp': 40.0,
#   'name': 'Koffing',
#   'pokemon_type': 'Poison',
#   'special_attack': 60.0,
#   'special_defense': 45.0,
#   'speed': 35.0,
#   'total': 340.0},
#  111.0: {'attack': 90.0,
#   'defense': 120.0,
#   'hp': 65.0,
#   'name': 'Weezing',
#   'pokemon_type': 'Poison',
#   'special_attack': 85.0,
#   'special_defense': 70.0,
#   'speed': 60.0,
#   'total': 490.0},
#  112.0: {'attack': 85.0,
#   'defense': 95.0,
#   'hp': 80.0,
#   'name': 'Rhyhorn',
#   'pokemon_type': 'GroundRock',
#   'special_attack': 30.0,
#   'special_defense': 30.0,
#   'speed': 25.0,
#   'total': 345.0},
#  113.0: {'attack': 130.0,
#   'defense': 120.0,
#   'hp': 105.0,
#   'name': 'Rhydon',
#   'pokemon_type': 'GroundRock',
#   'special_attack': 45.0,
#   'special_defense': 45.0,
#   'speed': 40.0,
#   'total': 485.0},
#  114.0: {'attack': 5.0,
#   'defense': 5.0,
#   'hp': 250.0,
#   'name': 'Chansey',
#   'pokemon_type': 'Normal',
#   'special_attack': 35.0,
#   'special_defense': 105.0,
#   'speed': 50.0,
#   'total': 450.0},
#  115.0: {'attack': 55.0,
#   'defense': 115.0,
#   'hp': 65.0,
#   'name': 'Tangela',
#   'pokemon_type': 'Grass',
#   'special_attack': 100.0,
#   'special_defense': 40.0,
#   'speed': 60.0,
#   'total': 435.0},
#  115.1: {'attack': 95.0,
#   'defense': 80.0,
#   'hp': 105.0,
#   'name': 'Kangaskhan',
#   'pokemon_type': 'Normal',
#   'special_attack': 40.0,
#   'special_defense': 80.0,
#   'speed': 90.0,
#   'total': 490.0},
#  116.0: {'attack': 125.0,
#   'defense': 100.0,
#   'hp': 105.0,
#   'name': 'KangaskhanMega Kangaskhan',
#   'pokemon_type': 'Normal',
#   'special_attack': 60.0,
#   'special_defense': 100.0,
#   'speed': 100.0,
#   'total': 590.0},
#  117.0: {'attack': 40.0,
#   'defense': 70.0,
#   'hp': 30.0,
#   'name': 'Horsea',
#   'pokemon_type': 'Water',
#   'special_attack': 70.0,
#   'special_defense': 25.0,
#   'speed': 60.0,
#   'total': 295.0},
#  118.0: {'attack': 65.0,
#   'defense': 95.0,
#   'hp': 55.0,
#   'name': 'Seadra',
#   'pokemon_type': 'Water',
#   'special_attack': 95.0,
#   'special_defense': 45.0,
#   'speed': 85.0,
#   'total': 440.0},
#  119.0: {'attack': 67.0,
#   'defense': 60.0,
#   'hp': 45.0,
#   'name': 'Goldeen',
#   'pokemon_type': 'Water',
#   'special_attack': 35.0,
#   'special_defense': 50.0,
#   'speed': 63.0,
#   'total': 320.0},
#  120.0: {'attack': 92.0,
#   'defense': 65.0,
#   'hp': 80.0,
#   'name': 'Seaking',
#   'pokemon_type': 'Water',
#   'special_attack': 65.0,
#   'special_defense': 80.0,
#   'speed': 68.0,
#   'total': 450.0},
#  121.0: {'attack': 45.0,
#   'defense': 55.0,
#   'hp': 30.0,
#   'name': 'Staryu',
#   'pokemon_type': 'Water',
#   'special_attack': 70.0,
#   'special_defense': 55.0,
#   'speed': 85.0,
#   'total': 340.0},
#  122.0: {'attack': 75.0,
#   'defense': 85.0,
#   'hp': 60.0,
#   'name': 'Starmie',
#   'pokemon_type': 'WaterPsychic',
#   'special_attack': 100.0,
#   'special_defense': 85.0,
#   'speed': 115.0,
#   'total': 520.0},
#  123.0: {'attack': 45.0,
#   'defense': 65.0,
#   'hp': 40.0,
#   'name': 'Mr. Mime',
#   'pokemon_type': 'PsychicFairy',
#   'special_attack': 100.0,
#   'special_defense': 120.0,
#   'speed': 90.0,
#   'total': 460.0},
#  124.0: {'attack': 110.0,
#   'defense': 80.0,
#   'hp': 70.0,
#   'name': 'Scyther',
#   'pokemon_type': 'BugFlying',
#   'special_attack': 55.0,
#   'special_defense': 80.0,
#   'speed': 105.0,
#   'total': 500.0},
#  125.0: {'attack': 50.0,
#   'defense': 35.0,
#   'hp': 65.0,
#   'name': 'Jynx',
#   'pokemon_type': 'IcePsychic',
#   'special_attack': 115.0,
#   'special_defense': 95.0,
#   'speed': 95.0,
#   'total': 455.0},
#  126.0: {'attack': 83.0,
#   'defense': 57.0,
#   'hp': 65.0,
#   'name': 'Electabuzz',
#   'pokemon_type': 'Electric',
#   'special_attack': 95.0,
#   'special_defense': 85.0,
#   'speed': 105.0,
#   'total': 490.0},
#  127.0: {'attack': 95.0,
#   'defense': 57.0,
#   'hp': 65.0,
#   'name': 'Magmar',
#   'pokemon_type': 'Fire',
#   'special_attack': 100.0,
#   'special_defense': 85.0,
#   'speed': 93.0,
#   'total': 495.0},
#  127.1: {'attack': 125.0,
#   'defense': 100.0,
#   'hp': 65.0,
#   'name': 'Pinsir',
#   'pokemon_type': 'Bug',
#   'special_attack': 55.0,
#   'special_defense': 70.0,
#   'speed': 85.0,
#   'total': 500.0},
#  128.0: {'attack': 155.0,
#   'defense': 120.0,
#   'hp': 65.0,
#   'name': 'PinsirMega Pinsir',
#   'pokemon_type': 'BugFlying',
#   'special_attack': 65.0,
#   'special_defense': 90.0,
#   'speed': 105.0,
#   'total': 600.0},
#  129.0: {'attack': 100.0,
#   'defense': 95.0,
#   'hp': 75.0,
#   'name': 'Tauros',
#   'pokemon_type': 'Normal',
#   'special_attack': 40.0,
#   'special_defense': 70.0,
#   'speed': 110.0,
#   'total': 490.0},
#  130.0: {'attack': 10.0,
#   'defense': 55.0,
#   'hp': 20.0,
#   'name': 'Magikarp',
#   'pokemon_type': 'Water',
#   'special_attack': 15.0,
#   'special_defense': 20.0,
#   'speed': 80.0,
#   'total': 200.0},
#  130.1: {'attack': 125.0,
#   'defense': 79.0,
#   'hp': 95.0,
#   'name': 'Gyarados',
#   'pokemon_type': 'WaterFlying',
#   'special_attack': 60.0,
#   'special_defense': 100.0,
#   'speed': 81.0,
#   'total': 540.0},
#  131.0: {'attack': 155.0,
#   'defense': 109.0,
#   'hp': 95.0,
#   'name': 'GyaradosMega Gyarados',
#   'pokemon_type': 'WaterDark',
#   'special_attack': 70.0,
#   'special_defense': 130.0,
#   'speed': 81.0,
#   'total': 640.0},
#  132.0: {'attack': 85.0,
#   'defense': 80.0,
#   'hp': 130.0,
#   'name': 'Lapras',
#   'pokemon_type': 'WaterIce',
#   'special_attack': 85.0,
#   'special_defense': 95.0,
#   'speed': 60.0,
#   'total': 535.0},
#  133.0: {'attack': 48.0,
#   'defense': 48.0,
#   'hp': 48.0,
#   'name': 'Ditto',
#   'pokemon_type': 'Normal',
#   'special_attack': 48.0,
#   'special_defense': 48.0,
#   'speed': 48.0,
#   'total': 288.0},
#  134.0: {'attack': 55.0,
#   'defense': 50.0,
#   'hp': 55.0,
#   'name': 'Eevee',
#   'pokemon_type': 'Normal',
#   'special_attack': 45.0,
#   'special_defense': 65.0,
#   'speed': 55.0,
#   'total': 325.0},
#  135.0: {'attack': 65.0,
#   'defense': 60.0,
#   'hp': 130.0,
#   'name': 'Vaporeon',
#   'pokemon_type': 'Water',
#   'special_attack': 110.0,
#   'special_defense': 95.0,
#   'speed': 65.0,
#   'total': 525.0},
#  136.0: {'attack': 65.0,
#   'defense': 60.0,
#   'hp': 65.0,
#   'name': 'Jolteon',
#   'pokemon_type': 'Electric',
#   'special_attack': 110.0,
#   'special_defense': 95.0,
#   'speed': 130.0,
#   'total': 525.0},
#  137.0: {'attack': 130.0,
#   'defense': 60.0,
#   'hp': 65.0,
#   'name': 'Flareon',
#   'pokemon_type': 'Fire',
#   'special_attack': 95.0,
#   'special_defense': 110.0,
#   'speed': 65.0,
#   'total': 525.0},
#  138.0: {'attack': 60.0,
#   'defense': 70.0,
#   'hp': 65.0,
#   'name': 'Porygon',
#   'pokemon_type': 'Normal',
#   'special_attack': 85.0,
#   'special_defense': 75.0,
#   'speed': 40.0,
#   'total': 395.0},
#  139.0: {'attack': 40.0,
#   'defense': 100.0,
#   'hp': 35.0,
#   'name': 'Omanyte',
#   'pokemon_type': 'RockWater',
#   'special_attack': 90.0,
#   'special_defense': 55.0,
#   'speed': 35.0,
#   'total': 355.0},
#  140.0: {'attack': 60.0,
#   'defense': 125.0,
#   'hp': 70.0,
#   'name': 'Omastar',
#   'pokemon_type': 'RockWater',
#   'special_attack': 115.0,
#   'special_defense': 70.0,
#   'speed': 55.0,
#   'total': 495.0},
#  141.0: {'attack': 80.0,
#   'defense': 90.0,
#   'hp': 30.0,
#   'name': 'Kabuto',
#   'pokemon_type': 'RockWater',
#   'special_attack': 55.0,
#   'special_defense': 45.0,
#   'speed': 55.0,
#   'total': 355.0},
#  142.0: {'attack': 115.0,
#   'defense': 105.0,
#   'hp': 60.0,
#   'name': 'Kabutops',
#   'pokemon_type': 'RockWater',
#   'special_attack': 65.0,
#   'special_defense': 70.0,
#   'speed': 80.0,
#   'total': 495.0},
#  142.1: {'attack': 105.0,
#   'defense': 65.0,
#   'hp': 80.0,
#   'name': 'Aerodactyl',
#   'pokemon_type': 'RockFlying',
#   'special_attack': 60.0,
#   'special_defense': 75.0,
#   'speed': 130.0,
#   'total': 515.0},
#  143.0: {'attack': 135.0,
#   'defense': 85.0,
#   'hp': 80.0,
#   'name': 'AerodactylMega Aerodactyl',
#   'pokemon_type': 'RockFlying',
#   'special_attack': 70.0,
#   'special_defense': 95.0,
#   'speed': 150.0,
#   'total': 615.0},
#  144.0: {'attack': 110.0,
#   'defense': 65.0,
#   'hp': 160.0,
#   'name': 'Snorlax',
#   'pokemon_type': 'Normal',
#   'special_attack': 65.0,
#   'special_defense': 110.0,
#   'speed': 30.0,
#   'total': 540.0},
#  145.0: {'attack': 85.0,
#   'defense': 100.0,
#   'hp': 90.0,
#   'name': 'Articuno',
#   'pokemon_type': 'IceFlying',
#   'special_attack': 95.0,
#   'special_defense': 125.0,
#   'speed': 85.0,
#   'total': 580.0},
#  146.0: {'attack': 90.0,
#   'defense': 85.0,
#   'hp': 90.0,
#   'name': 'Zapdos',
#   'pokemon_type': 'ElectricFlying',
#   'special_attack': 125.0,
#   'special_defense': 90.0,
#   'speed': 100.0,
#   'total': 580.0},
#  147.0: {'attack': 100.0,
#   'defense': 90.0,
#   'hp': 90.0,
#   'name': 'Moltres',
#   'pokemon_type': 'FireFlying',
#   'special_attack': 125.0,
#   'special_defense': 85.0,
#   'speed': 90.0,
#   'total': 580.0},
#  148.0: {'attack': 64.0,
#   'defense': 45.0,
#   'hp': 41.0,
#   'name': 'Dratini',
#   'pokemon_type': 'Dragon',
#   'special_attack': 50.0,
#   'special_defense': 50.0,
#   'speed': 50.0,
#   'total': 300.0},
#  149.0: {'attack': 84.0,
#   'defense': 65.0,
#   'hp': 61.0,
#   'name': 'Dragonair',
#   'pokemon_type': 'Dragon',
#   'special_attack': 70.0,
#   'special_defense': 70.0,
#   'speed': 70.0,
#   'total': 420.0},
#  150.0: {'attack': 134.0,
#   'defense': 95.0,
#   'hp': 91.0,
#   'name': 'Dragonite',
#   'pokemon_type': 'DragonFlying',
#   'special_attack': 100.0,
#   'special_defense': 100.0,
#   'speed': 80.0,
#   'total': 600.0},
#  150.1: {'attack': 110.0,
#   'defense': 90.0,
#   'hp': 106.0,
#   'name': 'Mewtwo',
#   'pokemon_type': 'Psychic',
#   'special_attack': 154.0,
#   'special_defense': 90.0,
#   'speed': 130.0,
#   'total': 680.0},
#  150.2: {'attack': 190.0,
#   'defense': 100.0,
#   'hp': 126.0,
#   'name': 'MewtwoMega Mewtwo X',
#   'pokemon_type': 'PsychicFighting',
#   'special_attack': 154.0,
#   'special_defense': 100.0,
#   'speed': 130.0,
#   'total': 800.0},
#  151.0: {'attack': 150.0,
#   'defense': 70.0,
#   'hp': 106.0,
#   'name': 'MewtwoMega Mewtwo Y',
#   'pokemon_type': 'Psychic',
#   'special_attack': 194.0,
#   'special_defense': 120.0,
#   'speed': 140.0,
#   'total': 780.0},
#  152.0: {'attack': 100.0,
#   'defense': 100.0,
#   'hp': 100.0,
#   'name': 'Mew',
#   'pokemon_type': 'Psychic',
#   'special_attack': 100.0,
#   'special_defense': 100.0,
#   'speed': 100.0,
#   'total': 600.0},
#  153.0: {'attack': 49.0,
#   'defense': 65.0,
#   'hp': 45.0,
#   'name': 'Chikorita',
#   'pokemon_type': 'Grass',
#   'special_attack': 49.0,
#   'special_defense': 65.0,
#   'speed': 45.0,
#   'total': 318.0},
#  154.0: {'attack': 62.0,
#   'defense': 80.0,
#   'hp': 60.0,
#   'name': 'Bayleef',
#   'pokemon_type': 'Grass',
#   'special_attack': 63.0,
#   'special_defense': 80.0,
#   'speed': 60.0,
#   'total': 405.0},
#  155.0: {'attack': 82.0,
#   'defense': 100.0,
#   'hp': 80.0,
#   'name': 'Meganium',
#   'pokemon_type': 'Grass',
#   'special_attack': 83.0,
#   'special_defense': 100.0,
#   'speed': 80.0,
#   'total': 525.0},
#  156.0: {'attack': 52.0,
#   'defense': 43.0,
#   'hp': 39.0,
#   'name': 'Cyndaquil',
#   'pokemon_type': 'Fire',
#   'special_attack': 60.0,
#   'special_defense': 50.0,
#   'speed': 65.0,
#   'total': 309.0},
#  157.0: {'attack': 64.0,
#   'defense': 58.0,
#   'hp': 58.0,
#   'name': 'Quilava',
#   'pokemon_type': 'Fire',
#   'special_attack': 80.0,
#   'special_defense': 65.0,
#   'speed': 80.0,
#   'total': 405.0},
#  158.0: {'attack': 84.0,
#   'defense': 78.0,
#   'hp': 78.0,
#   'name': 'Typhlosion',
#   'pokemon_type': 'Fire',
#   'special_attack': 109.0,
#   'special_defense': 85.0,
#   'speed': 100.0,
#   'total': 534.0},
#  159.0: {'attack': 65.0,
#   'defense': 64.0,
#   'hp': 50.0,
#   'name': 'Totodile',
#   'pokemon_type': 'Water',
#   'special_attack': 44.0,
#   'special_defense': 48.0,
#   'speed': 43.0,
#   'total': 314.0},
#  160.0: {'attack': 80.0,
#   'defense': 80.0,
#   'hp': 65.0,
#   'name': 'Croconaw',
#   'pokemon_type': 'Water',
#   'special_attack': 59.0,
#   'special_defense': 63.0,
#   'speed': 58.0,
#   'total': 405.0},
#  161.0: {'attack': 105.0,
#   'defense': 100.0,
#   'hp': 85.0,
#   'name': 'Feraligatr',
#   'pokemon_type': 'Water',
#   'special_attack': 79.0,
#   'special_defense': 83.0,
#   'speed': 78.0,
#   'total': 530.0},
#  162.0: {'attack': 46.0,
#   'defense': 34.0,
#   'hp': 35.0,
#   'name': 'Sentret',
#   'pokemon_type': 'Normal',
#   'special_attack': 35.0,
#   'special_defense': 45.0,
#   'speed': 20.0,
#   'total': 215.0},
#  163.0: {'attack': 76.0,
#   'defense': 64.0,
#   'hp': 85.0,
#   'name': 'Furret',
#   'pokemon_type': 'Normal',
#   'special_attack': 45.0,
#   'special_defense': 55.0,
#   'speed': 90.0,
#   'total': 415.0},
#  164.0: {'attack': 30.0,
#   'defense': 30.0,
#   'hp': 60.0,
#   'name': 'Hoothoot',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 36.0,
#   'special_defense': 56.0,
#   'speed': 50.0,
#   'total': 262.0},
#  165.0: {'attack': 50.0,
#   'defense': 50.0,
#   'hp': 100.0,
#   'name': 'Noctowl',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 76.0,
#   'special_defense': 96.0,
#   'speed': 70.0,
#   'total': 442.0},
#  166.0: {'attack': 20.0,
#   'defense': 30.0,
#   'hp': 40.0,
#   'name': 'Ledyba',
#   'pokemon_type': 'BugFlying',
#   'special_attack': 40.0,
#   'special_defense': 80.0,
#   'speed': 55.0,
#   'total': 265.0},
#  167.0: {'attack': 35.0,
#   'defense': 50.0,
#   'hp': 55.0,
#   'name': 'Ledian',
#   'pokemon_type': 'BugFlying',
#   'special_attack': 55.0,
#   'special_defense': 110.0,
#   'speed': 85.0,
#   'total': 390.0},
#  168.0: {'attack': 60.0,
#   'defense': 40.0,
#   'hp': 40.0,
#   'name': 'Spinarak',
#   'pokemon_type': 'BugPoison',
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 30.0,
#   'total': 250.0},
#  169.0: {'attack': 90.0,
#   'defense': 70.0,
#   'hp': 70.0,
#   'name': 'Ariados',
#   'pokemon_type': 'BugPoison',
#   'special_attack': 60.0,
#   'special_defense': 60.0,
#   'speed': 40.0,
#   'total': 390.0},
#  170.0: {'attack': 90.0,
#   'defense': 80.0,
#   'hp': 85.0,
#   'name': 'Crobat',
#   'pokemon_type': 'PoisonFlying',
#   'special_attack': 70.0,
#   'special_defense': 80.0,
#   'speed': 130.0,
#   'total': 535.0},
#  171.0: {'attack': 38.0,
#   'defense': 38.0,
#   'hp': 75.0,
#   'name': 'Chinchou',
#   'pokemon_type': 'WaterElectric',
#   'special_attack': 56.0,
#   'special_defense': 56.0,
#   'speed': 67.0,
#   'total': 330.0},
#  172.0: {'attack': 58.0,
#   'defense': 58.0,
#   'hp': 125.0,
#   'name': 'Lanturn',
#   'pokemon_type': 'WaterElectric',
#   'special_attack': 76.0,
#   'special_defense': 76.0,
#   'speed': 67.0,
#   'total': 460.0},
#  173.0: {'attack': 40.0,
#   'defense': 15.0,
#   'hp': 20.0,
#   'name': 'Pichu',
#   'pokemon_type': 'Electric',
#   'special_attack': 35.0,
#   'special_defense': 35.0,
#   'speed': 60.0,
#   'total': 205.0},
#  174.0: {'attack': 25.0,
#   'defense': 28.0,
#   'hp': 50.0,
#   'name': 'Cleffa',
#   'pokemon_type': 'Fairy',
#   'special_attack': 45.0,
#   'special_defense': 55.0,
#   'speed': 15.0,
#   'total': 218.0},
#  175.0: {'attack': 30.0,
#   'defense': 15.0,
#   'hp': 90.0,
#   'name': 'Igglybuff',
#   'pokemon_type': 'NormalFairy',
#   'special_attack': 40.0,
#   'special_defense': 20.0,
#   'speed': 15.0,
#   'total': 210.0},
#  176.0: {'attack': 20.0,
#   'defense': 65.0,
#   'hp': 35.0,
#   'name': 'Togepi',
#   'pokemon_type': 'Fairy',
#   'special_attack': 40.0,
#   'special_defense': 65.0,
#   'speed': 20.0,
#   'total': 245.0},
#  177.0: {'attack': 40.0,
#   'defense': 85.0,
#   'hp': 55.0,
#   'name': 'Togetic',
#   'pokemon_type': 'FairyFlying',
#   'special_attack': 80.0,
#   'special_defense': 105.0,
#   'speed': 40.0,
#   'total': 405.0},
#  178.0: {'attack': 50.0,
#   'defense': 45.0,
#   'hp': 40.0,
#   'name': 'Natu',
#   'pokemon_type': 'PsychicFlying',
#   'special_attack': 70.0,
#   'special_defense': 45.0,
#   'speed': 70.0,
#   'total': 320.0},
#  179.0: {'attack': 75.0,
#   'defense': 70.0,
#   'hp': 65.0,
#   'name': 'Xatu',
#   'pokemon_type': 'PsychicFlying',
#   'special_attack': 95.0,
#   'special_defense': 70.0,
#   'speed': 95.0,
#   'total': 470.0},
#  180.0: {'attack': 40.0,
#   'defense': 40.0,
#   'hp': 55.0,
#   'name': 'Mareep',
#   'pokemon_type': 'Electric',
#   'special_attack': 65.0,
#   'special_defense': 45.0,
#   'speed': 35.0,
#   'total': 280.0},
#  181.0: {'attack': 55.0,
#   'defense': 55.0,
#   'hp': 70.0,
#   'name': 'Flaaffy',
#   'pokemon_type': 'Electric',
#   'special_attack': 80.0,
#   'special_defense': 60.0,
#   'speed': 45.0,
#   'total': 365.0},
#  181.1: {'attack': 75.0,
#   'defense': 85.0,
#   'hp': 90.0,
#   'name': 'Ampharos',
#   'pokemon_type': 'Electric',
#   'special_attack': 115.0,
#   'special_defense': 90.0,
#   'speed': 55.0,
#   'total': 510.0},
#  182.0: {'attack': 95.0,
#   'defense': 105.0,
#   'hp': 90.0,
#   'name': 'AmpharosMega Ampharos',
#   'pokemon_type': 'ElectricDragon',
#   'special_attack': 165.0,
#   'special_defense': 110.0,
#   'speed': 45.0,
#   'total': 610.0},
#  183.0: {'attack': 80.0,
#   'defense': 95.0,
#   'hp': 75.0,
#   'name': 'Bellossom',
#   'pokemon_type': 'Grass',
#   'special_attack': 90.0,
#   'special_defense': 100.0,
#   'speed': 50.0,
#   'total': 490.0},
#  184.0: {'attack': 20.0,
#   'defense': 50.0,
#   'hp': 70.0,
#   'name': 'Marill',
#   'pokemon_type': 'WaterFairy',
#   'special_attack': 20.0,
#   'special_defense': 50.0,
#   'speed': 40.0,
#   'total': 250.0},
#  185.0: {'attack': 50.0,
#   'defense': 80.0,
#   'hp': 100.0,
#   'name': 'Azumarill',
#   'pokemon_type': 'WaterFairy',
#   'special_attack': 60.0,
#   'special_defense': 80.0,
#   'speed': 50.0,
#   'total': 420.0},
#  186.0: {'attack': 100.0,
#   'defense': 115.0,
#   'hp': 70.0,
#   'name': 'Sudowoodo',
#   'pokemon_type': 'Rock',
#   'special_attack': 30.0,
#   'special_defense': 65.0,
#   'speed': 30.0,
#   'total': 410.0},
#  187.0: {'attack': 75.0,
#   'defense': 75.0,
#   'hp': 90.0,
#   'name': 'Politoed',
#   'pokemon_type': 'Water',
#   'special_attack': 90.0,
#   'special_defense': 100.0,
#   'speed': 70.0,
#   'total': 500.0},
#  188.0: {'attack': 35.0,
#   'defense': 40.0,
#   'hp': 35.0,
#   'name': 'Hoppip',
#   'pokemon_type': 'GrassFlying',
#   'special_attack': 35.0,
#   'special_defense': 55.0,
#   'speed': 50.0,
#   'total': 250.0},
#  189.0: {'attack': 45.0,
#   'defense': 50.0,
#   'hp': 55.0,
#   'name': 'Skiploom',
#   'pokemon_type': 'GrassFlying',
#   'special_attack': 45.0,
#   'special_defense': 65.0,
#   'speed': 80.0,
#   'total': 340.0},
#  190.0: {'attack': 55.0,
#   'defense': 70.0,
#   'hp': 75.0,
#   'name': 'Jumpluff',
#   'pokemon_type': 'GrassFlying',
#   'special_attack': 55.0,
#   'special_defense': 95.0,
#   'speed': 110.0,
#   'total': 460.0},
#  191.0: {'attack': 70.0,
#   'defense': 55.0,
#   'hp': 55.0,
#   'name': 'Aipom',
#   'pokemon_type': 'Normal',
#   'special_attack': 40.0,
#   'special_defense': 55.0,
#   'speed': 85.0,
#   'total': 360.0},
#  192.0: {'attack': 30.0,
#   'defense': 30.0,
#   'hp': 30.0,
#   'name': 'Sunkern',
#   'pokemon_type': 'Grass',
#   'special_attack': 30.0,
#   'special_defense': 30.0,
#   'speed': 30.0,
#   'total': 180.0},
#  193.0: {'attack': 75.0,
#   'defense': 55.0,
#   'hp': 75.0,
#   'name': 'Sunflora',
#   'pokemon_type': 'Grass',
#   'special_attack': 105.0,
#   'special_defense': 85.0,
#   'speed': 30.0,
#   'total': 425.0},
#  194.0: {'attack': 65.0,
#   'defense': 45.0,
#   'hp': 65.0,
#   'name': 'Yanma',
#   'pokemon_type': 'BugFlying',
#   'special_attack': 75.0,
#   'special_defense': 45.0,
#   'speed': 95.0,
#   'total': 390.0},
#  195.0: {'attack': 45.0,
#   'defense': 45.0,
#   'hp': 55.0,
#   'name': 'Wooper',
#   'pokemon_type': 'WaterGround',
#   'special_attack': 25.0,
#   'special_defense': 25.0,
#   'speed': 15.0,
#   'total': 210.0},
#  196.0: {'attack': 85.0,
#   'defense': 85.0,
#   'hp': 95.0,
#   'name': 'Quagsire',
#   'pokemon_type': 'WaterGround',
#   'special_attack': 65.0,
#   'special_defense': 65.0,
#   'speed': 35.0,
#   'total': 430.0},
#  197.0: {'attack': 65.0,
#   'defense': 60.0,
#   'hp': 65.0,
#   'name': 'Espeon',
#   'pokemon_type': 'Psychic',
#   'special_attack': 130.0,
#   'special_defense': 95.0,
#   'speed': 110.0,
#   'total': 525.0},
#  198.0: {'attack': 65.0,
#   'defense': 110.0,
#   'hp': 95.0,
#   'name': 'Umbreon',
#   'pokemon_type': 'Dark',
#   'special_attack': 60.0,
#   'special_defense': 130.0,
#   'speed': 65.0,
#   'total': 525.0},
#  199.0: {'attack': 85.0,
#   'defense': 42.0,
#   'hp': 60.0,
#   'name': 'Murkrow',
#   'pokemon_type': 'DarkFlying',
#   'special_attack': 85.0,
#   'special_defense': 42.0,
#   'speed': 91.0,
#   'total': 405.0},
#  200.0: {'attack': 75.0,
#   'defense': 80.0,
#   'hp': 95.0,
#   'name': 'Slowking',
#   'pokemon_type': 'WaterPsychic',
#   'special_attack': 100.0,
#   'special_defense': 110.0,
#   'speed': 30.0,
#   'total': 490.0},
#  201.0: {'attack': 60.0,
#   'defense': 60.0,
#   'hp': 60.0,
#   'name': 'Misdreavus',
#   'pokemon_type': 'Ghost',
#   'special_attack': 85.0,
#   'special_defense': 85.0,
#   'speed': 85.0,
#   'total': 435.0},
#  202.0: {'attack': 72.0,
#   'defense': 48.0,
#   'hp': 48.0,
#   'name': 'Unown',
#   'pokemon_type': 'Psychic',
#   'special_attack': 72.0,
#   'special_defense': 48.0,
#   'speed': 48.0,
#   'total': 336.0},
#  203.0: {'attack': 33.0,
#   'defense': 58.0,
#   'hp': 190.0,
#   'name': 'Wobbuffet',
#   'pokemon_type': 'Psychic',
#   'special_attack': 33.0,
#   'special_defense': 58.0,
#   'speed': 33.0,
#   'total': 405.0},
#  204.0: {'attack': 80.0,
#   'defense': 65.0,
#   'hp': 70.0,
#   'name': 'Girafarig',
#   'pokemon_type': 'NormalPsychic',
#   'special_attack': 90.0,
#   'special_defense': 65.0,
#   'speed': 85.0,
#   'total': 455.0},
#  205.0: {'attack': 65.0,
#   'defense': 90.0,
#   'hp': 50.0,
#   'name': 'Pineco',
#   'pokemon_type': 'Bug',
#   'special_attack': 35.0,
#   'special_defense': 35.0,
#   'speed': 15.0,
#   'total': 290.0},
#  206.0: {'attack': 90.0,
#   'defense': 140.0,
#   'hp': 75.0,
#   'name': 'Forretress',
#   'pokemon_type': 'BugSteel',
#   'special_attack': 60.0,
#   'special_defense': 60.0,
#   'speed': 40.0,
#   'total': 465.0},
#  207.0: {'attack': 70.0,
#   'defense': 70.0,
#   'hp': 100.0,
#   'name': 'Dunsparce',
#   'pokemon_type': 'Normal',
#   'special_attack': 65.0,
#   'special_defense': 65.0,
#   'speed': 45.0,
#   'total': 415.0},
#  208.0: {'attack': 75.0,
#   'defense': 105.0,
#   'hp': 65.0,
#   'name': 'Gligar',
#   'pokemon_type': 'GroundFlying',
#   'special_attack': 35.0,
#   'special_defense': 65.0,
#   'speed': 85.0,
#   'total': 430.0},
#  208.1: {'attack': 85.0,
#   'defense': 200.0,
#   'hp': 75.0,
#   'name': 'Steelix',
#   'pokemon_type': 'SteelGround',
#   'special_attack': 55.0,
#   'special_defense': 65.0,
#   'speed': 30.0,
#   'total': 510.0},
#  209.0: {'attack': 125.0,
#   'defense': 230.0,
#   'hp': 75.0,
#   'name': 'SteelixMega Steelix',
#   'pokemon_type': 'SteelGround',
#   'special_attack': 55.0,
#   'special_defense': 95.0,
#   'speed': 30.0,
#   'total': 610.0},
#  210.0: {'attack': 80.0,
#   'defense': 50.0,
#   'hp': 60.0,
#   'name': 'Snubbull',
#   'pokemon_type': 'Fairy',
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 30.0,
#   'total': 300.0},
#  211.0: {'attack': 120.0,
#   'defense': 75.0,
#   'hp': 90.0,
#   'name': 'Granbull',
#   'pokemon_type': 'Fairy',
#   'special_attack': 60.0,
#   'special_defense': 60.0,
#   'speed': 45.0,
#   'total': 450.0},
#  212.0: {'attack': 95.0,
#   'defense': 75.0,
#   'hp': 65.0,
#   'name': 'Qwilfish',
#   'pokemon_type': 'WaterPoison',
#   'special_attack': 55.0,
#   'special_defense': 55.0,
#   'speed': 85.0,
#   'total': 430.0},
#  212.1: {'attack': 130.0,
#   'defense': 100.0,
#   'hp': 70.0,
#   'name': 'Scizor',
#   'pokemon_type': 'BugSteel',
#   'special_attack': 55.0,
#   'special_defense': 80.0,
#   'speed': 65.0,
#   'total': 500.0},
#  213.0: {'attack': 150.0,
#   'defense': 140.0,
#   'hp': 70.0,
#   'name': 'ScizorMega Scizor',
#   'pokemon_type': 'BugSteel',
#   'special_attack': 65.0,
#   'special_defense': 100.0,
#   'speed': 75.0,
#   'total': 600.0},
#  214.0: {'attack': 10.0,
#   'defense': 230.0,
#   'hp': 20.0,
#   'name': 'Shuckle',
#   'pokemon_type': 'BugRock',
#   'special_attack': 10.0,
#   'special_defense': 230.0,
#   'speed': 5.0,
#   'total': 505.0},
#  214.1: {'attack': 125.0,
#   'defense': 75.0,
#   'hp': 80.0,
#   'name': 'Heracross',
#   'pokemon_type': 'BugFighting',
#   'special_attack': 40.0,
#   'special_defense': 95.0,
#   'speed': 85.0,
#   'total': 500.0},
#  215.0: {'attack': 185.0,
#   'defense': 115.0,
#   'hp': 80.0,
#   'name': 'HeracrossMega Heracross',
#   'pokemon_type': 'BugFighting',
#   'special_attack': 40.0,
#   'special_defense': 105.0,
#   'speed': 75.0,
#   'total': 600.0},
#  216.0: {'attack': 95.0,
#   'defense': 55.0,
#   'hp': 55.0,
#   'name': 'Sneasel',
#   'pokemon_type': 'DarkIce',
#   'special_attack': 35.0,
#   'special_defense': 75.0,
#   'speed': 115.0,
#   'total': 430.0},
#  217.0: {'attack': 80.0,
#   'defense': 50.0,
#   'hp': 60.0,
#   'name': 'Teddiursa',
#   'pokemon_type': 'Normal',
#   'special_attack': 50.0,
#   'special_defense': 50.0,
#   'speed': 40.0,
#   'total': 330.0},
#  218.0: {'attack': 130.0,
#   'defense': 75.0,
#   'hp': 90.0,
#   'name': 'Ursaring',
#   'pokemon_type': 'Normal',
#   'special_attack': 75.0,
#   'special_defense': 75.0,
#   'speed': 55.0,
#   'total': 500.0},
#  219.0: {'attack': 40.0,
#   'defense': 40.0,
#   'hp': 40.0,
#   'name': 'Slugma',
#   'pokemon_type': 'Fire',
#   'special_attack': 70.0,
#   'special_defense': 40.0,
#   'speed': 20.0,
#   'total': 250.0},
#  220.0: {'attack': 50.0,
#   'defense': 120.0,
#   'hp': 50.0,
#   'name': 'Magcargo',
#   'pokemon_type': 'FireRock',
#   'special_attack': 80.0,
#   'special_defense': 80.0,
#   'speed': 30.0,
#   'total': 410.0},
#  221.0: {'attack': 50.0,
#   'defense': 40.0,
#   'hp': 50.0,
#   'name': 'Swinub',
#   'pokemon_type': 'IceGround',
#   'special_attack': 30.0,
#   'special_defense': 30.0,
# ...
#  653.0: {'attack': 107.0,
#   'defense': 122.0,
#   'hp': 88.0,
#   'name': 'Chesnaught',
#   'pokemon_type': 'GrassFighting',
#   'special_attack': 74.0,
#   'special_defense': 75.0,
#   'speed': 64.0,
#   'total': 530.0},
#  654.0: {'attack': 45.0,
#   'defense': 40.0,
#   'hp': 40.0,
#   'name': 'Fennekin',
#   'pokemon_type': 'Fire',
#   'special_attack': 62.0,
#   'special_defense': 60.0,
#   'speed': 60.0,
#   'total': 307.0},
#  655.0: {'attack': 59.0,
#   'defense': 58.0,
#   'hp': 59.0,
#   'name': 'Braixen',
#   'pokemon_type': 'Fire',
#   'special_attack': 90.0,
#   'special_defense': 70.0,
#   'speed': 73.0,
#   'total': 409.0},
#  656.0: {'attack': 69.0,
#   'defense': 72.0,
#   'hp': 75.0,
#   'name': 'Delphox',
#   'pokemon_type': 'FirePsychic',
#   'special_attack': 114.0,
#   'special_defense': 100.0,
#   'speed': 104.0,
#   'total': 534.0},
#  657.0: {'attack': 56.0,
#   'defense': 40.0,
#   'hp': 41.0,
#   'name': 'Froakie',
#   'pokemon_type': 'Water',
#   'special_attack': 62.0,
#   'special_defense': 44.0,
#   'speed': 71.0,
#   'total': 314.0},
#  658.0: {'attack': 63.0,
#   'defense': 52.0,
#   'hp': 54.0,
#   'name': 'Frogadier',
#   'pokemon_type': 'Water',
#   'special_attack': 83.0,
#   'special_defense': 56.0,
#   'speed': 97.0,
#   'total': 405.0},
#  659.0: {'attack': 95.0,
#   'defense': 67.0,
#   'hp': 72.0,
#   'name': 'Greninja',
#   'pokemon_type': 'WaterDark',
#   'special_attack': 103.0,
#   'special_defense': 71.0,
#   'speed': 122.0,
#   'total': 530.0},
#  660.0: {'attack': 36.0,
#   'defense': 38.0,
#   'hp': 38.0,
#   'name': 'Bunnelby',
#   'pokemon_type': 'Normal',
#   'special_attack': 32.0,
#   'special_defense': 36.0,
#   'speed': 57.0,
#   'total': 237.0},
#  661.0: {'attack': 56.0,
#   'defense': 77.0,
#   'hp': 85.0,
#   'name': 'Diggersby',
#   'pokemon_type': 'NormalGround',
#   'special_attack': 50.0,
#   'special_defense': 77.0,
#   'speed': 78.0,
#   'total': 423.0},
#  662.0: {'attack': 50.0,
#   'defense': 43.0,
#   'hp': 45.0,
#   'name': 'Fletchling',
#   'pokemon_type': 'NormalFlying',
#   'special_attack': 40.0,
#   'special_defense': 38.0,
#   'speed': 62.0,
#   'total': 278.0},
#  663.0: {'attack': 73.0,
#   'defense': 55.0,
#   'hp': 62.0,
#   'name': 'Fletchinder',
#   'pokemon_type': 'FireFlying',
#   'special_attack': 56.0,
#   'special_defense': 52.0,
#   'speed': 84.0,
#   'total': 382.0},
#  664.0: {'attack': 81.0,
#   'defense': 71.0,
#   'hp': 78.0,
#   'name': 'Talonflame',
#   'pokemon_type': 'FireFlying',
#   'special_attack': 74.0,
#   'special_defense': 69.0,
#   'speed': 126.0,
#   'total': 499.0},
#  665.0: {'attack': 35.0,
#   'defense': 40.0,
#   'hp': 38.0,
#   'name': 'Scatterbug',
#   'pokemon_type': 'Bug',
#   'special_attack': 27.0,
#   'special_defense': 25.0,
#   'speed': 35.0,
#   'total': 200.0},
#  666.0: {'attack': 22.0,
#   'defense': 60.0,
#   'hp': 45.0,
#   'name': 'Spewpa',
#   'pokemon_type': 'Bug',
#   'special_attack': 27.0,
#   'special_defense': 30.0,
#   'speed': 29.0,
#   'total': 213.0},
#  667.0: {'attack': 52.0,
#   'defense': 50.0,
#   'hp': 80.0,
#   'name': 'Vivillon',
#   'pokemon_type': 'BugFlying',
#   'special_attack': 90.0,
#   'special_defense': 50.0,
#   'speed': 89.0,
#   'total': 411.0},
#  668.0: {'attack': 50.0,
#   'defense': 58.0,
#   'hp': 62.0,
#   'name': 'Litleo',
#   'pokemon_type': 'FireNormal',
#   'special_attack': 73.0,
#   'special_defense': 54.0,
#   'speed': 72.0,
#   'total': 369.0},
#  669.0: {'attack': 68.0,
#   'defense': 72.0,
#   'hp': 86.0,
#   'name': 'Pyroar',
#   'pokemon_type': 'FireNormal',
#   'special_attack': 109.0,
#   'special_defense': 66.0,
#   'speed': 106.0,
#   'total': 507.0},
#  670.0: {'attack': 38.0,
#   'defense': 39.0,
#   'hp': 44.0,
#   'name': 'Flabebe',
#   'pokemon_type': 'Fairy',
#   'special_attack': 61.0,
#   'special_defense': 79.0,
#   'speed': 42.0,
#   'total': 303.0},
#  671.0: {'attack': 45.0,
#   'defense': 47.0,
#   'hp': 54.0,
#   'name': 'Floette',
#   'pokemon_type': 'Fairy',
#   'special_attack': 75.0,
#   'special_defense': 98.0,
#   'speed': 52.0,
#   'total': 371.0},
#  672.0: {'attack': 65.0,
#   'defense': 68.0,
#   'hp': 78.0,
#   'name': 'Florges',
#   'pokemon_type': 'Fairy',
#   'special_attack': 112.0,
#   'special_defense': 154.0,
#   'speed': 75.0,
#   'total': 552.0},
#  673.0: {'attack': 65.0,
#   'defense': 48.0,
#   'hp': 66.0,
#   'name': 'Skiddo',
#   'pokemon_type': 'Grass',
#   'special_attack': 62.0,
#   'special_defense': 57.0,
#   'speed': 52.0,
#   'total': 350.0},
#  674.0: {'attack': 100.0,
#   'defense': 62.0,
#   'hp': 123.0,
#   'name': 'Gogoat',
#   'pokemon_type': 'Grass',
#   'special_attack': 97.0,
#   'special_defense': 81.0,
#   'speed': 68.0,
#   'total': 531.0},
#  675.0: {'attack': 82.0,
#   'defense': 62.0,
#   'hp': 67.0,
#   'name': 'Pancham',
#   'pokemon_type': 'Fighting',
#   'special_attack': 46.0,
#   'special_defense': 48.0,
#   'speed': 43.0,
#   'total': 348.0},
#  676.0: {'attack': 124.0,
#   'defense': 78.0,
#   'hp': 95.0,
#   'name': 'Pangoro',
#   'pokemon_type': 'FightingDark',
#   'special_attack': 69.0,
#   'special_defense': 71.0,
#   'speed': 58.0,
#   'total': 495.0},
#  677.0: {'attack': 80.0,
#   'defense': 60.0,
#   'hp': 75.0,
#   'name': 'Furfrou',
#   'pokemon_type': 'Normal',
#   'special_attack': 65.0,
#   'special_defense': 90.0,
#   'speed': 102.0,
#   'total': 472.0},
#  678.0: {'attack': 48.0,
#   'defense': 54.0,
#   'hp': 62.0,
#   'name': 'Espurr',
#   'pokemon_type': 'Psychic',
#   'special_attack': 63.0,
#   'special_defense': 60.0,
#   'speed': 68.0,
#   'total': 355.0},
#  678.1: {'attack': 48.0,
#   'defense': 76.0,
#   'hp': 74.0,
#   'name': 'MeowsticMale',
#   'pokemon_type': 'Psychic',
#   'special_attack': 83.0,
#   'special_defense': 81.0,
#   'speed': 104.0,
#   'total': 466.0},
#  679.0: {'attack': 48.0,
#   'defense': 76.0,
#   'hp': 74.0,
#   'name': 'MeowsticFemale',
#   'pokemon_type': 'Psychic',
#   'special_attack': 83.0,
#   'special_defense': 81.0,
#   'speed': 104.0,
#   'total': 466.0},
#  680.0: {'attack': 80.0,
#   'defense': 100.0,
#   'hp': 45.0,
#   'name': 'Honedge',
#   'pokemon_type': 'SteelGhost',
#   'special_attack': 35.0,
#   'special_defense': 37.0,
#   'speed': 28.0,
#   'total': 325.0},
#  681.0: {'attack': 110.0,
#   'defense': 150.0,
#   'hp': 59.0,
#   'name': 'Doublade',
#   'pokemon_type': 'SteelGhost',
#   'special_attack': 45.0,
#   'special_defense': 49.0,
#   'speed': 35.0,
#   'total': 448.0},
#  681.1: {'attack': 150.0,
#   'defense': 50.0,
#   'hp': 60.0,
#   'name': 'AegislashBlade Forme',
#   'pokemon_type': 'SteelGhost',
#   'special_attack': 150.0,
#   'special_defense': 50.0,
#   'speed': 60.0,
#   'total': 520.0},
#  682.0: {'attack': 50.0,
#   'defense': 150.0,
#   'hp': 60.0,
#   'name': 'AegislashShield Forme',
#   'pokemon_type': 'SteelGhost',
#   'special_attack': 50.0,
#   'special_defense': 150.0,
#   'speed': 60.0,
#   'total': 520.0},
#  683.0: {'attack': 52.0,
#   'defense': 60.0,
#   'hp': 78.0,
#   'name': 'Spritzee',
#   'pokemon_type': 'Fairy',
#   'special_attack': 63.0,
#   'special_defense': 65.0,
#   'speed': 23.0,
#   'total': 341.0},
#  684.0: {'attack': 72.0,
#   'defense': 72.0,
#   'hp': 101.0,
#   'name': 'Aromatisse',
#   'pokemon_type': 'Fairy',
#   'special_attack': 99.0,
#   'special_defense': 89.0,
#   'speed': 29.0,
#   'total': 462.0},
#  685.0: {'attack': 48.0,
#   'defense': 66.0,
#   'hp': 62.0,
#   'name': 'Swirlix',
#   'pokemon_type': 'Fairy',
#   'special_attack': 59.0,
#   'special_defense': 57.0,
#   'speed': 49.0,
#   'total': 341.0},
#  686.0: {'attack': 80.0,
#   'defense': 86.0,
#   'hp': 82.0,
#   'name': 'Slurpuff',
#   'pokemon_type': 'Fairy',
#   'special_attack': 85.0,
#   'special_defense': 75.0,
#   'speed': 72.0,
#   'total': 480.0},
#  687.0: {'attack': 54.0,
#   'defense': 53.0,
#   'hp': 53.0,
#   'name': 'Inkay',
#   'pokemon_type': 'DarkPsychic',
#   'special_attack': 37.0,
#   'special_defense': 46.0,
#   'speed': 45.0,
#   'total': 288.0},
#  688.0: {'attack': 92.0,
#   'defense': 88.0,
#   'hp': 86.0,
#   'name': 'Malamar',
#   'pokemon_type': 'DarkPsychic',
#   'special_attack': 68.0,
#   'special_defense': 75.0,
#   'speed': 73.0,
#   'total': 482.0},
#  689.0: {'attack': 52.0,
#   'defense': 67.0,
#   'hp': 42.0,
#   'name': 'Binacle',
#   'pokemon_type': 'RockWater',
#   'special_attack': 39.0,
#   'special_defense': 56.0,
#   'speed': 50.0,
#   'total': 306.0},
#  690.0: {'attack': 105.0,
#   'defense': 115.0,
#   'hp': 72.0,
#   'name': 'Barbaracle',
#   'pokemon_type': 'RockWater',
#   'special_attack': 54.0,
#   'special_defense': 86.0,
#   'speed': 68.0,
#   'total': 500.0},
#  691.0: {'attack': 60.0,
#   'defense': 60.0,
#   'hp': 50.0,
#   'name': 'Skrelp',
#   'pokemon_type': 'PoisonWater',
#   'special_attack': 60.0,
#   'special_defense': 60.0,
#   'speed': 30.0,
#   'total': 320.0},
#  692.0: {'attack': 75.0,
#   'defense': 90.0,
#   'hp': 65.0,
#   'name': 'Dragalge',
#   'pokemon_type': 'PoisonDragon',
#   'special_attack': 97.0,
#   'special_defense': 123.0,
#   'speed': 44.0,
#   'total': 494.0},
#  693.0: {'attack': 53.0,
#   'defense': 62.0,
#   'hp': 50.0,
#   'name': 'Clauncher',
#   'pokemon_type': 'Water',
#   'special_attack': 58.0,
#   'special_defense': 63.0,
#   'speed': 44.0,
#   'total': 330.0},
#  694.0: {'attack': 73.0,
#   'defense': 88.0,
#   'hp': 71.0,
#   'name': 'Clawitzer',
#   'pokemon_type': 'Water',
#   'special_attack': 120.0,
#   'special_defense': 89.0,
#   'speed': 59.0,
#   'total': 500.0},
#  695.0: {'attack': 38.0,
#   'defense': 33.0,
#   'hp': 44.0,
#   'name': 'Helioptile',
#   'pokemon_type': 'ElectricNormal',
#   'special_attack': 61.0,
#   'special_defense': 43.0,
#   'speed': 70.0,
#   'total': 289.0},
#  696.0: {'attack': 55.0,
#   'defense': 52.0,
#   'hp': 62.0,
#   'name': 'Heliolisk',
#   'pokemon_type': 'ElectricNormal',
#   'special_attack': 109.0,
#   'special_defense': 94.0,
#   'speed': 109.0,
#   'total': 481.0},
#  697.0: {'attack': 89.0,
#   'defense': 77.0,
#   'hp': 58.0,
#   'name': 'Tyrunt',
#   'pokemon_type': 'RockDragon',
#   'special_attack': 45.0,
#   'special_defense': 45.0,
#   'speed': 48.0,
#   'total': 362.0},
#  698.0: {'attack': 121.0,
#   'defense': 119.0,
#   'hp': 82.0,
#   'name': 'Tyrantrum',
#   'pokemon_type': 'RockDragon',
#   'special_attack': 69.0,
#   'special_defense': 59.0,
#   'speed': 71.0,
#   'total': 521.0},
#  699.0: {'attack': 59.0,
#   'defense': 50.0,
#   'hp': 77.0,
#   'name': 'Amaura',
#   'pokemon_type': 'RockIce',
#   'special_attack': 67.0,
#   'special_defense': 63.0,
#   'speed': 46.0,
#   'total': 362.0},
#  700.0: {'attack': 77.0,
#   'defense': 72.0,
#   'hp': 123.0,
#   'name': 'Aurorus',
#   'pokemon_type': 'RockIce',
#   'special_attack': 99.0,
#   'special_defense': 92.0,
#   'speed': 58.0,
#   'total': 521.0},
#  701.0: {'attack': 65.0,
#   'defense': 65.0,
#   'hp': 95.0,
#   'name': 'Sylveon',
#   'pokemon_type': 'Fairy',
#   'special_attack': 110.0,
#   'special_defense': 130.0,
#   'speed': 60.0,
#   'total': 525.0},
#  702.0: {'attack': 92.0,
#   'defense': 75.0,
#   'hp': 78.0,
#   'name': 'Hawlucha',
#   'pokemon_type': 'FightingFlying',
#   'special_attack': 74.0,
#   'special_defense': 63.0,
#   'speed': 118.0,
#   'total': 500.0},
#  703.0: {'attack': 58.0,
#   'defense': 57.0,
#   'hp': 67.0,
#   'name': 'Dedenne',
#   'pokemon_type': 'ElectricFairy',
#   'special_attack': 81.0,
#   'special_defense': 67.0,
#   'speed': 101.0,
#   'total': 431.0},
#  704.0: {'attack': 50.0,
#   'defense': 150.0,
#   'hp': 50.0,
#   'name': 'Carbink',
#   'pokemon_type': 'RockFairy',
#   'special_attack': 50.0,
#   'special_defense': 150.0,
#   'speed': 50.0,
#   'total': 500.0},
#  705.0: {'attack': 50.0,
#   'defense': 35.0,
#   'hp': 45.0,
#   'name': 'Goomy',
#   'pokemon_type': 'Dragon',
#   'special_attack': 55.0,
#   'special_defense': 75.0,
#   'speed': 40.0,
#   'total': 300.0},
#  706.0: {'attack': 75.0,
#   'defense': 53.0,
#   'hp': 68.0,
#   'name': 'Sliggoo',
#   'pokemon_type': 'Dragon',
#   'special_attack': 83.0,
#   'special_defense': 113.0,
#   'speed': 60.0,
#   'total': 452.0},
#  707.0: {'attack': 100.0,
#   'defense': 70.0,
#   'hp': 90.0,
#   'name': 'Goodra',
#   'pokemon_type': 'Dragon',
#   'special_attack': 110.0,
#   'special_defense': 150.0,
#   'speed': 80.0,
#   'total': 600.0},
#  708.0: {'attack': 80.0,
#   'defense': 91.0,
#   'hp': 57.0,
#   'name': 'Klefki',
#   'pokemon_type': 'SteelFairy',
#   'special_attack': 80.0,
#   'special_defense': 87.0,
#   'speed': 75.0,
#   'total': 470.0},
#  709.0: {'attack': 70.0,
#   'defense': 48.0,
#   'hp': 43.0,
#   'name': 'Phantump',
#   'pokemon_type': 'GhostGrass',
#   'special_attack': 50.0,
#   'special_defense': 60.0,
#   'speed': 38.0,
#   'total': 309.0},
#  710.0: {'attack': 110.0,
#   'defense': 76.0,
#   'hp': 85.0,
#   'name': 'Trevenant',
#   'pokemon_type': 'GhostGrass',
#   'special_attack': 65.0,
#   'special_defense': 82.0,
#   'speed': 56.0,
#   'total': 474.0},
#  710.1: {'attack': 66.0,
#   'defense': 70.0,
#   'hp': 49.0,
#   'name': 'PumpkabooAverage Size',
#   'pokemon_type': 'GhostGrass',
#   'special_attack': 44.0,
#   'special_defense': 55.0,
#   'speed': 51.0,
#   'total': 335.0},
#  710.2: {'attack': 66.0,
#   'defense': 70.0,
#   'hp': 44.0,
#   'name': 'PumpkabooSmall Size',
#   'pokemon_type': 'GhostGrass',
#   'special_attack': 44.0,
#   'special_defense': 55.0,
#   'speed': 56.0,
#   'total': 335.0},
#  710.3000000000001: {'attack': 66.0,
#   'defense': 70.0,
#   'hp': 54.0,
#   'name': 'PumpkabooLarge Size',
#   'pokemon_type': 'GhostGrass',
#   'special_attack': 44.0,
#   'special_defense': 55.0,
#   'speed': 46.0,
#   'total': 335.0},
#  711.0: {'attack': 66.0,
#   'defense': 70.0,
#   'hp': 59.0,
#   'name': 'PumpkabooSuper Size',
#   'pokemon_type': 'GhostGrass',
#   'special_attack': 44.0,
#   'special_defense': 55.0,
#   'speed': 41.0,
#   'total': 335.0},
#  711.1: {'attack': 90.0,
#   'defense': 122.0,
#   'hp': 65.0,
#   'name': 'GourgeistAverage Size',
#   'pokemon_type': 'GhostGrass',
#   'special_attack': 58.0,
#   'special_defense': 75.0,
#   'speed': 84.0,
#   'total': 494.0},
#  711.2: {'attack': 85.0,
#   'defense': 122.0,
#   'hp': 55.0,
#   'name': 'GourgeistSmall Size',
#   'pokemon_type': 'GhostGrass',
#   'special_attack': 58.0,
#   'special_defense': 75.0,
#   'speed': 99.0,
#   'total': 494.0},
#  711.3000000000001: {'attack': 95.0,
#   'defense': 122.0,
#   'hp': 75.0,
#   'name': 'GourgeistLarge Size',
#   'pokemon_type': 'GhostGrass',
#   'special_attack': 58.0,
#   'special_defense': 75.0,
#   'speed': 69.0,
#   'total': 494.0},
#  712.0: {'attack': 100.0,
#   'defense': 122.0,
#   'hp': 85.0,
#   'name': 'GourgeistSuper Size',
#   'pokemon_type': 'GhostGrass',
#   'special_attack': 58.0,
#   'special_defense': 75.0,
#   'speed': 54.0,
#   'total': 494.0},
#  713.0: {'attack': 69.0,
#   'defense': 85.0,
#   'hp': 55.0,
#   'name': 'Bergmite',
#   'pokemon_type': 'Ice',
#   'special_attack': 32.0,
#   'special_defense': 35.0,
#   'speed': 28.0,
#   'total': 304.0},
#  714.0: {'attack': 117.0,
#   'defense': 184.0,
#   'hp': 95.0,
#   'name': 'Avalugg',
#   'pokemon_type': 'Ice',
#   'special_attack': 44.0,
#   'special_defense': 46.0,
#   'speed': 28.0,
#   'total': 514.0},
#  715.0: {'attack': 30.0,
#   'defense': 35.0,
#   'hp': 40.0,
#   'name': 'Noibat',
#   'pokemon_type': 'FlyingDragon',
#   'special_attack': 45.0,
#   'special_defense': 40.0,
#   'speed': 55.0,
#   'total': 245.0},
#  716.0: {'attack': 70.0,
#   'defense': 80.0,
#   'hp': 85.0,
#   'name': 'Noivern',
#   'pokemon_type': 'FlyingDragon',
#   'special_attack': 97.0,
#   'special_defense': 80.0,
#   'speed': 123.0,
#   'total': 535.0},
#  717.0: {'attack': 131.0,
#   'defense': 95.0,
#   'hp': 126.0,
#   'name': 'Xerneas',
#   'pokemon_type': 'Fairy',
#   'special_attack': 131.0,
#   'special_defense': 98.0,
#   'speed': 99.0,
#   'total': 680.0},
#  718.0: {'attack': 131.0,
#   'defense': 95.0,
#   'hp': 126.0,
#   'name': 'Yveltal',
#   'pokemon_type': 'DarkFlying',
#   'special_attack': 131.0,
#   'special_defense': 98.0,
#   'speed': 99.0,
#   'total': 680.0},
#  719.0: {'attack': 100.0,
#   'defense': 121.0,
#   'hp': 108.0,
#   'name': 'Zygarde Forme',
#   'pokemon_type': 'DragonGround',
#   'special_attack': 81.0,
#   'special_defense': 95.0,
#   'speed': 95.0,
#   'total': 600.0},
#  719.1: {'attack': 100.0,
#   'defense': 150.0,
#   'hp': 50.0,
#   'name': 'Diancie',
#   'pokemon_type': 'RockFairy',
#   'special_attack': 100.0,
#   'special_defense': 150.0,
#   'speed': 50.0,
#   'total': 600.0},
#  720.0: {'attack': 160.0,
#   'defense': 110.0,
#   'hp': 50.0,
#   'name': 'DiancieMega Diancie',
#   'pokemon_type': 'RockFairy',
#   'special_attack': 160.0,
#   'special_defense': 110.0,
#   'speed': 110.0,
#   'total': 700.0},
#  720.1: {'attack': 110.0,
#   'defense': 60.0,
#   'hp': 80.0,
#   'name': 'HoopaHoopa Confined',
#   'pokemon_type': 'PsychicGhost',
#   'special_attack': 150.0,
#   'special_defense': 130.0,
#   'speed': 70.0,
#   'total': 600.0},
#  721.0: {'attack': 160.0,
#   'defense': 60.0,
#   'hp': 80.0,
#   'name': 'HoopaHoopa Unbound',
#   'pokemon_type': 'PsychicDark',
#   'special_attack': 170.0,
#   'special_defense': 130.0,
#   'speed': 80.0,
#   'total': 680.0}}

# %% [markdown]
# ###### Step 8: Now calculate some basic statistics about the pokemon in the pokedex just created
#
# 1. What is the population mean of the "Total" attribute for all characters in the pokedex?
# 2. What is the standard deviation of the "Total" attribute for all characters in the pokedex?

# %%
#calculate the mean

# initialize a blank list to store the totals of each pokemon
poke_mean = []

# use a for loop to grab the total power for each pokeon
for pokemon in new_full_pokedex:
    poke_mean.append(new_full_pokedex[pokemon]['total'])
p_mean = sum(poke_mean[1:])/(len(new_full_pokedex) - 1)

# print out the result
print("The population mean of the 'Total' attribute is {}".format(p_mean))
# Out:
# The population mean of the 'Total' attribute is 434.92115143929914

# %%
# calculate the std
# formula for std is: ((1/n)*(sum((i-sample_mean)**2)))**(1.0/2)

observations = poke_mean[1:]
sample_mean = p_mean
difs = [i - sample_mean for i in observations]
dif_sq = [i**2 for i in difs]
sum_dif_sq = sum(dif_sq)
var = (1/len(observations))*sum_dif_sq
p_std = var**(1.0/2)

# print out the result
print("The standard deviation of the 'Total' attribute is {}".format(p_std))
# Out:
# The standard deviation of the 'Total' attribute is 119.89509407250227

# %% [markdown]
# ###### Step 9: Use function to determine if any pokemon are unbalanced
#
# Characters are "overpowered" if they have a "Total" more than three standard deviations from the population mean.

# %%
# use the std and mean calculated above to see if characters are out of balance
p_std = p_std
p_mean = p_mean


# make the function
def overpowered(key):
    """Returns a dictionary with keys set to the pokemon ids and boolean values to indicate if the pokemon is overpowered.
    key is the key in the pokemon dictionary.
    """
    out_of_balance = (3 * p_std) + p_mean
    if key['total'] > out_of_balance:
        return True
    else:
        return False

# %%
# use a dictionary comprehension to apply the overpowered function to the pokedex
balance_dct = {key:overpowered(value) for key, value in new_full_pokedex.items() if isinstance(value['total'], float)}

# %%
# are there any overpowered pokemon? apply a filter to the balance_dct
overpowered_dct = {key: value for key, value in balance_dct.items() if value}
print(sum(overpowered_dct.values()))
# Out:
# 1

# %%
# yes, there is! But which one is it?
print({key: value for key, value in balance_dct.items() if value == True})
# Out:
# {150.2: True}

# %%
#now we know the id number and can call it from the full pokedex.
new_full_pokedex[150.2]
# Out:
# {'attack': 190.0,
#  'defense': 100.0,
#  'hp': 126.0,
#  'name': 'MewtwoMega Mewtwo X',
#  'pokemon_type': 'PsychicFighting',
#  'special_attack': 154.0,
#  'special_defense': 100.0,
#  'speed': 130.0,
#  'total': 800.0}

# %% [markdown]
# ###### Step 9.1: To confirm that the function and filter are working as they should, create a new pokemon that is overpowered and redo the test

# %%
# create a new pokemon that is incredibly overpowered

overpowered_pokemon = {999: {'attack': 100.0,
     'defense': 100.0,
     'hp': 1000.0,
     'name': 'david',
     'pokemon_type': 'other',
     'special_attack': 100.0,
     'special_defense': 100.0,
     'speed': 100.0,
     'total': 1500.0}}

# %%
# create a copy of the full pokedex and append the new overpowered pokemon to this new pokedex
new_new_full_pokedex = new_full_pokedex.copy()
new_new_full_pokedex.update(overpowered_pokemon)

# print out the new pokemon to confirm it was successfully appended
print(new_new_full_pokedex[999])
# Out:
# {'attack': 100.0, 'defense': 100.0, 'hp': 1000.0, 'name': 'david', 'pokemon_type': 'other', 'special_attack': 100.0, 'special_defense': 100.0, 'speed': 100.0, 'total': 1500.0}

# %%
# create a new dictionary to assess the balance using a dictionary comprehension
new_balance_dct = {key:overpowered(value) for key, value in new_new_full_pokedex.items()\
                   if isinstance(value['total'], float)}
#apply the same comprehension to search for overpowere pokemon
new_overpowered = {key: value for key, value in new_balance_dct.items() if value}

# return the overwpowered pokemon
new_overpowered
# Out:
# {150.2: True, 999: True}
